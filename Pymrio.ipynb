# %% [markdown]
# <a href="https://colab.research.google.com/github/Tom-Jung/Tom-Jung/blob/main/Pymrio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
pip install pymrio --upgrade
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.5/133.5 kB 2.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 15.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.0/250.0 kB 11.9 MB/s eta 0:00:00
# ...
#   Created wheel for pymrio: filename=pymrio-0.5.4-py3-none-any.whl size=140078 sha256=ec652ea5745cf58ef8f0ebf1691fe69402b199f4a1e07f47bdc150aa284160af
#   Stored in directory: /root/.cache/pip/wheels/00/82/5b/0f466095a87b3b8ab221af30e845f6da97975ffc021b0c5bbd
# Successfully built pymrio
# ...
#   Attempting uninstall: openpyxl
#     Found existing installation: openpyxl 3.1.5
#     Uninstalling openpyxl-3.1.5:
#       Successfully uninstalled openpyxl-3.1.5
# ...

# %%
import pymrio
test_mrio = pymrio.load_test()

# %%
print(test_mrio.get_sectors())
print(test_mrio.get_regions())
# Out:
# Index(['food', 'mining', 'manufactoring', 'electricity', 'construction',
#        'trade', 'transport', 'other'],
#       dtype='object', name='sector')
# Index(['reg1', 'reg2', 'reg3', 'reg4', 'reg5', 'reg6'], dtype='object', name='region')

# %%
test_mrio.Z
test_mrio.emissions.F
# Out:
# region                            reg1                                         \
# sector                            food      mining manufactoring  electricity
# stressor       compartment
# emission_type1 air          1848064.80  986448.090   23613787.00  28139100.00
# emission_type2 water         139250.47   22343.295     763569.18    273981.55
#
# region                                                                     \
# sector                     construction      trade   transport      other
# stressor       compartment
# emission_type1 air           2584141.80  4132656.3  21766987.0  7842090.6
# emission_type2 water          317396.51  1254477.8   1012999.1  2449178.0
#
# region                            reg2              ...      reg5              \
# sector                            food      mining  ... transport       other
# stressor       compartment                          ...
# emission_type1 air          1697937.30  347378.150  ...  42299319  10773826.0
# ...

# %%
test_mrio.calc_all()
# Out:
# /usr/local/lib/python3.11/dist-packages/pymrio/core/mriosystem.py:900: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   Y_agg = Y.groupby(level="region", axis=1, sort=False).sum()
# /usr/local/lib/python3.11/dist-packages/pymrio/core/mriosystem.py:984: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   self.D_cba.groupby(level="region", axis=1, sort=False).sum()
# /usr/local/lib/python3.11/dist-packages/pymrio/core/mriosystem.py:993: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   self.D_pba.groupby(level="region", axis=1, sort=False).sum()
# /usr/local/lib/python3.11/dist-packages/pymrio/core/mriosystem.py:1001: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   self.D_imp_reg = self.D_imp.groupby(
# ...

# %%
test_mrio.A
test_mrio.emissions.D_cba
test_mrio.emissions.D_exp
# Out:
# region                               reg1                               \
# sector                               food         mining manufactoring
# stressor       compartment
# emission_type1 air          926543.977573  512746.861038  1.887986e+07
# emission_type2 water         69814.480722   11613.844147  6.104941e+05
#
# region                                                               \
# sector                       electricity construction         trade
# stressor       compartment
# emission_type1 air          8.152246e+06  3435.857568  1.735434e+06
# emission_type2 water        7.937585e+04   422.008266  5.267953e+05
#
# region                                                          reg2  \
# sector                         transport          other         food
# stressor       compartment
# emission_type1 air          1.148746e+07  289428.775142  3071.981372
# emission_type2 water        5.346073e+05   90392.042735   370.597110
#
# ...

# %%
import matplotlib as plt
test_mrio.emissions.plot_account('emission_type1')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-9122296add2b> in <cell line: 0>()
#       1 import matplotlib as plt
#       2 test_mrio.emissions.plot_account('emission_type1')
# ----> 3 plt.show()
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/_api/__init__.py in __getattr__(name)
#     216         if name in props:
#     217             return props[name].__get__(instance)
# --> 218         raise AttributeError(
#     219             f"module {cls.__module__!r} has no attribute {name!r}")
#     220
#
# AttributeError: module 'matplotlib' has no attribute 'show'

# %%
test_mrio.save_all('some/folder')

# %%
exio3_folder = "/tmp/mrios/autodownload/EXIO3"

# %%
exio_downloadlog = pymrio.download_exiobase3(
    storage_folder=exio3_folder, system="pxp", years=[2011, 2012]
)

# %%
exio_downloadlog
# Out:
# Description: Download log of EXIOBASE3
# MRIO Name: EXIO3
# System: pxp
# Version: 10.5281/zenodo.3583070
# File: /tmp/mrios/autodownload/EXIO3/download_log.json
# History:
# 20250214 06:39:11 - FILEIO -  Downloaded https://zenodo.org/records/14614930/files/IOT_2012_pxp.zip to IOT_2012_pxp.zip
# 20250214 06:38:16 - FILEIO -  Downloaded https://zenodo.org/records/14614930/files/IOT_2011_pxp.zip to IOT_2011_pxp.zip
# 20250214 06:37:37 - NOTE -  Download log created
# 20250214 06:37:37 - NOTE -  python_version: 3.11.11
# 20250214 06:37:37 - NOTE -  pymrio_version: 0.5.4
# 20250214 06:37:37 - NOTE -  os: Linux
# 20250214 06:37:37 - NOTE -  hostname: 985236cf07c4
# 20250214 06:37:37 - NOTE -  username: root

# %%
oecd_folder_v2021 = "/tmp/mrios/autodownload/OECD_2021"
oecd_folder_v2018 = "/tmp/mrios/autodownload/OECD_2018"

# %%
oecd_folder_v2021
# Out:
# '/tmp/mrios/autodownload/OECD_2021'

# %%
log_2021 = pymrio.download_oecd(storage_folder=oecd_folder_v2021)

# %%
import os

# 다운로드된 파일 확인
files = os.listdir(oecd_folder_v2021)
print(files)
# Out:
# ['ICIO2023_ICIO2023_ICIO2023_ICIO2023_ICIO2023_1995.csv', 'ICIO2023_ICIO2023_2015.csv', 'ICIO2023_ICIO2023_2012.csv', 'ICIO2023_ICIO2023_ICIO2023_ICIO2023_2002.csv', 'ICIO2023_ICIO2023_ICIO2023_2009.csv', 'ICIO2023_ICIO2023_ICIO2023_ICIO2023_ICIO2023_1998.csv', 'ICIO2023_ICIO2023_ICIO2023_ICIO2023_2005.csv', 'ICIO2023_ICIO2023_ICIO2023_2006.csv', 'ICIO2023_ICIO2023_ICIO2023_ICIO2023_2004.csv', 'ICIO2023_2017.csv', 'ICIO2023_2019.csv', 'ICIO2023_ICIO2023_2011.csv', 'ICIO2023_ICIO2023_ICIO2023_ICIO2023_ICIO2023_2000.csv', 'ICIO2023_ICIO2023_ICIO2023_ICIO2023_2003.csv', 'ICIO2023_2016.csv', 'ICIO2023_ICIO2023_2014.csv', 'ICIO2023_ICIO2023_2013.csv', 'ICIO2023_2018.csv', 'ICIO2023_ICIO2023_ICIO2023_2007.csv', 'ICIO2023_ICIO2023_ICIO2023_ICIO2023_ICIO2023_1999.csv', 'ICIO2023_ICIO2023_ICIO2023_2010.csv', 'ICIO2023_2020.csv', 'ICIO2023_ICIO2023_ICIO2023_2008.csv', 'ICIO2023_ICIO2023_ICIO2023_ICIO2023_ICIO2023_1997.csv', 'download_log.json', 'ICIO2023_ICIO2023_ICIO2023_ICIO2023_2001.csv', '
# ...

# %%
import pandas as pd

# 예제: "oecd_data.csv" 파일이 있다고 가정
file_path = os.path.join(oecd_folder_v2021, "oecd_data.csv")

# CSV 파일을 Pandas DataFrame으로 읽기
df = pd.read_csv('/tmp/mrios/autodownload/OECD_2021/ICIO2023_2016.csv')
print(df.head())  # 데이터 확인
df.head()
# Out:
#            V1  ARG_A01_02  ARG_A03  ARG_B05_06  ARG_B07_08   ARG_B09  \
# 0  ARG_A01_02   6715.3233  25.6137      2.9099      2.8416    0.0000
# 1     ARG_A03      5.3468  87.4997      0.0428      0.0003    0.0026
# 2  ARG_B05_06      4.9437   0.1199    261.7120     10.0641   29.8039
# 3  ARG_B07_08      0.8736   0.1744     68.4119    266.8836    0.0143
# 4     ARG_B09      0.0000   0.0000   3822.4815     63.9287  131.6347
#
#    ARG_C10T12  ARG_C13T15  ARG_C16  ARG_C17_18  ...  ZAF_GFCF  ZAF_INVNT  \
# 0  28270.0241   1438.8787  84.5193     78.9725  ...    2.3427        0.0
# 1    565.5521      0.0250   0.0007      0.1206  ...    0.0000        0.0
# 2     12.4020      1.7770   0.5075      1.2633  ...    0.0030        0.0
# 3     94.6170      7.9503   0.0400      6.5265  ...    0.0002        0.0
# 4      0.0000      0.0000   0.0000      0.0000  ...    0.0000        0.0
#
#    ZAF_DPABR  ROW_HFCE  ROW_NPISH  ROW_GGFC  ROW_GFCF  ROW_INVNT  ROW_DPABR  \
# ...

# %%
import os

# 다운로드 폴더 경로
data_folder = "/tmp/mrios/autodownload/OECD_2021"

# 폴더가 존재하는지 확인
if os.path.exists(data_folder):
    print("폴더가 존재합니다.")
    print("파일 목록:", os.listdir(data_folder))
else:
    print("폴더가 존재하지 않습니다. 데이터를 다시 다운로드하세요.")
# Out:
# 폴더가 존재합니다.
# ...

# %%
import os

# 저장 폴더 경로 (사용자가 설정한 폴더)
oecd_folder_v2021 = "/tmp/mrios/autodownload/OECD_2021"

# 폴더가 존재하는지 확인
if os.path.exists(oecd_folder_v2021):
    print("폴더가 존재합니다. 파일 목록:")
    print(os.listdir(oecd_folder_v2021))
else:
    print("폴더가 존재하지 않습니다. 데이터를 다시 다운로드하세요.")
# Out:
# 폴더가 존재합니다. 파일 목록:
# ...
