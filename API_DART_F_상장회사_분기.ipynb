# %% [markdown]
# <a href="https://colab.research.google.com/github/Tom-Jung/Tom-Jung/blob/main/API_DART_F_%EC%83%81%EC%9E%A5%ED%9A%8C%EC%82%AC_%EB%B6%84%EA%B8%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install dart-fss
# Out:
# Collecting dart-fss
#   Downloading dart_fss-0.4.13-py3-none-any.whl.metadata (3.6 kB)
# Collecting xmltodict (from dart-fss)
#   Downloading xmltodict-0.14.2-py2.py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from dart-fss) (2.32.3)
# Collecting arelle-release (from dart-fss)
#   Downloading arelle_release-2.37.3-py3-none-any.whl.metadata (9.1 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from dart-fss) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from dart-fss) (2.2.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from dart-fss) (4.67.1)
# Collecting yaspin (from dart-fss)
#   Downloading yaspin-3.1.0-py3-none-any.whl.metadata (14 kB)
# Collecting fake-useragent>=1.5 (from dart-fss)
#   Downloading fake_useragent-2.2.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from dart-fss) (4.13.4)
# Collecting appdirs (from dart-fss)
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting bottle<0.14,>=0.13 (from arelle-release->dart-fss)
#   Downloading bottle-0.13.3-py2.py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from arelle-release->dart-fss) (2025.1.31)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from arelle-release->dart-fss) (3.18.0)
# Collecting isodate==0.* (from arelle-release->dart-fss)
#   Downloading isodate-0.7.2-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: lxml<6,>=4 in /usr/local/lib/python3.11/dist-packages (from arelle-release->dart-fss) (5.3.2)
# Requirement already satisfied: openpyxl==3.* in /usr/local/lib/python3.11/dist-packages (from arelle-release->dart-fss) (3.1.5)
# Requirement already satisfied: pillow<12,>=10 in /usr/local/lib/python3.11/dist-packages (from arelle-release->dart-fss) (11.1.0)
# Requirement already satisfied: pyparsing==3.* in /usr/local/lib/python3.11/dist-packages (from arelle-release->dart-fss) (3.2.3)
# Requirement already satisfied: python-dateutil==2.* in /usr/local/lib/python3.11/dist-packages (from arelle-release->dart-fss) (2.8.2)
# Requirement already satisfied: regex in /usr/local/lib/python3.11/dist-packages (from arelle-release->dart-fss) (2024.11.6)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.11/dist-packages (from openpyxl==3.*->arelle-release->dart-fss) (2.0.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil==2.*->arelle-release->dart-fss) (1.17.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->dart-fss) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->dart-fss) (4.13.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->dart-fss) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->dart-fss) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->dart-fss) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->dart-fss) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->dart-fss) (2.3.0)
# Collecting termcolor<2.4.0,>=2.2.0 (from yaspin->dart-fss)
#   Downloading termcolor-2.3.0-py3-none-any.whl.metadata (5.3 kB)
# Downloading dart_fss-0.4.13-py3-none-any.whl (146 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 146.7/146.7 kB 4.4 MB/s eta 0:00:00
# Downloading fake_useragent-2.2.0-py3-none-any.whl (161 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.7/161.7 kB 6.6 MB/s eta 0:00:00
# Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Downloading arelle_release-2.37.3-py3-none-any.whl (44.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.9/44.9 MB 14.6 MB/s eta 0:00:00
# Downloading isodate-0.7.2-py3-none-any.whl (22 kB)
# Downloading xmltodict-0.14.2-py2.py3-none-any.whl (10.0 kB)
# Downloading yaspin-3.1.0-py3-none-any.whl (18 kB)
# Downloading bottle-0.13.3-py2.py3-none-any.whl (104 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.2/104.2 kB 7.0 MB/s eta 0:00:00
# Downloading termcolor-2.3.0-py3-none-any.whl (6.9 kB)
# Installing collected packages: bottle, appdirs, xmltodict, termcolor, isodate, fake-useragent, yaspin, arelle-release, dart-fss
#   Attempting uninstall: termcolor
#     Found existing installation: termcolor 3.0.1
#     Uninstalling termcolor-3.0.1:
#       Successfully uninstalled termcolor-3.0.1
# Successfully installed appdirs-1.4.4 arelle-release-2.37.3 bottle-0.13.3 dart-fss-0.4.13 fake-useragent-2.2.0 isodate-0.7.2 termcolor-2.3.0 xmltodict-0.14.2 yaspin-3.1.0

# %% [markdown]
# # 분기보고서 다운로드 후 정리하기

# %%
import requests
import zipfile
import io
import xml.etree.ElementTree as ET
import pandas as pd
import re

# 1. API 엔드포인트 및 파라미터 설정 (DART Open API 사용)
API_KEY = "e5ebd99a0228714b70206b955cb7931ffc873783"  # 여기에 발급받은 API 키를 입력하세요
CORP_CODE = "00126380"  # 삼성전자 종목코드 예시, 실제 회사 코드로 변경
REPORT_CODE = "11011"  # 사업보고서 코드
QUARTER = "20234Q"  # 2023년 4분기

# 2. API 호출 및 XBRL 파일 다운로드
def download_xbrl(api_key, corp_code, report_code, bsns_year, reprt_code):
    """DART Open API를 통해 XBRL zip 파일을 다운로드합니다."""
    url = "https://opendart.fss.or.kr/api/list.xml"
    params = {
        "crtfc_key": api_key,
        "corp_code": corp_code,
        "bsns_year": bsns_year[:4],
        "reprt_code": reprt_code,
        "page_count": 100
    }
    response = requests.get(url, params=params)
    response.raise_for_status()
    xml_data = response.text

    # 필요한 정보 추출 (list.xml 응답에서)
    root = ET.fromstring(xml_data)
    ns = {'default': 'http://dart.fss.or.kr/dtd/ns/corpcode'}  # 네임스페이스 정의
    file_name = root.find(".//default:list/default:atch_file", namespaces=ns).text
    report_name = root.find(".//default:list/default:report_nm", namespaces=ns).text
    url = f"https://opendart.fss.or.kr/api/document.xml?crtfc_key={api_key}&rcept_no={root.find('.//default:list/default:rcept_no', namespaces=ns).text}"
    # URL 및 API 키를 사용하여 document.xml 다운로드 시도
    response = requests.get(url)
    response.raise_for_status()
    xml_data = response.text
    root = ET.fromstring(xml_data)
    link = root.find('.//default:list/default:atch_file', namespaces=ns).text
    link_str = f"https://opendart.fss.or.kr/api/download.zip?crtfc_key={api_key}&atch_file={root.find('.//default:list/default:atch_file', namespaces=ns).text}&rcept_no={root.find('.//default:list/default:rcept_no', namespaces=ns).text}"
    # 다운로드 URL
    download_url = f"https://opendart.fss.or.kr/api/download.zip?crtfc_key={api_key}&atch_file={link}&rcept_no={root.find('.//default:list/default:rcept_no', namespaces=ns).text}"


    zip_response = requests.get(download_url)
    zip_response.raise_for_status()  # 에러 발생 시 예외 처리
    return io.BytesIO(zip_response.content)

# 3. XBRL 파일 파싱 및 계정과목 추출
def parse_xbrl(zip_file):
    """XBRL zip 파일에서 계정과목 및 값을 추출합니다."""
    account_data = []
    with zipfile.ZipFile(zip_file, "r") as zf:
        for filename in zf.namelist():
            if filename.endswith(".xml"):  # XBRL 파일만 처리
                try:
                    with zf.open(filename) as xml_file:
                        tree = ET.parse(xml_file)
                        root = tree.getroot()

                        # 네임스페이스 처리 (네임스페이스가 있는 경우)
                        ns = {'xbrli': 'http://www.xbrl.org/2003/instance'}
                        # 필요한 정보 추출 (계정과목 이름, 값 등)
                        for element in root.findall(".//*[@contextRef]", namespaces=ns):
                            context_ref = element.get('contextRef')
                            # 각 element.tag 에서 account name 추출
                            tag_name = element.tag.split("}")[-1]
                            # 값 추출
                            text_value = element.text
                            # 계정과목명, 값을 튜플로 저장
                            account_data.append((tag_name, text_value, context_ref))

                except Exception as e:
                    print(f"Error parsing {filename}: {e}")
    return account_data

# 4. 데이터 프레임 생성 및 결과 확인
def create_dataframe(account_data):
    """추출된 계정 데이터로 Pandas DataFrame을 생성합니다."""
    df = pd.DataFrame(account_data, columns=["계정과목", "값", "ContextRef"])
    return df

# 5. Main 실행 함수
if __name__ == "__main__":
    try:
        # XBRL 파일 다운로드
        zip_file = download_xbrl(API_KEY, CORP_CODE, REPORT_CODE, QUARTER, "11011")

        # XBRL 파일 파싱
        account_data = parse_xbrl(zip_file)

        # 데이터 프레임 생성
        df = create_dataframe(account_data)

        # 결과 출력 (예시)
        print(df.head())
        # 필요하다면 CSV 파일로 저장
        # df.to_csv("account_data.csv", encoding="utf-8-sig", index=False)

    except Exception as e:
        print(f"오류 발생: {e}")
# Out:
# 오류 발생: 'NoneType' object has no attribute 'text'

# %%
import requests
import pandas as pd
import time

# DART API 인증키 (본인의 API 키 입력)
API_KEY = 'e5ebd99a0228714b70206b955cb7931ffc873783'

# DART 재무제표 API URL
FS_URL = "https://opendart.fss.or.kr/api/fnlttSinglAcntAll.json"

# 기업 리스트 엑셀 파일 읽기
file_path = "./corp_list_split.xlsx"  # 로컬 파일 경로
corporations_df = pd.read_excel(file_path, sheet_name="L1", dtype={'code': str})

# 데이터 저장을 위한 리스트
financial_data = []

# 자본변동표 관련 계정과목 필터링 리스트
exclude_accounts = [
    "자본금 변동", "기타포괄손익누계액", "이익잉여금 변동",
    "자본총계 변동", "기타자본항목 변동", "배당금 지급", "주식발행", "자본조정"
]

# 자본 관련 항목 리스트 (우선 재무상태표 항목을 우선하고, 없는 경우 첫 번째로 나온 항목 선택)
capital_related_accounts = ["자본총계", "기초자본", "자본금", "이익잉여금", "기타자본항목"]

# 기업별 재무제표 요청
for _, row in corporations_df.iterrows():
    corp_code = row['code']  # 기업 코드
    corp_name = row.get('name', '알 수 없음')  # 기업 이름

    params = {
        'crtfc_key': API_KEY,
        'corp_code': corp_code,
        'bsns_year': "20234Q",  # 연도
        'reprt_code': '11011',  # 사업보고서 (연결 재무제표)
        'fs_div': 'OFS'  # 개별 재무제표 (자본변동표 포함 X)
    }

    try:
        # API 요청
        response = requests.get(FS_URL, params=params, timeout=10)
        response.raise_for_status()
        data = response.json()

        if data.get('status') == '000':  # 정상 응답
            if 'list' in data and data['list']:
                unique_accounts = set()  # 중복 방지를 위한 set
                first_appearance_accounts = []  # 첫 번째로 나온 항목을 저장할 리스트

                for item in data['list']:
                    account_name = item['account_nm'].strip()
                    account_id = item.get('account_id', '데이터 없음')  # account_id 추가

                    # 자본변동표 관련 항목 제외
                    if any(excl in account_name for excl in exclude_accounts):
                        continue

                    # 자본 관련 계정 처리: 재무상태표에 있는 항목을 우선하고, 없으면 첫 번째 항목 사용
                    if any(account_name.startswith(capital_account) for capital_account in capital_related_accounts):
                        # 재무상태표에 있는 자본 항목을 우선 처리
                        if account_name not in unique_accounts:
                            unique_accounts.add(account_name)
                            financial_data.append({
                                "기업 이름": corp_name,
                                "기업 코드": corp_code,
                                "연도": 2023,
                                "계정과목명": account_name,
                                "account_id": account_id,  # account_id 추가
                                "금액": item.get('thstrm_amount', '데이터 없음'),  # 2023년 금액
                                "2022년 금액": item.get('frmtrm_amount', '데이터 없음'),  # 2022년 금액
                                "2021년 금액": item.get('lfy_amount', '데이터 없음')  # 2021년 금액
                            })
                    else:
                        # 첫 번째로 나온 자본 관련 항목을 선택하여 추가
                        if account_name not in first_appearance_accounts:
                            first_appearance_accounts.append(account_name)
                            financial_data.append({
                                "기업 이름": corp_name,
                                "기업 코드": corp_code,
                                "연도": "20234Q",
                                "계정과목명": account_name,
                                "account_id": account_id,  # account_id 추가
                                "금액": item.get('thstrm_amount', '데이터 없음'),  # 2023년 금액
                                "2022년 금액": item.get('frmtrm_amount', '데이터 없음'),  # 2022년 금액
                                "2021년 금액": item.get('lfy_amount', '데이터 없음')  # 2021년 금액
                            })

                print(f"✅ {corp_name}({corp_code}) - 데이터 수집 완료")
            else:
                print(f"⚠️ {corp_name}({corp_code}) - 재무 데이터 없음")
        else:
            print(f"❌ {corp_name}({corp_code}) - API 오류: {data.get('message', '알 수 없는 오류')}")

    except requests.exceptions.RequestException as e:
        print(f"🚨 {corp_name}({corp_code}) - 요청 실패: {e}")

    time.sleep(1)  # API 요청 간격 조정

# DataFrame 변환
df_1 = pd.DataFrame(financial_data)

# 결과 저장
output_excel = "기업_재무제표_2023년_L1.xlsx"

df_1.to_excel(output_excel, index=False)

print(f"✅ 데이터 저장 완료: {output_excel}, {output_excel}")
# Out:
# ❌ (주)파라다이스(00171265) - API 오류: 조회된 데이타가 없습니다.
# ❌ 한국타이어앤테크놀로지(주)(00937324) - API 오류: 조회된 데이타가 없습니다.
# ❌ 한국철강 주식회사(00687711) - API 오류: 조회된 데이타가 없습니다.
# ❌ 대원강업 주식회사(00111847) - API 오류: 조회된 데이타가 없습니다.
# ❌ 키스코홀딩스 주식회사(00159740) - API 오류: 조회된 데이타가 없습니다.
# ❌ (주)팜젠사이언스(00135050) - API 오류: 조회된 데이타가 없습니다.
# ❌ (주)지니뮤직(00223762) - API 오류: 조회된 데이타가 없습니다.
# ❌ 새론오토모티브(주)(00305668) - API 오류: 조회된 데이타가 없습니다.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-2bc678187adf> in <cell line: 0>()
#      96         print(f"🚨 {corp_name}({corp_code}) - 요청 실패: {e}")
#      97
# ---> 98     time.sleep(1)  # API 요청 간격 조정
#      99
#     100 # DataFrame 변환
#
# KeyboardInterrupt:

# %% [markdown]
# #
# :------------------------------------------------------------------------------L2------------------------------------

# %%
import requests
import pandas as pd
import time

# DART API 인증키 (본인의 API 키 입력)
API_KEY = '85006d20472a255d5eae25ee265b5ed1b78d1386'

# DART 재무제표 API URL
FS_URL = "https://opendart.fss.or.kr/api/fnlttSinglAcntAll.json"

# 기업 리스트 엑셀 파일 읽기
file_path = "./corp_list_split.xlsx"  # 로컬 파일 경로
corporations_df = pd.read_excel(file_path, sheet_name="L2", dtype={'code': str})

# 데이터 저장을 위한 리스트
financial_data = []

# 자본변동표 관련 계정과목 필터링 리스트
exclude_accounts = [
    "자본금 변동", "기타포괄손익누계액", "이익잉여금 변동",
    "자본총계 변동", "기타자본항목 변동", "배당금 지급", "주식발행", "자본조정"
]

# 자본 관련 항목 리스트 (우선 재무상태표 항목을 우선하고, 없는 경우 첫 번째로 나온 항목 선택)
capital_related_accounts = ["자본총계", "기초자본", "자본금", "이익잉여금", "기타자본항목"]

# 기업별 재무제표 요청
for _, row in corporations_df.iterrows():
    corp_code = row['code']  # 기업 코드
    corp_name = row.get('name', '알 수 없음')  # 기업 이름

    params = {
        'crtfc_key': API_KEY,
        'corp_code': corp_code,
        'bsns_year': 2023,  # 연도
        'reprt_code': '11011',  # 사업보고서 (연결 재무제표)
        'fs_div': 'OFS'  # 개별 재무제표 (자본변동표 포함 X)
    }

    try:
        # API 요청
        response = requests.get(FS_URL, params=params, timeout=10)
        response.raise_for_status()
        data = response.json()

        if data.get('status') == '000':  # 정상 응답
            if 'list' in data and data['list']:
                unique_accounts = set()  # 중복 방지를 위한 set
                first_appearance_accounts = []  # 첫 번째로 나온 항목을 저장할 리스트

                for item in data['list']:
                    account_name = item['account_nm'].strip()
                    account_id = item.get('account_id', '데이터 없음')  # account_id 추가

                    # 자본변동표 관련 항목 제외
                    if any(excl in account_name for excl in exclude_accounts):
                        continue

                    # 자본 관련 계정 처리: 재무상태표에 있는 항목을 우선하고, 없으면 첫 번째 항목 사용
                    if any(account_name.startswith(capital_account) for capital_account in capital_related_accounts):
                        # 재무상태표에 있는 자본 항목을 우선 처리
                        if account_name not in unique_accounts:
                            unique_accounts.add(account_name)
                            financial_data.append({
                                "기업 이름": corp_name,
                                "기업 코드": corp_code,
                                "연도": 2023,
                                "계정과목명": account_name,
                                "account_id": account_id,  # account_id 추가
                                "금액": item.get('thstrm_amount', '데이터 없음'),  # 2023년 금액
                                "2022년 금액": item.get('frmtrm_amount', '데이터 없음'),  # 2022년 금액
                                "2021년 금액": item.get('lfy_amount', '데이터 없음')  # 2021년 금액
                            })
                    else:
                        # 첫 번째로 나온 자본 관련 항목을 선택하여 추가
                        if account_name not in first_appearance_accounts:
                            first_appearance_accounts.append(account_name)
                            financial_data.append({
                                "기업 이름": corp_name,
                                "기업 코드": corp_code,
                                "연도": 2023,
                                "계정과목명": account_name,
                                "account_id": account_id,  # account_id 추가
                                "금액": item.get('thstrm_amount', '데이터 없음'),  # 2023년 금액
                                "2022년 금액": item.get('frmtrm_amount', '데이터 없음'),  # 2022년 금액
                                "2021년 금액": item.get('lfy_amount', '데이터 없음')  # 2021년 금액
                            })

                print(f"✅ {corp_name}({corp_code}) - 데이터 수집 완료")
            else:
                print(f"⚠️ {corp_name}({corp_code}) - 재무 데이터 없음")
        else:
            print(f"❌ {corp_name}({corp_code}) - API 오류: {data.get('message', '알 수 없는 오류')}")

    except requests.exceptions.RequestException as e:
        print(f"🚨 {corp_name}({corp_code}) - 요청 실패: {e}")

    time.sleep(1)  # API 요청 간격 조정

# DataFrame 변환
df_2 = pd.DataFrame(financial_data)

# 결과 저장
output_excel = "기업_재무제표_2023년_L2.xlsx"

df_2.to_excel(output_excel, index=False)

print(f"✅ 데이터 저장 완료: {output_excel}, {output_excel}")
# Out:
# ✅ (주)휴비츠(00398668) - 데이터 수집 완료
# ✅ 주식회사 휴스틸(00156488) - 데이터 수집 완료
# ✅ 주식회사 엔지켐생명과학(00606886) - 데이터 수집 완료
# ✅ 삼화전자공업(주)(00129280) - 데이터 수집 완료
# ✅ 주식회사 덕신이피씨(00454937) - 데이터 수집 완료
# ✅ 엔에이치엔(주)(00983271) - 데이터 수집 완료
# ✅ 피에이치에이 주식회사(00155151) - 데이터 수집 완료
# ✅ (주)에이스테크놀로지(00556907) - 데이터 수집 완료
# ✅ 아이쓰리시스템(주)(00612489) - 데이터 수집 완료
# ✅ 대한약품공업주식회사(00113128) - 데이터 수집 완료
# ✅ (주)서한(00131504) - 데이터 수집 완료
# ✅ 주식회사 라닉스(01327092) - 데이터 수집 완료
# ✅ 스튜디오드래곤(주)(01168684) - 데이터 수집 완료
# ✅ (주)앤디포스(00942131) - 데이터 수집 완료
# ❌ 유성티엔에스(00173999) - API 오류: 조회된 데이타가 없습니다.
# ✅ (주)까스텔바작(01181807) - 데이터 수집 완료
# ✅ 주식회사 세토피아(01091382) - 데이터 수집 완료
# ✅ 광전자(주)(00152729) - 데이터 수집 완료
# ✅ (주)골드앤에스(00249502) - 데이터 수집 완료
# ✅ (주)인포바인(00491415) - 데이터 수집 완료
# ✅ 주식회사 남해화학(00107987) - 데이터 수집 완료
# ✅ 하이트진로홀딩스 주식회사(00148993) - 데이터 수집 완료
# ✅ (주)알에프텍(00309831) - 데이터 수집 완료
# ✅ 대원제약 주식회사(00111999) - 데이터 수집 완료
# ✅ 패션플랫폼(주)(01101041) - 데이터 수집 완료
# ✅ (주)씨유메디칼시스템(00681249) - 데이터 수집 완료
# ✅ 로체시스템즈 주식회사(00363486) - 데이터 수집 완료
# ✅ (주)이수앱지스(00526872) - 데이터 수집 완료
# ✅ 주식회사 휴센텍(01063884) - 데이터 수집 완료
# ✅ (주)한솔케미칼(00140955) - 데이터 수집 완료
# ✅ 주식회사 디에이치오토리드(01182578) - 데이터 수집 완료
# ✅ 에이치엠엠 주식회사(00164645) - 데이터 수집 완료
# ✅ ㈜일진파워(00485177) - 데이터 수집 완료
# ✅ (주)현대지에프홀딩스(00105280) - 데이터 수집 완료
# ✅ 일정실업(주)(00146542) - 데이터 수집 완료
# ✅ (주)온타이드(00168331) - 데이터 수집 완료
# ✅ 주식회사 매커스(00596677) - 데이터 수집 완료
# ✅ (주)한솔홈데코(00203582) - 데이터 수집 완료
# ✅ 주식회사 이랜시스(01199189) - 데이터 수집 완료
# ✅ 한울소재과학(00560122) - 데이터 수집 완료
# ✅ 엘아이지넥스원(주)(00503668) - 데이터 수집 완료
# ✅ (주)유니테크노(00531865) - 데이터 수집 완료
# ✅ 삼화전기주식회사(00129271) - 데이터 수집 완료
# ✅ 주식회사 디에이치오토웨어(00110583) - 데이터 수집 완료
# ✅ 엘지디스플레이(주)(00105873) - 데이터 수집 완료
# ✅ 주식회사 엠피씨플러스(00302078) - 데이터 수집 완료
# ✅ (주)와이씨(01109539) - 데이터 수집 완료
# ✅ (주)중앙첨단소재(00347716) - 데이터 수집 완료
# ✅ (주)알테오젠(00989619) - 데이터 수집 완료
# ✅ 주식회사 이엠앤아이(00475718) - 데이터 수집 완료
# ✅ 주식회사 네이처셀(00117276) - 데이터 수집 완료
# ✅ S-Oil 주식회사(00138279) - 데이터 수집 완료
# ✅ 주식회사 엠젠솔루션(00110884) - 데이터 수집 완료
# ✅ (주)경보제약(00101664) - 데이터 수집 완료
# ✅ (주) 피씨디렉트(00297934) - 데이터 수집 완료
# ✅ (주)푸른소나무(00410739) - 데이터 수집 완료
# ✅ 삼성에스디에스 주식회사(00126186) - 데이터 수집 완료
# ✅ 주식회사 멀티캠퍼스(00425351) - 데이터 수집 완료
# ✅ (주)케이씨텍(01261893) - 데이터 수집 완료
# ✅ (주)이엠넷(00616290) - 데이터 수집 완료
# ✅ (주)새로닉스(00147994) - 데이터 수집 완료
# ✅ 에이에프더블류(주)(01223219) - 데이터 수집 완료
# ✅ (주)서전기전(00869272) - 데이터 수집 완료
# ✅ (주)서울제약(00131018) - 데이터 수집 완료
# ✅ 주식회사알티캐스트(00364254) - 데이터 수집 완료
# ✅ 일신방직(주)(00146269) - 데이터 수집 완료
# ✅ 옵티시스 주식회사(00660291) - 데이터 수집 완료
# ✅ (주)유유제약(00144818) - 데이터 수집 완료
# ✅ (주)휴림에이텍(00230814) - 데이터 수집 완료
# ✅ 한신기계공업(주)(00162072) - 데이터 수집 완료
# ✅ 일동홀딩스 주식회사(00146083) - 데이터 수집 완료
# ✅ 일동제약 주식회사(01168383) - 데이터 수집 완료
# ✅ 주식회사 강원에너지(00100601) - 데이터 수집 완료
# ✅ 모베이스(00498001) - 데이터 수집 완료
# ✅ 서호전기 주식회사(00220622) - 데이터 수집 완료
# ✅ 한일사료(주)(00162911) - 데이터 수집 완료
# ✅ 주식회사 한창(00163716) - 데이터 수집 완료
# ✅ (주)오킨스전자(00543107) - 데이터 수집 완료
# ✅ 알리코제약(주)(00447007) - 데이터 수집 완료
# ✅ 주식회사 한국큐빅(00160010) - 데이터 수집 완료
# ✅ 지엠비코리아 주식회사(00156354) - 데이터 수집 완료
# ✅ 케이에스인더스트리(00618410) - 데이터 수집 완료
# ✅ 주식회사 파워로직스(00269612) - 데이터 수집 완료
# ✅ (주)셀트리온(00413046) - 데이터 수집 완료
# ✅ 아남전자 주식회사(00138516) - 데이터 수집 완료
# ✅ 주식회사 한섬(00188089) - 데이터 수집 완료
# ✅ 사조씨푸드 주식회사(00124780) - 데이터 수집 완료
# ✅ 전진바이오팜(주)(00632793) - 데이터 수집 완료
# ✅ 우림피티에스(주)(00567222) - 데이터 수집 완료
# ✅ 미원상사 주식회사(00121932) - 데이터 수집 완료
# ✅ (주)파버나인(00429694) - 데이터 수집 완료
# ✅ 화성밸브(주)(00217743) - 데이터 수집 완료
# ✅ 주식회사 쎄트렉아이(00449254) - 데이터 수집 완료
# ✅ 국일제지(주)(00104573) - 데이터 수집 완료
# ✅ 일성아이에스 주식회사(00146214) - 데이터 수집 완료
# ✅ 주식회사 노랑풍선(00632845) - 데이터 수집 완료
# ✅ 주식회사 에스티오(00612188) - 데이터 수집 완료
# ✅ 에이치디현대 주식회사(01205709) - 데이터 수집 완료
# ✅ (주)한화(00160588) - 데이터 수집 완료
# ✅ 일진다이아몬드㈜(00508274) - 데이터 수집 완료
# ✅ 주식회사 아이티아이즈(01429840) - 데이터 수집 완료
# ✅ 씨에스베어링(주)(00765462) - 데이터 수집 완료
# ✅ 주식회사 수산아이앤티(00577016) - 데이터 수집 완료
# ✅ 롯데정밀화학(주)(00157681) - 데이터 수집 완료
# ✅ 로지시스(00238199) - 데이터 수집 완료
# ✅ (주)장원테크(00659684) - 데이터 수집 완료
# ✅ 주식회사 대림제지(00109781) - 데이터 수집 완료
# ✅ 주식회사 디알텍(01062867) - 데이터 수집 완료
# ✅ 주식회사 신세계(00136378) - 데이터 수집 완료
# ✅ (주)LG생활건강(00356370) - 데이터 수집 완료
# ✅ (주)엠에스오토텍(00259545) - 데이터 수집 완료
# ✅ 주식회사 크래프톤(00760971) - 데이터 수집 완료
# ✅ 주식회사 브이원텍(01027794) - 데이터 수집 완료
# ✅ (주)유한양행(00145109) - 데이터 수집 완료
# ✅ 서울바이오시스 주식회사(00488402) - 데이터 수집 완료
# ✅ 주식회사 코미코(00997812) - 데이터 수집 완료
# ✅ 디엘 주식회사(00109693) - 데이터 수집 완료
# ✅ 피씨엘(주)(01051092) - 데이터 수집 완료
# ✅ 세방전지 주식회사(00133858) - 데이터 수집 완료
# ✅ 케이디켐(주)(00370918) - 데이터 수집 완료
# ✅ 씨아이에스 주식회사(01090471) - 데이터 수집 완료
# ✅ 주식회사 디와이디(01089378) - 데이터 수집 완료
# ✅ (주)지에스글로벌(00138190) - 데이터 수집 완료
# ✅ 주식회사 슈프리마(01124653) - 데이터 수집 완료
# ✅ 유아이엘 주식회사(00256380) - 데이터 수집 완료
# ✅ 팅크웨어(주)(00438036) - 데이터 수집 완료
# ✅ 주식회사 테이팩스(00256955) - 데이터 수집 완료
# ✅ (주)다이나믹디자인(00453488) - 데이터 수집 완료
# ✅ 제이엠티 주식회사(00533508) - 데이터 수집 완료
# ✅ 한일홀딩스 주식회사(00162993) - 데이터 수집 완료
# ✅ 에스와이 주식회사(00535481) - 데이터 수집 완료
# ✅ 삼아알미늄(주)(00126779) - 데이터 수집 완료
# ✅ 한일시멘트 주식회사(01319808) - 데이터 수집 완료
# ✅ (주)인터로조(00604426) - 데이터 수집 완료
# ✅ 주식회사 티라유텍(01309388) - 데이터 수집 완료
# ✅ 쿠쿠홈시스 주식회사(01267684) - 데이터 수집 완료
# ✅ 한솔로지스틱스(주)(00140946) - 데이터 수집 완료
# ✅ (주)카프로(00159810) - 데이터 수집 완료
# ✅ 에스디엔 주식회사(00574611) - 데이터 수집 완료
# ✅ (주)경동도시가스(01208885) - 데이터 수집 완료
# ✅ (주)이크레더블(00634728) - 데이터 수집 완료
# ✅ (주)엘엠에스(00494218) - 데이터 수집 완료
# ✅ (주)퓨처코어(00653103) - 데이터 수집 완료
# ✅ ㈜유니크(00147152) - 데이터 수집 완료
# ✅ 국일신동(00203847) - 데이터 수집 완료
# ✅ 주식회사 바텍(00264255) - 데이터 수집 완료
# ✅ 휴마시스 주식회사(01042979) - 데이터 수집 완료
# ✅ (주)원익큐브(00128175) - 데이터 수집 완료
# ✅ 모나용평(주)(00365989) - 데이터 수집 완료
# ✅ (주)동방(00115287) - 데이터 수집 완료
# ✅ 쿠쿠홀딩스 주식회사(00132354) - 데이터 수집 완료
# ✅ 한솔테크닉스 주식회사(00157399) - 데이터 수집 완료
# ✅ 동양피스톤주식회사(00117726) - 데이터 수집 완료
# ✅ 명문제약 주식회사(00121039) - 데이터 수집 완료
# ✅ 주식회사 덴티움(00526599) - 데이터 수집 완료
# ✅ 윈팩 주식회사(00536286) - 데이터 수집 완료
# ✅ 주식회사 엘디티(00540571) - 데이터 수집 완료
# ✅ 한국기업평가주식회사(00156956) - 데이터 수집 완료
# ✅ 현대사료(주)(00164618) - 데이터 수집 완료
# ✅ 주식회사 씨엔플러스(00660033) - 데이터 수집 완료
# ✅ 주식회사 농심(00108241) - 데이터 수집 완료
# ✅ 나이스디앤비(00606293) - 데이터 수집 완료
# ✅ 주식회사 티에이치엔(00118965) - 데이터 수집 완료
# ✅ 주식회사 까뮤이앤씨(00129420) - 데이터 수집 완료
# ✅ (주)캠시스(00330044) - 데이터 수집 완료
# ✅ 에이치엘디앤아이한라 주식회사(00161116) - 데이터 수집 완료
# ✅ 동일철강 주식회사(00172945) - 데이터 수집 완료
# ✅ 금호건설 주식회사(00106313) - 데이터 수집 완료
# ✅ 테라사이언스 주식회사(00373021) - 데이터 수집 완료
# ✅ 삼화왕관 주식회사(00129235) - 데이터 수집 완료
# ✅ (주)얼라인드제네틱스(01073678) - 데이터 수집 완료
# ✅ 율촌화학(주)(00145260) - 데이터 수집 완료
# ✅ 극동유화(주)(00105156) - 데이터 수집 완료
# ✅ (주)에스티큐브(00273110) - 데이터 수집 완료
# ✅ 삼륭물산(주)(00125488) - 데이터 수집 완료
# ✅ (주)이엘씨(00137289) - 데이터 수집 완료
# ✅ (주)한창제지(00163761) - 데이터 수집 완료
# ✅ (주)케이엑스이노베이션(00657987) - 데이터 수집 완료
# ✅ 퀀타피아 주식회사(00501970) - 데이터 수집 완료
# ✅ (주)인트로메딕(00661157) - 데이터 수집 완료
# ✅ 주식회사 신도기연(00961570) - 데이터 수집 완료
# ✅ (주)중앙에너비스(00149770) - 데이터 수집 완료
# ✅ (주)메디아나(00273439) - 데이터 수집 완료
# ✅ 주식회사 아이윈(00365624) - 데이터 수집 완료
# ✅ 고려아연(주)(00102858) - 데이터 수집 완료
# ✅ 유성기업(주)(00174004) - 데이터 수집 완료
# ✅ (주)삼일씨엔에스(00109806) - 데이터 수집 완료
# ✅ (주)세원물산(00173591) - 데이터 수집 완료
# ✅ 에스퓨얼셀 주식회사(01257872) - 데이터 수집 완료
# ✅ 에프엔에스테크(주)(00476036) - 데이터 수집 완료
# ✅ SK이노베이션(주)(00631518) - 데이터 수집 완료
# ✅ 에코볼트(주)(00562360) - 데이터 수집 완료
# ✅ 코오롱생명과학(주)(00525642) - 데이터 수집 완료
# ✅ (주)케이피티유(00357607) - 데이터 수집 완료
# ✅ (주)에스엘에너지(00957568) - 데이터 수집 완료
# ✅ (주)한울반도체(01359815) - 데이터 수집 완료
# ✅ SK(주)(00181712) - 데이터 수집 완료
# ✅ (주)일월지엠엘(00923826) - 데이터 수집 완료
# ✅ 주식회사 우주일렉트로닉스(00390903) - 데이터 수집 완료
# ✅ 동일제강 주식회사(00118451) - 데이터 수집 완료
# ✅ 주식회사 나이벡(00767628) - 데이터 수집 완료
# ✅ ㈜디딤이앤에프(01068658) - 데이터 수집 완료
# ✅ 주식회사 마크로젠(00261373) - 데이터 수집 완료
# ✅ (주)스킨앤스킨(00896753) - 데이터 수집 완료
# ✅ 주식회사 휴먼테크놀로지(00861997) - 데이터 수집 완료
# ✅ 주식회사 파세코(00238153) - 데이터 수집 완료
# ✅ 주식회사 피엔티 엠에스(01144569) - 데이터 수집 완료
# ✅ 주식회사 레이언스(00899459) - 데이터 수집 완료
# ✅ 주식회사 이루온(00390514) - 데이터 수집 완료
# ✅ (주)파커스(00384762) - 데이터 수집 완료
# ✅ 주식회사 청담글로벌(01534577) - 데이터 수집 완료
# ✅ 아이진 주식회사(00945457) - 데이터 수집 완료
# ✅ 신일제약(주)(00137058) - 데이터 수집 완료
# ✅ 삼일제약(주)(00128032) - 데이터 수집 완료
# ✅ 주식회사 세화피앤씨(01169267) - 데이터 수집 완료
# ✅ 주식회사 뉴파워프라즈마(00521390) - 데이터 수집 완료
# ✅ 주식회사 에이치에스애드(00140168) - 데이터 수집 완료
# ✅ 삼영전자공업주식회사(00127200) - 데이터 수집 완료
# ✅ 주식회사 야스(00875307) - 데이터 수집 완료
# ✅ 한화에어로스페이스주식회사(00126566) - 데이터 수집 완료
# ✅ 주식회사 에쎈테크(00203209) - 데이터 수집 완료
# ✅ 유네코 주식회사(00127699) - 데이터 수집 완료
# ✅ 삼천리(주)(00128555) - 데이터 수집 완료
# ✅ 이삭엔지니어링(주)(01135640) - 데이터 수집 완료
# ✅ 상신이디피 주식회사(00480783) - 데이터 수집 완료
# ✅ 하이즈항공(주)(00688358) - 데이터 수집 완료
# ✅ 국제약품(주)(00104722) - 데이터 수집 완료
# ✅ (주)진바이오텍(00491053) - 데이터 수집 완료
# ✅ 조아제약주식회사(00231831) - 데이터 수집 완료
# ✅ (주)에이치알에스(00230911) - 데이터 수집 완료
# ✅ 주식회사 쎌바이오텍(00357430) - 데이터 수집 완료
# ✅ 주식회사 아스플로(00561732) - 데이터 수집 완료
# ✅ (주) 강스템바이오텍(01025644) - 데이터 수집 완료
# ✅ 주식회사 하이트론씨스템즈(00156150) - 데이터 수집 완료
# ✅ 자이글 주식회사(01020524) - 데이터 수집 완료
# ✅ 주식회사 한국비티비(01031229) - 데이터 수집 완료
# ✅ (주)엔켐(01011526) - 데이터 수집 완료
# ✅ 한국공항 주식회사(00156691) - 데이터 수집 완료
# ✅ (주)메카로(00652007) - 데이터 수집 완료
# ✅ 계양전기(주)(00102618) - 데이터 수집 완료
# ✅ 안트로젠(00631837) - 데이터 수집 완료
# ✅ 대동기어 주식회사(00109310) - 데이터 수집 완료
# ✅ 대창단조주식회사(00112679) - 데이터 수집 완료
# ✅ (주)타이거일렉(00617314) - 데이터 수집 완료
# ✅ 아비코전자 주식회사(00138598) - 데이터 수집 완료
# ✅ (주)심텍홀딩스(00152127) - 데이터 수집 완료
# ✅ 주식회사 이지스레지던스위탁관리부동산투자회사(01436628) - 데이터 수집 완료
# ✅ (주)파멥신(00972293) - 데이터 수집 완료
# ✅ 신흥에스이씨(주)(00807379) - 데이터 수집 완료
# ✅ (주)동국에스엔씨(00415594) - 데이터 수집 완료
# ✅ 주식회사 리더스코스메틱(00180263) - 데이터 수집 완료
# ✅ 주식회사 하이텍팜(00409964) - 데이터 수집 완료
# ✅ (주)에너토크(00169215) - 데이터 수집 완료
# ✅ 주식회사 대원(00111838) - 데이터 수집 완료
# ✅ 디엔에이링크(00642541) - 데이터 수집 완료
# ✅ 주식회사 드래곤플라이(00230036) - 데이터 수집 완료
# ✅ 씨앤티85(주)(00318662) - 데이터 수집 완료
# ✅ 아이크래프트(주)(00405719) - 데이터 수집 완료
# ✅ 주식회사 삼화네트웍스(00301112) - 데이터 수집 완료
# ✅ (주)유티아이(00961774) - 데이터 수집 완료
# ✅ 에이피위성(주)(00874803) - 데이터 수집 완료
# ✅ (주)미래컴퍼니(00447760) - 데이터 수집 완료
# ✅ (주)경동나비엔(00101488) - 데이터 수집 완료
# ✅ 주식회사 테스(00524421) - 데이터 수집 완료
# ✅ 주식회사 서플러스글로벌(00599285) - 데이터 수집 완료
# ✅ 태원물산 주식회사(00154055) - 데이터 수집 완료
# ✅ 인바이오 주식회사(00367871) - 데이터 수집 완료
# ✅ (주)코다코(00295857) - 데이터 수집 완료
# ✅ 이원컴포텍 주식회사(00409140) - 데이터 수집 완료
# ✅ 사조동아원(주)(00137252) - 데이터 수집 완료
# ✅ 제일연마공업(주)(00148461) - 데이터 수집 완료
# ✅ (주)에스에프에이(00358271) - 데이터 수집 완료
# ✅ (주)모아라이프플러스(00587925) - 데이터 수집 완료
# ✅ 주식회사 더테크놀로지(00351454) - 데이터 수집 완료
# ✅ 티피(주)(00154329) - 데이터 수집 완료
# ✅ 엘컴텍 주식회사(00242712) - 데이터 수집 완료
# ✅ 현우산업(주)(00367455) - 데이터 수집 완료
# ✅ 한국정밀기계㈜(00257732) - 데이터 수집 완료
# ✅ 덕우전자(주)(00571298) - 데이터 수집 완료
# ✅ 디와이피엔에프 주식회사(00602136) - 데이터 수집 완료
# ✅ (주)캐스텍코리아(00302582) - 데이터 수집 완료
# ✅ 범양건영주식회사(00122694) - 데이터 수집 완료
# ✅ 파크시스템스 주식회사(00244747) - 데이터 수집 완료
# ✅ 남화토건주식회사(00108001) - 데이터 수집 완료
# ✅ 주식회사 제이스텍(00493185) - 데이터 수집 완료
# ✅ 올릭스 주식회사(01113718) - 데이터 수집 완료
# ✅ 주식회사 에이치시티(00527464) - 데이터 수집 완료
# ✅ 주식회사 파트론(00490151) - 데이터 수집 완료
# ✅ 주식회사 크린앤사이언스(00185222) - 데이터 수집 완료
# ✅ (주)하이로닉(00977641) - 데이터 수집 완료
# ✅ 주식회사 에스티아이(00298340) - 데이터 수집 완료
# ✅ (주)씨에스에이코스믹(00406037) - 데이터 수집 완료
# ✅ (주)글로벌스탠다드테크놀로지(00540863) - 데이터 수집 완료
# ✅ 라온시큐어(주)(00255433) - 데이터 수집 완료
# ✅ 고려제약(주)(00103015) - 데이터 수집 완료
# ✅ (주)비덴트(00693651) - 데이터 수집 완료
# ✅ (주)에스앤더블류(00137012) - 데이터 수집 완료
# ✅ 주식회사 플랜티넷(00490179) - 데이터 수집 완료
# ✅ 주식회사 엑시온그룹(00426068) - 데이터 수집 완료
# ✅ 주식회사 희림종합건축사사무소(00236863) - 데이터 수집 완료
# ✅ (주)삼진엘앤디(00239514) - 데이터 수집 완료
# ✅ 미원화학(00855163) - 데이터 수집 완료
# ✅ 남광토건 주식회사(00107066) - 데이터 수집 완료
# ✅ 주식회사 클리노믹스(01201970) - 데이터 수집 완료
# ✅ (주)대한항공(00113526) - 데이터 수집 완료
# ✅ (주)티비에이치글로벌(00409672) - 데이터 수집 완료
# ✅ 주식회사코리아써키트(00152686) - 데이터 수집 완료
# ✅ 주식회사 인지디스플레이(00265421) - 데이터 수집 완료
# ✅ 주식회사 텔콘알에프제약(00608802) - 데이터 수집 완료
# ✅ (주)사조대림(00109718) - 데이터 수집 완료
# ✅ 비씨엔씨 주식회사(01301623) - 데이터 수집 완료
# ✅ ㈜아이윈플러스(00615723) - 데이터 수집 완료
# ✅ 핸즈코퍼레이션㈜(00119140) - 데이터 수집 완료
# ✅ 한국컴퓨터(주)(00303396) - 데이터 수집 완료
# ✅ 제일일렉트릭 주식회사(00148470) - 데이터 수집 완료
# ✅ (주)비지에프에코머티리얼즈(00599595) - 데이터 수집 완료
# ✅ 에스케이위탁관리부동산투자회사(주)(01535150) - 데이터 수집 완료
# ✅ 주식회사 지앤비에스 에코(00958327) - 데이터 수집 완료
# ✅ 엔젠바이오(01397903) - 데이터 수집 완료
# ✅ 주식회사 신화다이나믹스(00137809) - 데이터 수집 완료
# ✅ (주)수산인더스트리(00193328) - 데이터 수집 완료
# ✅ 주식회사 포바이포(01513699) - 데이터 수집 완료
# ✅ 주식회사 네패스(00227333) - 데이터 수집 완료
# ✅ (주)경농(00101433) - 데이터 수집 완료
# ✅ 주식회사 밸로프(01398151) - 데이터 수집 완료
# ✅ 명신산업(주)(00173078) - 데이터 수집 완료
# ✅ 주식회사 한국종합기술(00159500) - 데이터 수집 완료
# ✅ 엑스큐어 주식회사(00683007) - 데이터 수집 완료
# ✅ 나이스평가정보(주)(00158325) - 데이터 수집 완료
# ✅ KG케미칼(주)(00101220) - 데이터 수집 완료
# ✅ 주식회사 케이지이니시스(00264547) - 데이터 수집 완료
# ✅ (주)엑시콘(00611736) - 데이터 수집 완료
# ✅ 주식회사 녹십자엠에스(00513948) - 데이터 수집 완료
# ✅ 주식회사 녹십자웰빙(01135057) - 데이터 수집 완료
# ✅ 주식회사 커넥트웨이브(00585608) - 데이터 수집 완료
# ✅ 바이온 주식회사(00232089) - 데이터 수집 완료
# ✅ 한화오션 주식회사(00111704) - 데이터 수집 완료
# ✅ (주)케이엔더블유(00606664) - 데이터 수집 완료
# ✅ 태광산업 주식회사(00153393) - 데이터 수집 완료
# ✅ 대한제분주식회사(00113243) - 데이터 수집 완료
# ✅ 경인전자(주)(00102140) - 데이터 수집 완료
# ✅ (주)프럼파스트(00356389) - 데이터 수집 완료
# ✅ 에스케이렌터카(주)(00201450) - 데이터 수집 완료
# ✅ (주)오텍(00397289) - 데이터 수집 완료
# ✅ (주)진도(00557933) - 데이터 수집 완료
# ✅ 한화시스템 주식회사(00339391) - 데이터 수집 완료
# ✅ 주식회사 현대홈쇼핑(00412597) - 데이터 수집 완료
# ✅ 주식회사 현대퓨처넷(00403632) - 데이터 수집 완료
# ✅ 주식회사 케이씨아이(00265041) - 데이터 수집 완료
# ✅ (주)폴라리스세원(00617998) - 데이터 수집 완료
# ✅ (주)와이팜(01015160) - 데이터 수집 완료
# ✅ (주)공구우먼(01307335) - 데이터 수집 완료
# ✅ 주식회사 인콘(00475976) - 데이터 수집 완료
# ✅ 주식회사 엔에이치올원
# 위탁관리부동산투자회사(01480780) - 데이터 수집 완료
# ✅ (주)위지트(00258360) - 데이터 수집 완료
# ✅ 주식회사 와이즈버즈(01236532) - 데이터 수집 완료
# ✅ 피엔케이피부임상연구센타(주)(01290381) - 데이터 수집 완료
# ✅ 주식회사 신한서부티엔디위탁관리부동산투자회사(01436558) - 데이터 수집 완료
# ✅ 씨피시스템 주식회사(01601222) - 데이터 수집 완료
# ✅ (주)아스타(01157235) - 데이터 수집 완료
# ✅ 한국주철관공업(주)(00159573) - 데이터 수집 완료
# ✅ 주식회사 미코(00366942) - 데이터 수집 완료
# ✅ 프레스티지바이오로직스 주식회사(01258428) - 데이터 수집 완료
# ✅ (주)에코프로비엠(01160363) - 데이터 수집 완료
# ✅ (주)구영테크(00202060) - 데이터 수집 완료
# ✅ (주)위메이드맥스(00643656) - 데이터 수집 완료
# ✅ (주)네이블커뮤니케이션즈(00842585) - 데이터 수집 완료
# ✅ 주식회사 다산네트웍스(00268251) - 데이터 수집 완료
# ✅ (주)레이크머티리얼즈(01255652) - 데이터 수집 완료
# ✅ 주식회사 지아이텍(01311310) - 데이터 수집 완료
# ✅ (주)효성(00117188) - 데이터 수집 완료
# ✅ SKC(주)(00139889) - 데이터 수집 완료
# ✅ 주식회사 팜스빌(00986898) - 데이터 수집 완료
# ✅ 위즈코프주식회사(00264228) - 데이터 수집 완료
# ✅ 주식회사 오리엔트정공(00300405) - 데이터 수집 완료
# ✅ 주식회사 신도리코(00135795) - 데이터 수집 완료
# ✅ 평화홀딩스주식회사(00155124) - 데이터 수집 완료
# ✅ 에이치디한국조선해양 주식회사(00164830) - 데이터 수집 완료
# ✅ 주식회사 디케이앤디(00892526) - 데이터 수집 완료
# ✅ CJ주식회사(00148540) - 데이터 수집 완료
# ✅ 주식회사 엔에프씨(01217829) - 데이터 수집 완료
# ✅ (주)티제이미디어(00201733) - 데이터 수집 완료
# ✅ (주)바이오스마트(00240857) - 데이터 수집 완료
# ✅ (주)화승코퍼레이션(00166272) - 데이터 수집 완료
# ✅ 주식회사 박셀바이오(01335851) - 데이터 수집 완료
# ✅ 주식회사 엔피케이(00108490) - 데이터 수집 완료
# ✅ (주)넵튠(01067808) - 데이터 수집 완료
# ✅ 애경산업 주식회사(00139454) - 데이터 수집 완료
# ✅ 주식회사 제주항공(00555874) - 데이터 수집 완료
# ✅ 유니셈주식회사(00260569) - 데이터 수집 완료
# ✅ 주식회사 아이퀘스트(01146822) - 데이터 수집 완료
# ✅ (주)형지아이앤씨(00142713) - 데이터 수집 완료
# ✅ 써니전자(주)(00138057) - 데이터 수집 완료
# ✅ (주)시공테크(00170026) - 데이터 수집 완료
# ✅ (주)에스디생명공학(01099667) - 데이터 수집 완료
# ✅ (주)자연과환경(00418379) - 데이터 수집 완료
# ✅ 에이디엠코리아(주)(01409022) - 데이터 수집 완료
# ✅ 한국전자인증(주)(00361169) - 데이터 수집 완료
# ✅ 주식회사 퓨쳐켐(01053540) - 데이터 수집 완료
# ✅ 엣지파운드리 주식회사(00766106) - 데이터 수집 완료
# ✅ 주식회사 알로이스(01309795) - 데이터 수집 완료
# ✅ 주식회사 토박스코리아(01064069) - 데이터 수집 완료
# ✅ 더블유씨피 주식회사(01291317) - 데이터 수집 완료
# ✅ HD현대중공업 주식회사(01390344) - 데이터 수집 완료
# ✅ 나무기술 주식회사(01136348) - 데이터 수집 완료
# ✅ 주식회사 하나투어(00269940) - 데이터 수집 완료
# ✅ (주)아나패스(00761952) - 데이터 수집 완료
# ✅ (주)오디텍(00529815) - 데이터 수집 완료
# ✅ 이화산업 주식회사(00145686) - 데이터 수집 완료
# ✅ (주)그린플러스(00602279) - 데이터 수집 완료
# ✅ 주식회사 픽셀플러스(00495086) - 데이터 수집 완료
# ✅ 주식회사 오파스넷(00867849) - 데이터 수집 완료
# ✅ 주식회사 아이패밀리에스씨(00692254) - 데이터 수집 완료
# ✅ 주식회사 브랜드엑스코퍼레이션(01391103) - 데이터 수집 완료
# ✅ (주)제이에스티나(00120289) - 데이터 수집 완료
# ✅ 알에스오토메이션 주식회사(00858124) - 데이터 수집 완료
# ✅ 주식회사 디어유(01456011) - 데이터 수집 완료
# ✅ 주식회사 케스피온(00479705) - 데이터 수집 완료
# ✅ (주)경동인베스트(00143527) - 데이터 수집 완료
# ✅ (주)나래나노텍(00362122) - 데이터 수집 완료
# ✅ 주식회사 에스아이리소스(00120906) - 데이터 수집 완료
# ✅ 주식회사 마이크로디지탈(01267967) - 데이터 수집 완료
# ✅ 주식회사 엘앤씨바이오(01181515) - 데이터 수집 완료
# ✅ 주식회사 센코(01023318) - 데이터 수집 완료
# ✅ (주)신세계인터내셔날(00234412) - 데이터 수집 완료
# ✅ 이노뎁(주)(01264872) - 데이터 수집 완료
# ✅ 주식회사 필옵틱스(00938721) - 데이터 수집 완료
# ✅ 주식회사 핸디소프트(00793155) - 데이터 수집 완료
# ✅ (주)크레버스(00525882) - 데이터 수집 완료
# ✅ 주식회사 대유플러스(00126089) - 데이터 수집 완료
# ✅ (주)한진(00163512) - 데이터 수집 완료
# ✅ 주식회사 티와이엠(00117230) - 데이터 수집 완료
# ✅ (주)티엔엔터테인먼트(00814786) - 데이터 수집 완료
# ✅ ㈜오픈베이스(00335076) - 데이터 수집 완료
# ✅ 효성화학㈜(01316236) - 데이터 수집 완료
# ✅ 자이에스앤디 주식회사(00367844) - 데이터 수집 완료
# ✅ (주)이지바이오(01480568) - 데이터 수집 완료
# ✅ (주)프로텍(00325112) - 데이터 수집 완료
# ✅ 남양유업주식회사(00107598) - 데이터 수집 완료
# ✅ (주)에이블씨엔씨(00400857) - 데이터 수집 완료
# ✅ (주)우진(00173944) - 데이터 수집 완료
# ✅ 주식회사 종근당바이오(00390055) - 데이터 수집 완료
# ✅ (주)콘텐트리중앙(00203315) - 데이터 수집 완료
# ✅ 앱클론 주식회사(00991191) - 데이터 수집 완료
# ✅ 원텍(주)(01407909) - 데이터 수집 완료
# ✅ (주)모코엠시스(01407158) - 데이터 수집 완료
# ✅ 주식회사 엔피(01276901) - 데이터 수집 완료
# ✅ 엠에프엠코리아 주식회사(01384477) - 데이터 수집 완료
# ✅ (주)제주반도체(00447487) - 데이터 수집 완료
# ✅ 주식회사 서원(00131197) - 데이터 수집 완료
# ✅ 주식회사 위지윅스튜디오(01276327) - 데이터 수집 완료
# ✅ 넥센타이어(주)(00173874) - 데이터 수집 완료
# ✅ (주)엘지에너지솔루션(01515323) - 데이터 수집 완료
# ✅ 롯데위탁관리부동산투자회사 주식회사(01363818) - 데이터 수집 완료
# ✅ 주식회사 티씨케이(00245472) - 데이터 수집 완료
# ✅ 주식회사 이노룰스(01341630) - 데이터 수집 완료
# ✅ 대덕전자 주식회사(01478712) - 데이터 수집 완료
# ✅ 주식회사 드림시큐리티(01038693) - 데이터 수집 완료
# ✅ 에스지씨이앤씨 주식회사(00141246) - 데이터 수집 완료
# ✅ 주식회사 에스비에스(00130772) - 데이터 수집 완료
# ✅ AJ네트웍스(주)(00365387) - 데이터 수집 완료
# ✅ CJ제일제당(주)(00635134) - 데이터 수집 완료
# ✅ 씨제이대한통운(주)(00113410) - 데이터 수집 완료
# ✅ 주식회사 엘엑스홀딩스(01562589) - 데이터 수집 완료
# ✅ 인지소프트(00641171) - 데이터 수집 완료
# ✅ 주식회사 블레이드엔터테인먼트(00173449) - 데이터 수집 완료
# ✅ 주식회사 에스제이엠홀딩스(00181943) - 데이터 수집 완료
# ✅ 남화산업(주)(00245694) - 데이터 수집 완료
# ✅ 애경케미칼(주)(00936787) - 데이터 수집 완료
# ✅ (주)이리츠코크렙기업구조조정부동산투자회사(00544452) - 데이터 수집 완료
# ✅ 주식회사 제이알글로벌위탁관리부동산투자회사(01415892) - 데이터 수집 완료
# ✅ 삼성전자(주)(00126380) - 데이터 수집 완료
# ✅ 효성티앤씨 주식회사(01316227) - 데이터 수집 완료
# ✅ 주식회사 케이피에프(00157636) - 데이터 수집 완료
# ✅ 주식회사 대덕(00109189) - 데이터 수집 완료
# ✅ 주식회사 와이솔(00759294) - 데이터 수집 완료
# ✅ 효성첨단소재(주)(01316254) - 데이터 수집 완료
# ✅ 케이지모빌리티(주)(00138242) - 데이터 수집 완료
# ✅ 메가엠디 주식회사(00807555) - 데이터 수집 완료
# ✅ (주)F&F(01568413) - 데이터 수집 완료
# ✅ 롯데렌탈 주식회사(00545716) - 데이터 수집 완료
# ✅ 케이엔솔주식회사(00304076) - 데이터 수집 완료
# ✅ 성호전자 주식회사(00317210) - 데이터 수집 완료
# ✅ 코오롱인더스트리 주식회사(00795135) - 데이터 수집 완료
# ✅ (주)태광(00153375) - 데이터 수집 완료
# ✅ (주)에이치와이티씨(00885906) - 데이터 수집 완료
# ✅ 주식회사 에이피에스(00296078) - 데이터 수집 완료
# ✅ 주식회사 삼양사(00896285) - 데이터 수집 완료
# ✅ 주식회사 선앤엘(00132211) - 데이터 수집 완료
# ✅ 주식회사 빅솔론(00478900) - 데이터 수집 완료
# ✅ 주식회사 디아이(00118275) - 데이터 수집 완료
# ✅ 소니드 주식회사(00363510) - 데이터 수집 완료
# ✅ 주식회사 웅진(00143651) - 데이터 수집 완료
# ✅ 삼영무역(주)(00127167) - 데이터 수집 완료
# ✅ 제이더블유중외제약(00149947) - 데이터 수집 완료
# ✅ 주성엔지니어링(주)(00252135) - 데이터 수집 완료
# ✅ (주)엠아이텍(00531829) - 데이터 수집 완료
# ✅ (주)포스코디엑스(00155212) - 데이터 수집 완료
# ✅ (주)바른손이앤에이(00259590) - 데이터 수집 완료
# ✅ 주식회사 케이프(00152437) - 데이터 수집 완료
# ✅ 데이터 저장 완료: 기업_재무제표_2023년_L2.xlsx, 기업_재무제표_2023년_L2.xlsx

# %% [markdown]
# #
# :------------------------------------------------------------------------------L3------------------------------------

# %%
import requests
import pandas as pd
import time

# DART API 인증키 (본인의 API 키 입력)
API_KEY = '85006d20472a255d5eae25ee265b5ed1b78d1386'

# DART 재무제표 API URL
FS_URL = "https://opendart.fss.or.kr/api/fnlttSinglAcntAll.json"

# 기업 리스트 엑셀 파일 읽기
file_path = "./corp_list_split.xlsx"  # 로컬 파일 경로
corporations_df = pd.read_excel(file_path, sheet_name="L3", dtype={'code': str})

# 데이터 저장을 위한 리스트
financial_data = []

# 자본변동표 관련 계정과목 필터링 리스트
exclude_accounts = [
    "자본금 변동", "기타포괄손익누계액", "이익잉여금 변동",
    "자본총계 변동", "기타자본항목 변동", "배당금 지급", "주식발행", "자본조정"
]

# 자본 관련 항목 리스트 (우선 재무상태표 항목을 우선하고, 없는 경우 첫 번째로 나온 항목 선택)
capital_related_accounts = ["자본총계", "기초자본", "자본금", "이익잉여금", "기타자본항목"]

# 기업별 재무제표 요청
for _, row in corporations_df.iterrows():
    corp_code = row['code']  # 기업 코드
    corp_name = row.get('name', '알 수 없음')  # 기업 이름

    params = {
        'crtfc_key': API_KEY,
        'corp_code': corp_code,
        'bsns_year': 2023,  # 연도
        'reprt_code': '11011',  # 사업보고서 (연결 재무제표)
        'fs_div': 'OFS'  # 개별 재무제표 (자본변동표 포함 X)
    }

    try:
        # API 요청
        response = requests.get(FS_URL, params=params, timeout=10)
        response.raise_for_status()
        data = response.json()

        if data.get('status') == '000':  # 정상 응답
            if 'list' in data and data['list']:
                unique_accounts = set()  # 중복 방지를 위한 set
                first_appearance_accounts = []  # 첫 번째로 나온 항목을 저장할 리스트

                for item in data['list']:
                    account_name = item['account_nm'].strip()
                    account_id = item.get('account_id', '데이터 없음')  # account_id 추가

                    # 자본변동표 관련 항목 제외
                    if any(excl in account_name for excl in exclude_accounts):
                        continue

                    # 자본 관련 계정 처리: 재무상태표에 있는 항목을 우선하고, 없으면 첫 번째 항목 사용
                    if any(account_name.startswith(capital_account) for capital_account in capital_related_accounts):
                        # 재무상태표에 있는 자본 항목을 우선 처리
                        if account_name not in unique_accounts:
                            unique_accounts.add(account_name)
                            financial_data.append({
                                "기업 이름": corp_name,
                                "기업 코드": corp_code,
                                "연도": 2023,
                                "계정과목명": account_name,
                                "account_id": account_id,  # account_id 추가
                                "금액": item.get('thstrm_amount', '데이터 없음'),  # 2023년 금액
                                "2022년 금액": item.get('frmtrm_amount', '데이터 없음'),  # 2022년 금액
                                "2021년 금액": item.get('lfy_amount', '데이터 없음')  # 2021년 금액
                            })
                    else:
                        # 첫 번째로 나온 자본 관련 항목을 선택하여 추가
                        if account_name not in first_appearance_accounts:
                            first_appearance_accounts.append(account_name)
                            financial_data.append({
                                "기업 이름": corp_name,
                                "기업 코드": corp_code,
                                "연도": 2023,
                                "계정과목명": account_name,
                                "account_id": account_id,  # account_id 추가
                                "금액": item.get('thstrm_amount', '데이터 없음'),  # 2023년 금액
                                "2022년 금액": item.get('frmtrm_amount', '데이터 없음'),  # 2022년 금액
                                "2021년 금액": item.get('lfy_amount', '데이터 없음')  # 2021년 금액
                            })

                print(f"✅ {corp_name}({corp_code}) - 데이터 수집 완료")
            else:
                print(f"⚠️ {corp_name}({corp_code}) - 재무 데이터 없음")
        else:
            print(f"❌ {corp_name}({corp_code}) - API 오류: {data.get('message', '알 수 없는 오류')}")

    except requests.exceptions.RequestException as e:
        print(f"🚨 {corp_name}({corp_code}) - 요청 실패: {e}")

    time.sleep(1)  # API 요청 간격 조정

# DataFrame 변환
df_3 = pd.DataFrame(financial_data)

# 결과 저장
output_excel = "기업_재무제표_2023년_L3.xlsx"

df_3.to_excel(output_excel, index=False)

print(f"✅ 데이터 저장 완료: {output_excel}, {output_excel}")
# Out:
# ✅ 포스코스틸리온(주)(00155258) - 데이터 수집 완료
# ✅ 비플라이소프트(주)(00980043) - 데이터 수집 완료
# ✅ 씨유테크주식회사(00575106) - 데이터 수집 완료
# ✅ 송원산업 주식회사(00134963) - 데이터 수집 완료
# ✅ KG스틸 주식회사(00115676) - 데이터 수집 완료
# ✅ (주)씨티프라퍼티(00349811) - 데이터 수집 완료
# ✅ 주식회사 셀바스헬스케어(01047451) - 데이터 수집 완료
# ✅ 주식회사 셀바스에이아이(00666064) - 데이터 수집 완료
# ✅ 주식회사 디지피(00367695) - 데이터 수집 완료
# ✅ 주식회사 앱코(01207716) - 데이터 수집 완료
# ✅ 주식회사 툴젠(00547510) - 데이터 수집 완료
# ❌ 주식회사 디에스앤엘(00812362) - API 오류: 조회된 데이타가 없습니다.
# ✅ 주식회사 디에스케이(00530121) - 데이터 수집 완료
# ✅ 메가스터디 주식회사(00422284) - 데이터 수집 완료
# ✅ 코닉오토메이션(주)(01573284) - 데이터 수집 완료
# ✅ 주식회사 알비더블유(01303029) - 데이터 수집 완료
# ✅ 한국내화주식회사(00160205) - 데이터 수집 완료
# ✅ 주식회사 한네트(00244783) - 데이터 수집 완료
# ✅ 주식회사 씨아이테크(00127158) - 데이터 수집 완료
# ✅ 풍원정밀(주)(00417167) - 데이터 수집 완료
# ✅ (주)골프존뉴딘홀딩스(00674498) - 데이터 수집 완료
# ✅ (주)태웅로직스(00562245) - 데이터 수집 완료
# ✅ (주)한송네오텍(01101722) - 데이터 수집 완료
# ✅ (주)모토닉(00151128) - 데이터 수집 완료
# ✅ (주)마이크로컨텍솔루션(00568188) - 데이터 수집 완료
# ✅ (주)에스피시스템스(00624749) - 데이터 수집 완료
# ✅ 주식회사 엘앤케이바이오메드(00918222) - 데이터 수집 완료
# ✅ 주식회사 뷰노(01344202) - 데이터 수집 완료
# ✅ 금강철강 주식회사(00105475) - 데이터 수집 완료
# ✅ 주식회사 삼일기업공사(00127936) - 데이터 수집 완료
# ✅ (주)케이씨피드(00101752) - 데이터 수집 완료
# ✅ 한국수출포장공업(주)(00158112) - 데이터 수집 완료
# ✅ (주)코텍(00305297) - 데이터 수집 완료
# ✅ (주)이노인스트루먼트(01065679) - 데이터 수집 완료
# ✅ 아주스틸 주식회사(00486705) - 데이터 수집 완료
# ✅ 주식회사 엔바이오니아(00964595) - 데이터 수집 완료
# ✅ 줌인터넷(주)(01128622) - 데이터 수집 완료
# ✅ (주)아이스크림에듀(00983934) - 데이터 수집 완료
# ✅ 주식회사 솔고바이오메디칼(00220109) - 데이터 수집 완료
# ✅ 주식회사 디엠에스(00361594) - 데이터 수집 완료
# ✅ (주)부-스타(00124276) - 데이터 수집 완료
# ✅ 와이씨켐 주식회사(00619507) - 데이터 수집 완료
# ✅ 주식회사 특수건설(00186939) - 데이터 수집 완료
# ✅ 유진기업(주)(00184667) - 데이터 수집 완료
# ✅ (주)대명소노시즌(00104810) - 데이터 수집 완료
# ✅ 주식회사 지엔씨에너지(00626464) - 데이터 수집 완료
# ✅ (주)아모그린텍(00611912) - 데이터 수집 완료
# ✅ 삼익THK 주식회사(00127802) - 데이터 수집 완료
# ✅ (주)미래아이앤지(00104786) - 데이터 수집 완료
# ✅ 주식회사 시너지이노베이션(00475985) - 데이터 수집 완료
# ✅ (주)세진티에스(00406727) - 데이터 수집 완료
# ✅ 제로투세븐(00563837) - 데이터 수집 완료
# ✅ 주식회사라이콤(01569102) - 데이터 수집 완료
# ✅ (주)인성정보(00229021) - 데이터 수집 완료
# ✅ 주식회사 에스에이티(01440153) - 데이터 수집 완료
# ✅ 아이오케이컴퍼니(00543204) - 데이터 수집 완료
# ✅ 보해양조 주식회사(00123541) - 데이터 수집 완료
# ✅ (주)티비씨(00204642) - 데이터 수집 완료
# ✅ 주식회사 케이피엠테크(00206686) - 데이터 수집 완료
# ✅ SGC에너지(주)(00125150) - 데이터 수집 완료
# ✅ 에스지에이(주)(00351579) - 데이터 수집 완료
# ✅ 오토앤 주식회사(01084294) - 데이터 수집 완료
# ✅ 대우전자부품(주)(00111689) - 데이터 수집 완료
# ✅ (주)케이엔엔(00208134) - 데이터 수집 완료
# ✅ 퍼스텍주식회사(00148522) - 데이터 수집 완료
# ✅ (주)대구백화점(00108977) - 데이터 수집 완료
# ✅ 주식회사 미디어젠(01190124) - 데이터 수집 완료
# ✅ (주)케어젠(00549891) - 데이터 수집 완료
# ✅ (주)스타플렉스(00405959) - 데이터 수집 완료
# ✅ 주식회사 일신바이오베이스(00385415) - 데이터 수집 완료
# ✅ 주식회사 휴네시온(01251577) - 데이터 수집 완료
# ✅ 선진뷰티사이언스(주)(00132202) - 데이터 수집 완료
# ✅ (주)원익피앤이(01020843) - 데이터 수집 완료
# ✅ 주식회사 프롬바이오(01217865) - 데이터 수집 완료
# ✅ (주)자이언트스텝(01264438) - 데이터 수집 완료
# ✅ (주)본느(01098792) - 데이터 수집 완료
# ✅ (주)파인텍(00820352) - 데이터 수집 완료
# ✅ 위더스제약(주)(00765851) - 데이터 수집 완료
# ✅ (주)대륙제관(00109587) - 데이터 수집 완료
# ✅ 대주전자제료(주)(00177816) - 데이터 수집 완료
# ✅ (주)티와이홀딩스(01497869) - 데이터 수집 완료
# ✅ 주식회사 나인테크(01208849) - 데이터 수집 완료
# ✅ 나노씨엠에스(주)(00660459) - 데이터 수집 완료
# ✅ 주식회사 리노스(00369213) - 데이터 수집 완료
# ✅ 주식회사 포메탈(00188797) - 데이터 수집 완료
# ✅ 주식회사 에스에프에이반도체(00301246) - 데이터 수집 완료
# ✅ 주식회사 나노브릭(01136001) - 데이터 수집 완료
# ✅ 주식회사 에이플러스에셋어드바이저(00684802) - 데이터 수집 완료
# ✅ 주식회사 샘씨엔에스(01199727) - 데이터 수집 완료
# ✅ 주식회사 대유에이텍(00149804) - 데이터 수집 완료
# ✅ (주)아이에스시(00572905) - 데이터 수집 완료
# ✅ 안국약품 주식회사(00139205) - 데이터 수집 완료
# ✅ (주)코렌텍(00541437) - 데이터 수집 완료
# ✅ 유니온머티리얼(주)(00369833) - 데이터 수집 완료
# ✅ 주식회사 일신석재(00146296) - 데이터 수집 완료
# ✅ 삼보모터스 주식회사(00351092) - 데이터 수집 완료
# ✅ 주식회사 옵티팜(00971726) - 데이터 수집 완료
# ✅ 케이바이아메탈주식회사(00158024) - 데이터 수집 완료
# ✅ (주)케이에스에스해운(00160232) - 데이터 수집 완료
# ✅ 동신건설 주식회사(00116408) - 데이터 수집 완료
# ✅ (주)에이스토리(00975290) - 데이터 수집 완료
# ✅ 에이비엘바이오 주식회사(01256864) - 데이터 수집 완료
# ✅ 주식회사 엠투아이코퍼레이션(00670766) - 데이터 수집 완료
# ✅ (주)드림텍(00415646) - 데이터 수집 완료
# ✅ 진원생명과학(주)(00118521) - 데이터 수집 완료
# ✅ 주식회사 화승알앤에이(01532603) - 데이터 수집 완료
# ✅ (주)유틸렉스(01110678) - 데이터 수집 완료
# ✅ (주)젬백스링크(00392691) - 데이터 수집 완료
# ✅ 주식회사 프로이천(01359736) - 데이터 수집 완료
# ✅ 주식회사 원준(01459212) - 데이터 수집 완료
# ✅ (주)아즈텍더블유비이(00201131) - 데이터 수집 완료
# ✅ 주식회사 힘스(00556712) - 데이터 수집 완료
# ✅ 주식회사 파라텍(00105138) - 데이터 수집 완료
# ✅ (주)정원엔시스(00147772) - 데이터 수집 완료
# ✅ 쌍용정보통신 주식회사(00138303) - 데이터 수집 완료
# ✅ (주)리메드(01275665) - 데이터 수집 완료
# ✅ 코웰패션 주식회사(00155948) - 데이터 수집 완료
# ✅ 주식회사 유수홀딩스(00163691) - 데이터 수집 완료
# ✅ 코스맥스비티아이주식회사(00219574) - 데이터 수집 완료
# ✅ 주식회사 에이루트(00608839) - 데이터 수집 완료
# ✅ 하이록코리아(주)(00165060) - 데이터 수집 완료
# ✅ 주식회사 인산가(01243161) - 데이터 수집 완료
# ✅ 성창기업지주(주)(00133335) - 데이터 수집 완료
# ✅ 주식회사 새빗켐(00862880) - 데이터 수집 완료
# ✅ (주)아셈스(00922304) - 데이터 수집 완료
# ✅ 모델솔루션(주)(00657783) - 데이터 수집 완료
# ✅ (주)티엘비(00920379) - 데이터 수집 완료
# ✅ (주)와이더플래닛(01116502) - 데이터 수집 완료
# ✅ 주식회사 코난테크놀로지(00601988) - 데이터 수집 완료
# ✅ 주식회사 이스타코(00134565) - 데이터 수집 완료
# ✅ 주식회사 와이엠텍(01215618) - 데이터 수집 완료
# ✅ 에스케이케미칼 주식회사(01267170) - 데이터 수집 완료
# ✅ 주식회사디아이씨(00112165) - 데이터 수집 완료
# ✅ (주)러셀(01068348) - 데이터 수집 완료
# ✅ 주식회사 피엔풍년(00133557) - 데이터 수집 완료
# ✅ 동화약품(주)(00119195) - 데이터 수집 완료
# ✅ 제너셈 주식회사(00666204) - 데이터 수집 완료
# ✅ 주식회사 국전약품(01329957) - 데이터 수집 완료
# ✅ 두산퓨얼셀 주식회사(01412725) - 데이터 수집 완료
# ✅ 주식회사 알체라(01405451) - 데이터 수집 완료
# ✅ 주식회사 퀀타매트릭스(01311286) - 데이터 수집 완료
# ✅ 주식회사 비케이홀딩스(00369569) - 데이터 수집 완료
# ✅ 인텍플러스(00479787) - 데이터 수집 완료
# ✅ (주)아난티(00161781) - 데이터 수집 완료
# ✅ (주)성창오토텍(00486370) - 데이터 수집 완료
# ✅ 주식회사 유니온(00144252) - 데이터 수집 완료
# ✅ 우리산업홀딩스(주)(00359623) - 데이터 수집 완료
# ✅ 코스맥스주식회사(01009789) - 데이터 수집 완료
# ✅ 경창산업(주)(00102353) - 데이터 수집 완료
# ✅ 에스트래픽주식회사(01014055) - 데이터 수집 완료
# ✅ 브릿지바이오테라퓨틱스 주식회사(01227039) - 데이터 수집 완료
# ✅ (주)이수화학(00145552) - 데이터 수집 완료
# ✅ (주)율호(00583026) - 데이터 수집 완료
# ✅ (주)세경하이테크(00913689) - 데이터 수집 완료
# ✅ (주)아이디스홀딩스(00359580) - 데이터 수집 완료
# ✅ 아이디피주식회사(01213586) - 데이터 수집 완료
# ✅ 주식회사 스코넥엔터테인먼트(01290248) - 데이터 수집 완료
# ✅ (주)케이씨(00209780) - 데이터 수집 완료
# ✅ (주)엔아이스틸(00116301) - 데이터 수집 완료
# ✅ 주식회사 큐로컴(00346407) - 데이터 수집 완료
# ✅ 주식회사 캐리소프트(01267222) - 데이터 수집 완료
# ✅ 한국제지(주)(00133706) - 데이터 수집 완료
# ✅ 베뉴지(주)(00267906) - 데이터 수집 완료
# ✅ (주)서희건설(00219848) - 데이터 수집 완료
# ✅ 주식회사 씨엔알리서치(01487446) - 데이터 수집 완료
# ✅ 주식회사 스맥(00580056) - 데이터 수집 완료
# ✅ (주)시노펙스(00203023) - 데이터 수집 완료
# ✅ 주식회사 바이브컴퍼니(00403793) - 데이터 수집 완료
# ✅ 피에스케이 주식회사(01365825) - 데이터 수집 완료
# ✅ 조일알미늄 주식회사(00149239) - 데이터 수집 완료
# ✅ 주식회사 세운메디칼(00362201) - 데이터 수집 완료
# ✅ 주식회사 하나기술(00601191) - 데이터 수집 완료
# ✅ 대원전선 주식회사(00260392) - 데이터 수집 완료
# ✅ 성우전자 주식회사(00364306) - 데이터 수집 완료
# ✅ 주식회사 원익(00210980) - 데이터 수집 완료
# ✅ 주식회사 삼보판지(00125938) - 데이터 수집 완료
# ✅ 주식회사 에이프로(00604268) - 데이터 수집 완료
# ✅ 디젠스(주)(00576789) - 데이터 수집 완료
# ✅ 삼현철강 주식회사(00128926) - 데이터 수집 완료
# ✅ 주식회사 이오테크닉스(00246417) - 데이터 수집 완료
# ✅ 주식회사 영흥(00141477) - 데이터 수집 완료
# ✅ 지니너스 주식회사(01494154) - 데이터 수집 완료
# ✅ (주)케이씨씨건설(00105466) - 데이터 수집 완료
# ✅ 한신공영(주)(00162063) - 데이터 수집 완료
# ✅ 동성제약 주식회사(00116268) - 데이터 수집 완료
# ✅ (주)피델릭스(00189538) - 데이터 수집 완료
# ✅ 주식회사 휴니드테크놀러지스(00111421) - 데이터 수집 완료
# ✅ 주식회사 프리엠스(00352064) - 데이터 수집 완료
# ✅ 솔트웨어(주)(구,미래에셋대우기업인수목적3호(주))(01390399) - 데이터 수집 완료
# ✅ (주)황금에스티(00218575) - 데이터 수집 완료
# ✅ 레이저쎌 주식회사(01573381) - 데이터 수집 완료
# ✅ (주)아우딘퓨쳐스(01080687) - 데이터 수집 완료
# ✅ 오성첨단소재(주)(00350048) - 데이터 수집 완료
# ✅ 주식회사 갤럭시아에스엠(00129554) - 데이터 수집 완료
# ✅ 주식회사 진시스템(01437858) - 데이터 수집 완료
# ✅ 주식회사 서남(00867973) - 데이터 수집 완료
# ✅ 주식회사 셀레믹스(01114586) - 데이터 수집 완료
# ✅ 주식회사 누리플렉스(00269889) - 데이터 수집 완료
# ✅ 주식회사 플리토(01237434) - 데이터 수집 완료
# ✅ 에스케이오션플랜트(주)(00480367) - 데이터 수집 완료
# ✅ 주식회사 서연이화(01036446) - 데이터 수집 완료
# ✅ 범한퓨얼셀 주식회사(01435489) - 데이터 수집 완료
# ✅ 주식회사 덕산테코피아(01021666) - 데이터 수집 완료
# ✅ 주식회사 쿠콘(01311055) - 데이터 수집 완료
# ✅ 웹케시 주식회사(00323868) - 데이터 수집 완료
# ✅ 동양이엔피(주)(00178790) - 데이터 수집 완료
# ✅ 주식회사 포인트엔지니어링(01179608) - 데이터 수집 완료
# ✅ 유비벨록스 주식회사(00592653) - 데이터 수집 완료
# ✅ 주식회사 동양(00117337) - 데이터 수집 완료
# ✅ 주식회사 알피바이오(01182259) - 데이터 수집 완료
# ✅ 엘비세미콘㈜(00412348) - 데이터 수집 완료
# ✅ 주식회사 동진쎄미켐(00118804) - 데이터 수집 완료
# ✅ KR모터스(주)(00112378) - 데이터 수집 완료
# ✅ 대한제당 주식회사(00113234) - 데이터 수집 완료
# ✅ 주식회사 종근당홀딩스(00149354) - 데이터 수집 완료
# ✅ 주식회사 위닉스(00293886) - 데이터 수집 완료
# ✅ 무림에스피주식회사(00121507) - 데이터 수집 완료
# ✅ (주)한컴위드(00363592) - 데이터 수집 완료
# ✅ 주식회사 나노신소재(00439965) - 데이터 수집 완료
# ✅ 솔브레인홀딩스(주)(00247975) - 데이터 수집 완료
# ✅ 주식회사 케이씨에스(00441650) - 데이터 수집 완료
# ✅ 솔브레인 주식회사(01489648) - 데이터 수집 완료
# ✅ 주식회사 LS네트웍스(00104698) - 데이터 수집 완료
# ✅ (주)케이엔제이(00769158) - 데이터 수집 완료
# ✅ 주식회사 라파스(01058101) - 데이터 수집 완료
# ✅ (주)인바디(00269922) - 데이터 수집 완료
# ✅ 주식회사 핑거(01142075) - 데이터 수집 완료
# ✅ 삼성공조(주)(00126201) - 데이터 수집 완료
# ✅ 에코바이오홀딩스 주식회사(00287812) - 데이터 수집 완료
# ✅ 주식회사 콤텍시스템(00186559) - 데이터 수집 완료
# ✅ 코스모신소재 주식회사(00129989) - 데이터 수집 완료
# ✅ 코스모화학 주식회사(00160302) - 데이터 수집 완료
# ✅ 한국석유공업 주식회사(00157991) - 데이터 수집 완료
# ✅ 주식회사 크리스에프앤씨(00522007) - 데이터 수집 완료
# ✅ 주식회사 베노티앤알(01043853) - 데이터 수집 완료
# ✅ 삼화콘덴서공업(00129350) - 데이터 수집 완료
# ✅ 주식회사 바이오솔루션(00560982) - 데이터 수집 완료
# ✅ 진양제약(주)(00150536) - 데이터 수집 완료
# ✅ 동국제약(주)(00114808) - 데이터 수집 완료
# ✅ 주식회사 에이프로젠헬스케어앤게임즈(00653194) - 데이터 수집 완료
# ✅ 대모엔지니어링 주식회사(00450995) - 데이터 수집 완료
# ✅ 리파인(01210066) - 데이터 수집 완료
# ✅ 케이지이티에스㈜(00366137) - 데이터 수집 완료
# ✅ 주식회사 티피씨(00578538) - 데이터 수집 완료
# ✅ 주식회사 이노메트리(01258710) - 데이터 수집 완료
# ✅ 풍국주정공업 주식회사(00155452) - 데이터 수집 완료
# ✅ 흥아해운(주)(00167208) - 데이터 수집 완료
# ✅ 주식회사 녹십자(00129679) - 데이터 수집 완료
# ✅ 주식회사 엔시스(01310773) - 데이터 수집 완료
# ✅ 주식회사 피코그램(00604028) - 데이터 수집 완료
# ✅ 주식회사 케이비지(00876166) - 데이터 수집 완료
# ✅ 주식회사 팜스토리(00192499) - 데이터 수집 완료
# ✅ 인베니아(주)(00409371) - 데이터 수집 완료
# ✅ (주)플레이위드코리아(00138367) - 데이터 수집 완료
# ✅ 삼천리자전거 주식회사(00128607) - 데이터 수집 완료
# ✅ 와이엠티 주식회사(00602172) - 데이터 수집 완료
# ✅ (주)동양에스텍(00178851) - 데이터 수집 완료
# ✅ 지투파워 주식회사(01462605) - 데이터 수집 완료
# ✅ 주식회사 빙그레(00124726) - 데이터 수집 완료
# ✅ 교촌에프앤비 주식회사(00453284) - 데이터 수집 완료
# ✅ 주식회사 애니플러스(01335578) - 데이터 수집 완료
# ✅ 주식회사 아이엠비씨(00370006) - 데이터 수집 완료
# ✅ 롯데에너지머티리얼리즈 주식회사(00113997) - 데이터 수집 완료
# ✅ 주식회사 유비케어(00220057) - 데이터 수집 완료
# ✅ 주식회사 해성티피씨(00453442) - 데이터 수집 완료
# ✅ (주)한국팩키지(00198192) - 데이터 수집 완료
# ✅ 해성산업 주식회사(00219361) - 데이터 수집 완료
# ✅ (주)에이프로젠바이오로직스(00101044) - 데이터 수집 완료
# ✅ DSR 주식회사(00110608) - 데이터 수집 완료
# ✅ (주)우진플라임(00303217) - 데이터 수집 완료
# ✅ 신화인터텍㈜(00228350) - 데이터 수집 완료
# ✅ (주)아이마켓코리아(00360142) - 데이터 수집 완료
# ✅ ㈜엘비루셈(00527011) - 데이터 수집 완료
# ✅ 주식회사 피플바이오(01118281) - 데이터 수집 완료
# ✅ (주)바이오톡스텍(00447502) - 데이터 수집 완료
# ✅ 주식회사 코퍼스코리아(01364297) - 데이터 수집 완료
# ✅ (주)성우하이텍(00132992) - 데이터 수집 완료
# ✅ 주식회사 이상네트웍스(00454399) - 데이터 수집 완료
# ✅ 주식회사 메쎄이상(01596656) - 데이터 수집 완료
# ✅ (주)비즈니스온커뮤니케이션(01014657) - 데이터 수집 완료
# ✅ 주식회사 휴럼(01453670) - 데이터 수집 완료
# ✅ (주)그래디언트(00244561) - 데이터 수집 완료
# ✅ 주식회사 케이사인(01003040) - 데이터 수집 완료
# ✅ 주식회사 미코바이오메드(01049167) - 데이터 수집 완료
# ✅ (주)에이스침대(00140052) - 데이터 수집 완료
# ✅ SNT모티브 주식회사(00398792) - 데이터 수집 완료
# ✅ 경동제약 주식회사(00101549) - 데이터 수집 완료
# ✅ SNT에너지주식회사(00648721) - 데이터 수집 완료
# ✅ 주식회사 오리엔탈정공(00141608) - 데이터 수집 완료
# ✅ 주식회사 노바텍(01259232) - 데이터 수집 완료
# ✅ 주식회사 더블유에스아이(01318261) - 데이터 수집 완료
# ✅ 주식회사 제이시스메디칼(01267602) - 데이터 수집 완료
# ✅ (주)제놀루션(01062177) - 데이터 수집 완료
# ✅ 주식회사 태성(01366000) - 데이터 수집 완료
# ✅ 주식회사 아이티센(00620868) - 데이터 수집 완료
# ✅ ㈜데이타솔루션(00877819) - 데이터 수집 완료
# ✅ (주)비아트론(00610083) - 데이터 수집 완료
# ✅ 주식회사 아이씨에이치(01302853) - 데이터 수집 완료
# ✅ (주)신세계푸드(00274933) - 데이터 수집 완료
# ✅ 아미코젠(주)(00545734) - 데이터 수집 완료
# ✅ 주식회사파수(00638487) - 데이터 수집 완료
# ✅ 주식회사 바른손(00122205) - 데이터 수집 완료
# ✅ 주식회사 와이엠(00140858) - 데이터 수집 완료
# ✅ (주)원일특강(00143907) - 데이터 수집 완료
# ✅ 대원미디어(주)(00351807) - 데이터 수집 완료
# ✅ 주식회사 오에스피(01491607) - 데이터 수집 완료
# ✅ 미래나노텍(주)(00526836) - 데이터 수집 완료
# ✅ 문배철강 주식회사(00121570) - 데이터 수집 완료
# ✅ 데브시스터즈(주)(01008762) - 데이터 수집 완료
# ✅ ㈜아가방앤컴퍼니(00138446) - 데이터 수집 완료
# ✅ (주)유신(00144650) - 데이터 수집 완료
# ✅ 주식회사 씨이랩(00991298) - 데이터 수집 완료
# ✅ (주) 비올(01406618) - 데이터 수집 완료
# ✅ 예스이십사 주식회사(00362858) - 데이터 수집 완료
# ✅ 알서포트 주식회사(00838962) - 데이터 수집 완료
# ✅ (주)성광벤드(00132318) - 데이터 수집 완료
# ✅ 동화기업(주)(00173032) - 데이터 수집 완료
# ✅ (주)와이비엠넷(00307222) - 데이터 수집 완료
# ✅ 주식회사 블리츠웨이(구, 대신밸런스제9호기업인수목적 주식회사)(01508855) - 데이터 수집 완료
# ✅ (주)동일기연(00199076) - 데이터 수집 완료
# ✅ 성일하이텍 주식회사(01274329) - 데이터 수집 완료
# ✅ ㈜더미동(00945208) - 데이터 수집 완료
# ✅ 이연제약(주)(00145598) - 데이터 수집 완료
# ✅ 엘티씨(주)(00866062) - 데이터 수집 완료
# ✅ (주)이지홀딩스(00242378) - 데이터 수집 완료
# ✅ 주식회사 에스비비테크(00567897) - 데이터 수집 완료
# ✅ 주식회사 신영와코루(00136624) - 데이터 수집 완료
# ✅ 주식회사 한탑(00140566) - 데이터 수집 완료
# ✅ 주식회사 한농화성(00160861) - 데이터 수집 완료
# ✅ (주)네오펙트(01246034) - 데이터 수집 완료
# ✅ 금호전기(주)(00106395) - 데이터 수집 완료
# ✅ 제일파마홀딩스 주식회사(00148443) - 데이터 수집 완료
# ✅ 에브리봇(01201590) - 데이터 수집 완료
# ✅ 주식회사 에코앤드림(00619640) - 데이터 수집 완료
# ✅ 주식회사 홈캐스트(00385336) - 데이터 수집 완료
# ✅ 주식회사 무학(00121543) - 데이터 수집 완료
# ✅ 엠케이전자(주)(00121686) - 데이터 수집 완료
# ✅ 주식회사 STX(00138297) - 데이터 수집 완료
# ✅ 갤럭시아머니트리 주식회사(00587457) - 데이터 수집 완료
# ✅ 주식회사 SG글로벌(00152039) - 데이터 수집 완료
# ✅ 이엠코리아(주)(00526951) - 데이터 수집 완료
# ✅ (주)금화피에스시(00176516) - 데이터 수집 완료
# ✅ 금강공업(주)(00105299) - 데이터 수집 완료
# ✅ 윈하이텍(00910840) - 데이터 수집 완료
# ✅ 주식회사 한진중공업홀딩스(00163673) - 데이터 수집 완료
# ✅ (주)엠플러스(00833064) - 데이터 수집 완료
# ✅ (주)삼기(00799177) - 데이터 수집 완료
# ✅ 키움제6호기업인수목적 주식회사(01616808) - 데이터 수집 완료
# ✅ (주)로보로보(01063990) - 데이터 수집 완료
# ✅ (주)웨이버스(01408999) - 데이터 수집 완료
# ✅ (주) 기가레인(00377018) - 데이터 수집 완료
# ✅ 주식회사 이글벳(00145473) - 데이터 수집 완료
# ✅ 인카금융서비스 주식회사(01013694) - 데이터 수집 완료
# ✅ 주식회사 안랩(00298270) - 데이터 수집 완료
# ✅ 한국정보인증(주)(00306454) - 데이터 수집 완료
# ✅ 주식회사 에이치피오(01068737) - 데이터 수집 완료
# ✅ 한양이엔지 주식회사(00216762) - 데이터 수집 완료
# ✅ 주식회사 영우디에스피(00569646) - 데이터 수집 완료
# ✅ 프리시젼바이오(주)(01137295) - 데이터 수집 완료
# ✅ 주식회사 위드텍(00925587) - 데이터 수집 완료
# ✅ 주식회사 네오셈(01170865) - 데이터 수집 완료
# ✅ 대림통상 주식회사(00109824) - 데이터 수집 완료
# ✅ 주식회사 일승(01396676) - 데이터 수집 완료
# ✅ (주)한컴라이프케어(00534598) - 데이터 수집 완료
# ✅ 주식회사 세진중공업(00415628) - 데이터 수집 완료
# ✅ 페이퍼코리아(주)(00134723) - 데이터 수집 완료
# ✅ 주식회사 텔레칩스(00423177) - 데이터 수집 완료
# ✅ (주)위세아이텍(00374738) - 데이터 수집 완료
# ✅ 아이텍 주식회사(00626011) - 데이터 수집 완료
# ✅ 주식회사 남성(00172185) - 데이터 수집 완료
# ✅ 주식회사레이(00828761) - 데이터 수집 완료
# ✅ 우수AMS 주식회사(00301422) - 데이터 수집 완료
# ✅ (주)씨앤투스(00875237) - 데이터 수집 완료
# ✅ 주식회사 오비고(00494546) - 데이터 수집 완료
# ✅ (주)티피씨메카트로닉스(00108649) - 데이터 수집 완료
# ✅ 주식회사 토비스(00390365) - 데이터 수집 완료
# ✅ 카페24 주식회사(00260879) - 데이터 수집 완료
# ✅ (주)티앤엘(00608440) - 데이터 수집 완료
# ✅ 키네마스터(주)(00535375) - 데이터 수집 완료
# ✅ 엑스페릭스(01231786) - 데이터 수집 완료
# ✅ 주식회사 우성(00142661) - 데이터 수집 완료
# ✅ 휴림네트웍스(주)(00623184) - 데이터 수집 완료
# ✅ (주)원티드랩(01441611) - 데이터 수집 완료
# ✅ (주)한글과컴퓨터(00204262) - 데이터 수집 완료
# ✅ 제이엔케이히터(주)(00442154) - 데이터 수집 완료
# ✅ 주식회사 액토즈소프트(00348034) - 데이터 수집 완료
# ✅ 주식회사 마니커에프앤지(00770312) - 데이터 수집 완료
# ✅ 주식회사 시알홀딩스(00148984) - 데이터 수집 완료
# ✅ 주식회사 코디(00308559) - 데이터 수집 완료
# ✅ 주식회사 에이치피에스피(01288827) - 데이터 수집 완료
# ✅ (주)싸이버원(01293953) - 데이터 수집 완료
# ✅ (주)비트나인(01381984) - 데이터 수집 완료
# ✅ 주식회사 에이치비테크놀러지(00255275) - 데이터 수집 완료
# ✅ 감성코퍼레이션 주식회사(00261009) - 데이터 수집 완료
# ✅ (주)에스엠코어(00137915) - 데이터 수집 완료
# ✅ 고려산업(주)(00102751) - 데이터 수집 완료
# ✅ 주식회사 영원무역홀딩스(00140964) - 데이터 수집 완료
# ✅ (주)셀리드(01235296) - 데이터 수집 완료
# ✅ 인화정공(주)(00482426) - 데이터 수집 완료
# ✅ 주식회사 한국전자홀딩스(00159254) - 데이터 수집 완료
# ✅ 주식회사 주성코퍼레이션(00753643) - 데이터 수집 완료
# ✅ 대동(00109286) - 데이터 수집 완료
# ✅ 주식회사 삼영(00127255) - 데이터 수집 완료
# ✅ 케이비아이동국실업주식회사(00114765) - 데이터 수집 완료
# ✅ 주식회사 핀텔(01524507) - 데이터 수집 완료
# ✅ 한성기업(주)(00161860) - 데이터 수집 완료
# ✅ (주)미래생명자원(01071944) - 데이터 수집 완료
# ✅ (주)덴티스(01187494) - 데이터 수집 완료
# ✅ 광진실업 주식회사(00104120) - 데이터 수집 완료
# ✅ (주)인피니트헬스케어(00435969) - 데이터 수집 완료
# ✅ 주식회사 선진(00855093) - 데이터 수집 완료
# ✅ (주)세동(00133663) - 데이터 수집 완료
# ✅ 라온피플(주)(01251489) - 데이터 수집 완료
# ✅ 주식회사 지노믹트리(01108248) - 데이터 수집 완료
# ✅ 주식회사 지오엘리먼트(00668965) - 데이터 수집 완료
# ✅ 주식회사 디알젬(00966168) - 데이터 수집 완료
# ✅ 주식회사 SNT홀딩스(00225159) - 데이터 수집 완료
# ✅ 주식회사하이딥(01505186) - 데이터 수집 완료
# ✅ 동일고무벨트 주식회사(00939687) - 데이터 수집 완료
# ✅ 주식회사 디알비동일(00118266) - 데이터 수집 완료
# ✅ 주식회사 모두투어네트워크(00456218) - 데이터 수집 완료
# ✅ 태경케미컬 주식회사(00109161) - 데이터 수집 완료
# ✅ (주)오스테오닉(01082348) - 데이터 수집 완료
# ✅ 대성홀딩스 주식회사(00108940) - 데이터 수집 완료
# ✅ 케이디 주식회사(00111218) - 데이터 수집 완료
# ✅ 대원산업 주식회사(00111874) - 데이터 수집 완료
# ✅ 전방주식회사(00147222) - 데이터 수집 완료
# ✅ 주식회사 상상인(00306162) - 데이터 수집 완료
# ✅ 지니언스(주)(00962223) - 데이터 수집 완료
# ✅ 세명전기공업주식회사(00133751) - 데이터 수집 완료
# ✅ (주)넥센(00167192) - 데이터 수집 완료
# ✅ 주식회사 ES큐브(00175623) - 데이터 수집 완료
# ✅ 주식회사 대창솔루션(00177870) - 데이터 수집 완료
# ✅ 주식회사 소룩스(00605522) - 데이터 수집 완료
# ✅ 주식회사 원익홀딩스(00216647) - 데이터 수집 완료
# ✅ 선바이오 주식회사(00407036) - 데이터 수집 완료
# ✅ 주식회사 딥노이드(01344831) - 데이터 수집 완료
# ✅ 주식회사 톱텍(00531917) - 데이터 수집 완료
# ✅ 주식회사 피제이전자(00155735) - 데이터 수집 완료
# ✅ 주식회사 서진시스템(00838005) - 데이터 수집 완료
# ✅ 주식회사주연테크(00269241) - 데이터 수집 완료
# ✅ 주식회사 애드바이오텍(01022902) - 데이터 수집 완료
# ✅ 유니슨 주식회사(00144243) - 데이터 수집 완료
# ✅ (주)MH에탄올(00121534) - 데이터 수집 완료
# ✅ 진흥기업주식회사(00150828) - 데이터 수집 완료
# ✅ 삼호개발 주식회사(00128980) - 데이터 수집 완료
# ✅ 옵투스제약 주식회사(00831428) - 데이터 수집 완료
# ✅ 에스지에이솔루션즈(주)(00988364) - 데이터 수집 완료
# ✅ 무림피앤피 주식회사(00119007) - 데이터 수집 완료
# ✅ 삼천당제약 주식회사(00128546) - 데이터 수집 완료
# ✅ (주)팬스타엔터프라이즈(00339072) - 데이터 수집 완료
# ✅ (주)리튬포어스(00440712) - 데이터 수집 완료
# ✅ 주식회사 코아스(00210856) - 데이터 수집 완료
# ✅ (주)컴투스홀딩스(00535746) - 데이터 수집 완료
# ✅ 주식회사 티사이언티픽(00372688) - 데이터 수집 완료
# ✅ 주식회사 대성파인텍(00442905) - 데이터 수집 완료
# ✅ 켄코아에어로스페이스 주식회사(01158553) - 데이터 수집 완료
# ✅ SNT다이내믹스 주식회사(00134477) - 데이터 수집 완료
# ✅ 주식회사 플래티어(01454341) - 데이터 수집 완료
# ✅ (주)코오롱(00152862) - 데이터 수집 완료
# ✅ 주식회사 케이엠더블유(00226352) - 데이터 수집 완료
# ✅ 주식회사 레고켐바이오사이언스(00842619) - 데이터 수집 완료
# ✅ 에쓰씨엔지니어링 주식회사(00121969) - 데이터 수집 완료
# ✅ 주식회사 차백신연구소(01141599) - 데이터 수집 완료
# ✅ (주)엘엑스세미콘(00525934) - 데이터 수집 완료
# ✅ (주) 국영지앤엠(00104537) - 데이터 수집 완료
# ✅ 주식회사 큐라클(01397772) - 데이터 수집 완료
# ✅ 에이피티씨(주)(00544577) - 데이터 수집 완료
# ✅ 주식회사 에코프로에이치엔(01566248) - 데이터 수집 완료
# ✅ ㈜라온테크(00911229) - 데이터 수집 완료
# ✅ 씨비아이(주)(00151605) - 데이터 수집 완료
# ✅ (주)금호에이치(00105606) - 데이터 수집 완료
# ✅ 대성산업 주식회사(00828789) - 데이터 수집 완료
# ✅ 주식회사 바이넥스(00216027) - 데이터 수집 완료
# ✅ 지에이치신소재 주식회사(00491938) - 데이터 수집 완료
# ✅ (주)선광(00131896) - 데이터 수집 완료
# ✅ 주식회사이퓨쳐(00788737) - 데이터 수집 완료
# ✅ 우진비앤지 주식회사(00103547) - 데이터 수집 완료
# ✅ 비나텍 주식회사(00563518) - 데이터 수집 완료
# ✅ 삼지전자(주)(00128315) - 데이터 수집 완료
# ✅ 대명에너지 주식회사(01150515) - 데이터 수집 완료
# ✅ 대한뉴팜(주)(00207375) - 데이터 수집 완료
# ✅ 주식회사 제노코(01014718) - 데이터 수집 완료
# ✅ 주식회사 멕아이씨에스(00270113) - 데이터 수집 완료
# ✅ 에스씨엠생명과학 주식회사(01110474) - 데이터 수집 완료
# ✅ (주)에프알텍(00442561) - 데이터 수집 완료
# ✅ (주)다우기술(00176914) - 데이터 수집 완료
# ✅ (주)상보(00129615) - 데이터 수집 완료
# ✅ 주식회사 아진엑스텍(00404288) - 데이터 수집 완료
# ✅ (주)큐브엔터(00985686) - 데이터 수집 완료
# ✅ 주식회사 오공(00220969) - 데이터 수집 완료
# ✅ (주) 소프트센(00204226) - 데이터 수집 완료
# ✅ 주식회사 경인양행(00102113) - 데이터 수집 완료
# ✅ 와이더블유(주)(00296263) - 데이터 수집 완료
# ✅ (주)브이티(00150165) - 데이터 수집 완료
# ✅ 주식회사 엠로(00396925) - 데이터 수집 완료
# ✅ 주식회사 테라젠이텍스(00249894) - 데이터 수집 완료
# ✅ 신세계건설 주식회사(00217947) - 데이터 수집 완료
# ✅ 주식회사 토니모리(00816544) - 데이터 수집 완료
# ✅ 주식회사 파이버프로(01513440) - 데이터 수집 완료
# ✅ 데이터 저장 완료: 기업_재무제표_2023년_L3.xlsx, 기업_재무제표_2023년_L3.xlsx

# %% [markdown]
# #
# :------------------------------------------------------------------------------L4------------------------------------

# %%
import requests
import pandas as pd
import time

# DART API 인증키 (본인의 API 키 입력)
API_KEY = '85006d20472a255d5eae25ee265b5ed1b78d1386'

# DART 재무제표 API URL
FS_URL = "https://opendart.fss.or.kr/api/fnlttSinglAcntAll.json"

# 기업 리스트 엑셀 파일 읽기
file_path = "./corp_list_split.xlsx"  # 로컬 파일 경로
corporations_df = pd.read_excel(file_path, sheet_name="L4", dtype={'code': str})

# 데이터 저장을 위한 리스트
financial_data = []

# 자본변동표 관련 계정과목 필터링 리스트
exclude_accounts = [
    "자본금 변동", "기타포괄손익누계액", "이익잉여금 변동",
    "자본총계 변동", "기타자본항목 변동", "배당금 지급", "주식발행", "자본조정"
]

# 자본 관련 항목 리스트 (우선 재무상태표 항목을 우선하고, 없는 경우 첫 번째로 나온 항목 선택)
capital_related_accounts = ["자본총계", "기초자본", "자본금", "이익잉여금", "기타자본항목"]

# 기업별 재무제표 요청
for _, row in corporations_df.iterrows():
    corp_code = row['code']  # 기업 코드
    corp_name = row.get('name', '알 수 없음')  # 기업 이름

    params = {
        'crtfc_key': API_KEY,
        'corp_code': corp_code,
        'bsns_year': 2023,  # 연도
        'reprt_code': '11011',  # 사업보고서 (연결 재무제표)
        'fs_div': 'OFS'  # 개별 재무제표 (자본변동표 포함 X)
    }

    try:
        # API 요청
        response = requests.get(FS_URL, params=params, timeout=10)
        response.raise_for_status()
        data = response.json()

        if data.get('status') == '000':  # 정상 응답
            if 'list' in data and data['list']:
                unique_accounts = set()  # 중복 방지를 위한 set
                first_appearance_accounts = []  # 첫 번째로 나온 항목을 저장할 리스트

                for item in data['list']:
                    account_name = item['account_nm'].strip()
                    account_id = item.get('account_id', '데이터 없음')  # account_id 추가

                    # 자본변동표 관련 항목 제외
                    if any(excl in account_name for excl in exclude_accounts):
                        continue

                    # 자본 관련 계정 처리: 재무상태표에 있는 항목을 우선하고, 없으면 첫 번째 항목 사용
                    if any(account_name.startswith(capital_account) for capital_account in capital_related_accounts):
                        # 재무상태표에 있는 자본 항목을 우선 처리
                        if account_name not in unique_accounts:
                            unique_accounts.add(account_name)
                            financial_data.append({
                                "기업 이름": corp_name,
                                "기업 코드": corp_code,
                                "연도": 2023,
                                "계정과목명": account_name,
                                "account_id": account_id,  # account_id 추가
                                "금액": item.get('thstrm_amount', '데이터 없음'),  # 2023년 금액
                                "2022년 금액": item.get('frmtrm_amount', '데이터 없음'),  # 2022년 금액
                                "2021년 금액": item.get('lfy_amount', '데이터 없음')  # 2021년 금액
                            })
                    else:
                        # 첫 번째로 나온 자본 관련 항목을 선택하여 추가
                        if account_name not in first_appearance_accounts:
                            first_appearance_accounts.append(account_name)
                            financial_data.append({
                                "기업 이름": corp_name,
                                "기업 코드": corp_code,
                                "연도": 2023,
                                "계정과목명": account_name,
                                "account_id": account_id,  # account_id 추가
                                "금액": item.get('thstrm_amount', '데이터 없음'),  # 2023년 금액
                                "2022년 금액": item.get('frmtrm_amount', '데이터 없음'),  # 2022년 금액
                                "2021년 금액": item.get('lfy_amount', '데이터 없음')  # 2021년 금액
                            })

                print(f"✅ {corp_name}({corp_code}) - 데이터 수집 완료")
            else:
                print(f"⚠️ {corp_name}({corp_code}) - 재무 데이터 없음")
        else:
            print(f"❌ {corp_name}({corp_code}) - API 오류: {data.get('message', '알 수 없는 오류')}")

    except requests.exceptions.RequestException as e:
        print(f"🚨 {corp_name}({corp_code}) - 요청 실패: {e}")

    time.sleep(1)  # API 요청 간격 조정

# DataFrame 변환
df_4 = pd.DataFrame(financial_data)

# 결과 저장
output_excel = "기업_재무제표_2023년_L4.xlsx"

df_4.to_excel(output_excel, index=False)

print(f"✅ 데이터 저장 완료: {output_excel}, {output_excel}")
# Out:
# ✅ 에이치케이이노엔 주식회사(01012066) - 데이터 수집 완료
# ✅ 한국단자공업(주)(00157070) - 데이터 수집 완료
# ✅ 주식회사 서부티엔디(00130383) - 데이터 수집 완료
# ✅ 우리바이오 주식회사(00369107) - 데이터 수집 완료
# ✅ 우리엔터프라이즈 주식회사(00155692) - 데이터 수집 완료
# ✅ 씨제이프레시웨이(주)(00127954) - 데이터 수집 완료
# ✅ 주식회사 코콤(00187725) - 데이터 수집 완료
# ✅ 삼성제약 주식회사(00126414) - 데이터 수집 완료
# ✅ 이지트로닉스(01140837) - 데이터 수집 완료
# ✅ 대보마그네틱 주식회사(01259418) - 데이터 수집 완료
# ✅ 주식회사 동성케미컬(00679314) - 데이터 수집 완료
# ✅ 주식회사 웹스(00864338) - 데이터 수집 완료
# ✅ 주식회사 삼영에스앤씨(00405506) - 데이터 수집 완료
# ✅ 디와이씨 주식회사(01336443) - 데이터 수집 완료
# ✅ 주식회사 홈센타홀딩스(00288495) - 데이터 수집 완료
# ✅ 지엘팜텍 주식회사(01042359) - 데이터 수집 완료
# ✅ 주식회사 비스토스(01506848) - 데이터 수집 완료
# ✅ (주)동운아나텍(00695969) - 데이터 수집 완료
# ✅ (주)티씨씨스틸(00117300) - 데이터 수집 완료
# ✅ 주식회사 토탈소프트뱅크(00355089) - 데이터 수집 완료
# ✅ 신라교역 주식회사(00135962) - 데이터 수집 완료
# ✅ 고려신용정보(00336297) - 데이터 수집 완료
# ✅ (주)모다이노칩(00480048) - 데이터 수집 완료
# ✅ (주)에스엠라이프디자인그룹(00367604) - 데이터 수집 완료
# ✅ 바이젠셀(주)(01335790) - 데이터 수집 완료
# ✅ 무림페이퍼 주식회사(00136086) - 데이터 수집 완료
# ✅ (주)다우데이타(00238782) - 데이터 수집 완료
# ✅ 주식회사 아스트(00409681) - 데이터 수집 완료
# ✅ 주식회사 세보엠이씨(00133876) - 데이터 수집 완료
# ✅ 화성산업주식회사(00174527) - 데이터 수집 완료
# ✅ 주식회사 딜리(00629212) - 데이터 수집 완료
# ✅ 주식회사 큐로홀딩스(00296324) - 데이터 수집 완료
# ✅ 대정화금 주식회사(00250997) - 데이터 수집 완료
# ✅ 주식회사 실리콘투(00982023) - 데이터 수집 완료
# ✅ 주식회사 샤페론(01387164) - 데이터 수집 완료
# ✅ 상신전자 주식회사(00760999) - 데이터 수집 완료
# ✅ 디아이동일(주)(00118345) - 데이터 수집 완료
# ✅ 바이오플러스 주식회사(00636656) - 데이터 수집 완료
# ✅ 세방 주식회사(00133812) - 데이터 수집 완료
# ✅ 농업회사법인(주)농우바이오(00176835) - 데이터 수집 완료
# ✅ (주)아톤(00595182) - 데이터 수집 완료
# ✅ 에이치엘비글로벌 주식회사(00169048) - 데이터 수집 완료
# ✅ 부산주공 주식회사(00124151) - 데이터 수집 완료
# ✅ 신일전자 주식회사(00173698) - 데이터 수집 완료
# ✅ 인크로스(주)(00819073) - 데이터 수집 완료
# ✅ (주) 승일(00135467) - 데이터 수집 완료
# ✅ 주식회사 신테카바이오(01344336) - 데이터 수집 완료
# ✅ (주)씨앤씨인터내셔널(01226410) - 데이터 수집 완료
# ✅ (주) 태양(00186717) - 데이터 수집 완료
# ✅ 솔루스첨단소재 주식회사(01412822) - 데이터 수집 완료
# ✅ 주식회사 엑셈(01042085) - 데이터 수집 완료
# ✅ 에이비온 주식회사(00977377) - 데이터 수집 완료
# ✅ 주식회사 세코닉스(00351630) - 데이터 수집 완료
# ✅ 엔피씨(주)(00108038) - 데이터 수집 완료
# ✅ 한솔인티큐브㈜(00470829) - 데이터 수집 완료
# ✅ 주식회사 뉴인텍(00105040) - 데이터 수집 완료
# ✅ (주)윙스풋(01405585) - 데이터 수집 완료
# ✅ 주식회사 휠라홀딩스(00195229) - 데이터 수집 완료
# ✅ 주식회사 영원무역(00776820) - 데이터 수집 완료
# ✅ (주)스페코(00136165) - 데이터 수집 완료
# ✅ 주식회사 아이비김영(01414422) - 데이터 수집 완료
# ✅ 제이씨현시스템(주)(00223513) - 데이터 수집 완료
# ✅ ㈜헥토이노베이션(01013311) - 데이터 수집 완료
# ✅ (주)피엔티(00612294) - 데이터 수집 완료
# ✅ 주식회사 모아데이타(01423837) - 데이터 수집 완료
# ✅ 주식회사 삼일(00127909) - 데이터 수집 완료
# ✅ 주식회사 휴메딕스(00614478) - 데이터 수집 완료
# ✅ (주)메드팩토(01336373) - 데이터 수집 완료
# ✅ 주식회사 디지털대성(00398808) - 데이터 수집 완료
# ✅ 리노공업(주)(00369657) - 데이터 수집 완료
# ✅ 하나제약(주)(00248974) - 데이터 수집 완료
# ✅ (주)솔트룩스(01050738) - 데이터 수집 완료
# ✅ (주)제이와이피엔터테인먼트(00258689) - 데이터 수집 완료
# ✅ (주)키다리스튜디오(00140131) - 데이터 수집 완료
# ✅ 제룡전기 주식회사(00185356) - 데이터 수집 완료
# ✅ (주)코리아나화장품(00152589) - 데이터 수집 완료
# ✅ (주)한익스프레스(00129509) - 데이터 수집 완료
# ✅ 일성건설 주식회사(00146232) - 데이터 수집 완료
# ✅ (주)이수페타시스(00107613) - 데이터 수집 완료
# ✅ 주식회사 아센디오(00145437) - 데이터 수집 완료
# ✅ 주식회사 메지온(00808022) - 데이터 수집 완료
# ✅ 노을 주식회사(01494118) - 데이터 수집 완료
# ✅ 우리산업 주식회사(01077577) - 데이터 수집 완료
# ✅ 주식회사 하이비젼시스템(00825959) - 데이터 수집 완료
# ✅ 주식회사 퓨런티어(01357446) - 데이터 수집 완료
# ✅ 주식회사 대양금속(00111111) - 데이터 수집 완료
# ✅ (주)탑머티리얼(01360875) - 데이터 수집 완료
# ✅ (주)코윈테크(01211232) - 데이터 수집 완료
# ✅ 주식회사 코스텍시스
# (구, 교보10호기업인수목적 주식회사)(01476219) - 데이터 수집 완료
# ✅ 주식회사 케이에스피(00328191) - 데이터 수집 완료
# ✅ 미래에셋비전기업인수목적1호 주식회사(01601286) - 데이터 수집 완료
# ✅ 주식회사 티앤알바이오팹(01109937) - 데이터 수집 완료
# ✅ 한국정보공학(주)(00261957) - 데이터 수집 완료
# ✅ (주)라이온켐텍(00317104) - 데이터 수집 완료
# ✅ 글로본 주식회사(00159731) - 데이터 수집 완료
# ✅ (주)에스앤디(00560849) - 데이터 수집 완료
# ✅ 경남스틸(주)(00206039) - 데이터 수집 완료
# ✅ 주식회사 티움바이오(01335930) - 데이터 수집 완료
# ✅ 주식회사 젠큐릭스(01051472) - 데이터 수집 완료
# ✅ (주)수젠텍(01063954) - 데이터 수집 완료
# ✅ 에이치디씨현대이피(주)(00357935) - 데이터 수집 완료
# ✅ (주)서원인텍(00445799) - 데이터 수집 완료
# ✅ (주)서울옥션(00410915) - 데이터 수집 완료
# ✅ 주식회사 원익큐엔씨(00468374) - 데이터 수집 완료
# ✅ 주식회사 두올(00119672) - 데이터 수집 완료
# ✅ 동아에스티(주)(00956930) - 데이터 수집 완료
# ✅ 일진전기 주식회사(00683469) - 데이터 수집 완료
# ✅ 도이치모터스 주식회사(00449379) - 데이터 수집 완료
# ✅ 주식회사 플레이디(00862853) - 데이터 수집 완료
# ✅ 재영솔루텍(주)(00147082) - 데이터 수집 완료
# ✅ 태림포장(주)(00153524) - 데이터 수집 완료
# ✅ 매일유업 주식회사(01234507) - 데이터 수집 완료
# ✅ 씨제이바이오사이언스 주식회사(01071041) - 데이터 수집 완료
# ✅ 삼보산업주식회사(00125822) - 데이터 수집 완료
# ✅ 매일홀딩스(주)(00120924) - 데이터 수집 완료
# ✅ 주식회사 하이드로리튬(00527491) - 데이터 수집 완료
# ✅ 동아쏘시오홀딩스(주)(00116824) - 데이터 수집 완료
# ✅ (주)디이엔티(00445160) - 데이터 수집 완료
# ✅ 주식회사 에코프로(00536541) - 데이터 수집 완료
# ✅ 주식회사 메타랩스(00442835) - 데이터 수집 완료
# ✅ 주식회사 큐렉소(00356802) - 데이터 수집 완료
# ✅ 엘에스에코에너지 주식회사(01093007) - 데이터 수집 완료
# ✅ 일진하이솔루스 주식회사(00972503) - 데이터 수집 완료
# ✅ 주식회사 우신시스템(00142883) - 데이터 수집 완료
# ✅ 깨끗한나라 주식회사(00113492) - 데이터 수집 완료
# ✅ 보성파워텍 주식회사(00267881) - 데이터 수집 완료
# ✅ 주식회사 일지테크(00146560) - 데이터 수집 완료
# ✅ 주식회사 지누스(00150633) - 데이터 수집 완료
# ✅ 에스텍파마(00463342) - 데이터 수집 완료
# ✅ 주식회사 에이비프로바이오(00620558) - 데이터 수집 완료
# ✅ 오로라월드(주)(00141556) - 데이터 수집 완료
# ✅ (주)폴라리스우노(00663669) - 데이터 수집 완료
# ✅ 알톤스포츠(00821607) - 데이터 수집 완료
# ✅ 영화테크 주식회사(00659976) - 데이터 수집 완료
# ✅ 보로노이(주)(01327746) - 데이터 수집 완료
# ✅ 주식회사 보락(00123107) - 데이터 수집 완료
# ✅ 주식회사 젬백스앤카엘(00492894) - 데이터 수집 완료
# ✅ 주식회사 이월드(00540605) - 데이터 수집 완료
# ✅ 주식회사 바이오에프디엔씨(01160974) - 데이터 수집 완료
# ✅ 나라엠앤디(주)(00297095) - 데이터 수집 완료
# ✅ (주)링네트(00352499) - 데이터 수집 완료
# ✅ (주)나무가(00819374) - 데이터 수집 완료
# ✅ 주식회사 넥스틴(01080252) - 데이터 수집 완료
# ✅ 주식회사 로보티즈(00946030) - 데이터 수집 완료
# ✅ (주)카이노스메드(01263527) - 데이터 수집 완료
# ✅ 에이치엘비바이오스텝(주)(01189438) - 데이터 수집 완료
# ✅ (주)우양(00486875) - 데이터 수집 완료
# ✅ 에이치엘비생명과학(주)(00365590) - 데이터 수집 완료
# ✅ 에이치엘비(주)(00199252) - 데이터 수집 완료
# ✅ 파미셀 주식회사(00145163) - 데이터 수집 완료
# ✅ 롯데정보통신(주)(01262032) - 데이터 수집 완료
# ✅ 케이엠제약 주식회사(01095704) - 데이터 수집 완료
# ✅ (주)맥스트(01409095) - 데이터 수집 완료
# ✅ 주식회사 케이아이엔엑스(00603348) - 데이터 수집 완료
# ✅ (주)원풍(00144012) - 데이터 수집 완료
# ✅ 영풍정밀 주식회사(00141389) - 데이터 수집 완료
# ✅ 인지컨트롤스(주)(00103510) - 데이터 수집 완료
# ✅ (주)유라테크(00201742) - 데이터 수집 완료
# ✅ 주식회사 셀루메드(00310156) - 데이터 수집 완료
# ✅ 주식회사 대성하이텍(00577335) - 데이터 수집 완료
# ✅ (주)제일테크노스(00148595) - 데이터 수집 완료
# ✅ (주)파이오링크(00492353) - 데이터 수집 완료
# ✅ 압타바이오 주식회사(01251595) - 데이터 수집 완료
# ✅ 주식회사 부방(00243067) - 데이터 수집 완료
# ✅ 디지아이(00295547) - 데이터 수집 완료
# ✅ 주식회사 에스씨디(00171867) - 데이터 수집 완료
# ✅ 주식회사 인팩(00180795) - 데이터 수집 완료
# ✅ (주)세림비앤지(01416572) - 데이터 수집 완료
# ✅ 주식회사 액션스퀘어(01042429) - 데이터 수집 완료
# ✅ 주식회사 네온테크(01325429) - 데이터 수집 완료
# ✅ 대성에너지(주)(00787376) - 데이터 수집 완료
# ✅ (주)코메론(00152783) - 데이터 수집 완료
# ✅ 에코플라스틱주식회사(00139153) - 데이터 수집 완료
# ✅ (주)금양(00106119) - 데이터 수집 완료
# ✅ 이녹스(00494476) - 데이터 수집 완료
# ✅ 브레인즈컴퍼니 주식회사(00642897) - 데이터 수집 완료
# ✅ 주식회사 디케이티(01137903) - 데이터 수집 완료
# ✅ 에스케이텔레콤 주식회사(00159023) - 데이터 수집 완료
# ✅ 한국정보통신 주식회사(00159342) - 데이터 수집 완료
# ✅ (주)아이티엠반도체(00579980) - 데이터 수집 완료
# ✅ 주식회사 현대바이오랜드(00347062) - 데이터 수집 완료
# ✅ 주식회사 오리온홀딩스(00117577) - 데이터 수집 완료
# ✅ 주식회사 제이엘케이(01153293) - 데이터 수집 완료
# ✅ 주식회사 한국비엔씨(01179617) - 데이터 수집 완료
# ✅ 에스엔케이폴리텍주식회사(00580667) - 데이터 수집 완료
# ✅ 주식회사 오리온(01238169) - 데이터 수집 완료
# ✅ 덕양산업 주식회사(00114154) - 데이터 수집 완료
# ✅ 한솔피엔에스주식회사(00103626) - 데이터 수집 완료
# ✅ 코나아이(주)(00349732) - 데이터 수집 완료
# ✅ (주)코미팜(00187415) - 데이터 수집 완료
# ✅ (주)에스에이엠티(00128661) - 데이터 수집 완료
# ✅ 주식회사 네패스아크(01368354) - 데이터 수집 완료
# ✅ 주식회사 케이티씨에스(00372882) - 데이터 수집 완료
# ✅ 주식회사 국순당(00256715) - 데이터 수집 완료
# ✅ 주식회사 지어소프트(00389110) - 데이터 수집 완료
# ✅ (주)스피어파워(01036367) - 데이터 수집 완료
# ✅ 주식회사 KH바텍(00378628) - 데이터 수집 완료
# ✅ 펌텍코리아주식회사(00761059) - 데이터 수집 완료
# ✅ (주)이노테라피(01110182) - 데이터 수집 완료
# ✅ 주식회사 헬릭스미스(00359395) - 데이터 수집 완료
# ✅ 주식회사 동성화인텍(00231105) - 데이터 수집 완료
# ✅ (주)뉴트리(01214248) - 데이터 수집 완료
# ✅ (주)제이앤티씨(00447575) - 데이터 수집 완료
# ✅ 주식회사 제닉(00624998) - 데이터 수집 완료
# ✅ 주식회사 제테마(01222867) - 데이터 수집 완료
# ✅ (주)엔케이(00172228) - 데이터 수집 완료
# ✅ 주식회사 엔비티(01051065) - 데이터 수집 완료
# ✅ 에스폴리텍(00340272) - 데이터 수집 완료
# ✅ 주식회사 원바이오젠(01326224) - 데이터 수집 완료
# ✅ (주)석경에이티(00921916) - 데이터 수집 완료
# ✅ 주식회사 서울리거(00305570) - 데이터 수집 완료
# ✅ (주)광주신세계(00220561) - 데이터 수집 완료
# ✅ 제이엠아이(주)(00222435) - 데이터 수집 완료
# ✅ (주)신세계아이앤씨(00219486) - 데이터 수집 완료
# ✅ 진양폴리우레탄식회사(00160375) - 데이터 수집 완료
# ✅ 주식회사 대동스틸(00109268) - 데이터 수집 완료
# ✅ 주식회사 네오티스(00447928) - 데이터 수집 완료
# ✅ (주)코이즈(00807397) - 데이터 수집 완료
# ✅ 에이치에스디엔진(주)(00361008) - 데이터 수집 완료
# ✅ (주)티에스아이(01139035) - 데이터 수집 완료
# ✅ 주식회사 유진테크(00531014) - 데이터 수집 완료
# ✅ 주식회사 앤씨앤(00537337) - 데이터 수집 완료
# ✅ 주식회사 지놈앤컴퍼니(01276026) - 데이터 수집 완료
# ✅ (주)엔피디(00876643) - 데이터 수집 완료
# ✅ 주식회사 유진로봇(00234227) - 데이터 수집 완료
# ✅ 케이카 주식회사(01323032) - 데이터 수집 완료
# ✅ (주)에이텍(00256502) - 데이터 수집 완료
# ✅ (주)오스코텍(00263654) - 데이터 수집 완료
# ✅ 주식회사 모비데이즈(01493535) - 데이터 수집 완료
# ✅ 텔코웨어 주식회사(00361488) - 데이터 수집 완료
# ✅ 주식회사 루닛(01397620) - 데이터 수집 완료
# ✅ 주식회사 우리기술(00231044) - 데이터 수집 완료
# ✅ 소프트캠프(주)(01182408) - 데이터 수집 완료
# ✅ 주식회사 티에스넥스젠(00317487) - 데이터 수집 완료
# ✅ 주식회사 유일로보틱스(01152586) - 데이터 수집 완료
# ✅ 주식회사 레드캡투어(00261355) - 데이터 수집 완료
# ✅ 대동금속 주식회사(00191287) - 데이터 수집 완료
# ✅ 주식회사 리드코프(00117708) - 데이터 수집 완료
# ✅ (주)오이솔루션(00571483) - 데이터 수집 완료
# ✅ (주)한국경제티브이(00263371) - 데이터 수집 완료
# ✅ ㈜더네이쳐홀딩스(01214743) - 데이터 수집 완료
# ✅ 현대코퍼레이션 주식회사(00164812) - 데이터 수집 완료
# ✅ (주)넥스트칩(01515864) - 데이터 수집 완료
# ✅ 주식회사 나스미디어(00486097) - 데이터 수집 완료
# ✅ 주식회사 네오위즈홀딩스(00266952) - 데이터 수집 완료
# ✅ 주식회사 네오위즈(00628860) - 데이터 수집 완료
# ✅ (주)케이티아이에스(00372873) - 데이터 수집 완료
# ✅ 주식회사 에스코넥(00573269) - 데이터 수집 완료
# ✅ 주식회사 비엠티(00524786) - 데이터 수집 완료
# ✅ 주식회사 천보(00897752) - 데이터 수집 완료
# ✅ (주)현대이지웰(00656951) - 데이터 수집 완료
# ✅ (주)에이프릴바이오(01375822) - 데이터 수집 완료
# ✅ 주식회사 가온칩스(01364747) - 데이터 수집 완료
# ✅ 한전KPS(주)(00159218) - 데이터 수집 완료
# ✅ 엘에스마린솔루션 주식회사(00225742) - 데이터 수집 완료
# ✅ 코위버 주식회사(00360674) - 데이터 수집 완료
# ✅ (주)와이어블(00250137) - 데이터 수집 완료
# ✅ 주식회사 에스메디(00791209) - 데이터 수집 완료
# ✅ 주식회사 고바이오랩(01399071) - 데이터 수집 완료
# ✅ 주식회사 한국파마(00187770) - 데이터 수집 완료
# ✅ 영보화학 주식회사(00140779) - 데이터 수집 완료
# ✅ 주식회사 티에스이(00372226) - 데이터 수집 완료
# ✅ 주식회사 드림씨아이에스(00916826) - 데이터 수집 완료
# ✅ (주)그리티(00671978) - 데이터 수집 완료
# ✅ 주식회사 조비(00148948) - 데이터 수집 완료
# ✅ (주)브이씨(01354740) - 데이터 수집 완료
# ✅ (주)블루콤(00238001) - 데이터 수집 완료
# ✅ 에스엘 주식회사(00125521) - 데이터 수집 완료
# ✅ (주)와이오엠(00370200) - 데이터 수집 완료
# ✅ 대한해운(주)(00113535) - 데이터 수집 완료
# ✅ 주식회사 우정바이오(01065013) - 데이터 수집 완료
# ✅ HD현대에너지솔루션 주식회사(01199550) - 데이터 수집 완료
# ✅ 주식회사 쇼박스(00303794) - 데이터 수집 완료
# ✅ 한국선재(주)(00158015) - 데이터 수집 완료
# ✅ 현대무벡스 주식회사(01358463) - 데이터 수집 완료
# ✅ 동양철관 주식회사(00117629) - 데이터 수집 완료
# ✅ 램테크놀러지(주)(00654272) - 데이터 수집 완료
# ✅ ㈜컴투스(00476498) - 데이터 수집 완료
# ✅ ㈜헥토파이낸셜(00763701) - 데이터 수집 완료
# ✅ STX중공업 주식회사(00406046) - 데이터 수집 완료
# ✅ 주식회사 동서(00144395) - 데이터 수집 완료
# ✅ 주식회사 케이옥션(00668600) - 데이터 수집 완료
# ✅ 진양화학주식회사(00347734) - 데이터 수집 완료
# ✅ (주)파인디앤씨(00350020) - 데이터 수집 완료
# ✅ 상신브레이크(주)(00129642) - 데이터 수집 완료
# ✅ KB오토시스(00157539) - 데이터 수집 완료
# ✅ (주)백금티앤에이(00360036) - 데이터 수집 완료
# ✅ 주식회사 포커스에이치엔에스(01393721) - 데이터 수집 완료
# ✅ 주식회사 이글루코퍼레이션(00364847) - 데이터 수집 완료
# ✅ 주식회사 마음에이아이(01297898) - 데이터 수집 완료
# ✅ (주)탑코미디어(00608699) - 데이터 수집 완료
# ✅ 주식회사 이지(00261054) - 데이터 수집 완료
# ✅ 주식회사 신원(00136864) - 데이터 수집 완료
# ✅ 주식회사 엔투텍(01105621) - 데이터 수집 완료
# ✅ 주식회사 파인테크닉스(00755739) - 데이터 수집 완료
# ✅ 주식회사 다날(00389970) - 데이터 수집 완료
# ✅ 주식회사 아이즈비전(00200910) - 데이터 수집 완료
# ✅ 동국산업 주식회사(00172680) - 데이터 수집 완료
# ✅ 주식회사 코엔텍(00197476) - 데이터 수집 완료
# ✅ (주)서연(00163114) - 데이터 수집 완료
# ✅ 현대비앤지스틸주식회사(00125743) - 데이터 수집 완료
# ✅ 주식회사 기산텔레콤(00258421) - 데이터 수집 완료
# ✅ 주식회사 신성이엔지(00136271) - 데이터 수집 완료
# ✅ 주식회사 위메이드(00444329) - 데이터 수집 완료
# ✅ (주)위메이드플레이(00815767) - 데이터 수집 완료
# ✅ 주식회사 화신정공(00825223) - 데이터 수집 완료
# ✅ 주식회사 솔루엠(01159233) - 데이터 수집 완료
# ✅ (주)모비릭스(01210190) - 데이터 수집 완료
# ✅ 제이더블유신약 주식회사(00110431) - 데이터 수집 완료
# ✅ 주식회사 디엔에프(00569691) - 데이터 수집 완료
# ✅ 주식회사 피엔에이치테크(01112889) - 데이터 수집 완료
# ✅ 부국철강주식회사(00123781) - 데이터 수집 완료
# ✅ 주식회사 녹십자홀딩스(00108135) - 데이터 수집 완료
# ✅ 신원종합개발 주식회사(00136925) - 데이터 수집 완료
# ✅ 주식회사 펄어비스(01152470) - 데이터 수집 완료
# ✅ 에스넷시스템 주식회사(00264635) - 데이터 수집 완료
# ✅ 노바렉스 주식회사(00811372) - 데이터 수집 완료
# ✅ 주식회사 오리콤(00141671) - 데이터 수집 완료
# ✅ (주)디오(00115931) - 데이터 수집 완료
# ✅ 에이치엘비파나진 주식회사(00172079) - 데이터 수집 완료
# ✅ 주식회사 에프앤에프홀딩스(00126487) - 데이터 수집 완료
# ✅ 디케이락주식회사(00533003) - 데이터 수집 완료
# ✅ (주)인트론바이오테크놀로지(00292434) - 데이터 수집 완료
# ✅ 신송홀딩스 주식회사(00136402) - 데이터 수집 완료
# ✅ (주)머큐리(00364740) - 데이터 수집 완료
# ✅ (주)피피아이(00403766) - 데이터 수집 완료
# ✅ (주)윌비스(00104999) - 데이터 수집 완료
# ✅ 애니젠(주)(00808086) - 데이터 수집 완료
# ✅ (주)삼진(00173351) - 데이터 수집 완료
# ✅ 비비씨 주식회사(01153105) - 데이터 수집 완료
# ✅ 효성아이티엑스(주)(00414850) - 데이터 수집 완료
# ✅ (주)현대공업(00164502) - 데이터 수집 완료
# ✅ 한전산업개발 주식회사(00194947) - 데이터 수집 완료
# ✅ 정상제이엘에스(00287788) - 데이터 수집 완료
# ✅ (주)푸른기술(00537832) - 데이터 수집 완료
# ✅ (주)카스(00152260) - 데이터 수집 완료
# ✅ 성신양회(주)(00132804) - 데이터 수집 완료
# ✅ 티케이지휴켐스 주식회사(00426086) - 데이터 수집 완료
# ✅ 주식회사세아메카닉스(00534701) - 데이터 수집 완료
# ✅ 주식회사 라이프시맨틱스(01336762) - 데이터 수집 완료
# ✅ 대한방직 주식회사(00112970) - 데이터 수집 완료
# ✅ 주식회사 화신(00166315) - 데이터 수집 완료
# ✅ (주)예림당(00259934) - 데이터 수집 완료
# ✅ 에이치비솔루션(주)(00523936) - 데이터 수집 완료
# ✅ (주)아이컴포넌트(00407285) - 데이터 수집 완료
# ✅ 주식회사 에프에스티(00223434) - 데이터 수집 완료
# ✅ 주식회사 화승인더스트리(00166227) - 데이터 수집 완료
# ✅ (주)BYC(00122579) - 데이터 수집 완료
# ✅ 주식회사 넥슨게임즈(01096341) - 데이터 수집 완료
# ✅ 주식회사 화승엔터프라이즈(01128613) - 데이터 수집 완료
# ✅ 강남제비스코 주식회사(00100939) - 데이터 수집 완료
# ✅ (주)압타머사이언스(01265251) - 데이터 수집 완료
# ✅ (주)와이티엔(00200275) - 데이터 수집 완료
# ✅ (주)아모센스(01012987) - 데이터 수집 완료
# ✅ 삼양통상주식회사(00127042) - 데이터 수집 완료
# ✅ 고려제강 주식회사(00103006) - 데이터 수집 완료
# ✅ (주)피제이메탈(00829380) - 데이터 수집 완료
# ✅ 주식회사 도화엔지니어링(00114552) - 데이터 수집 완료
# ✅ (주)영림원소프트랩(00532129) - 데이터 수집 완료
# ✅ 주식회사 에이치케이(00235183) - 데이터 수집 완료
# ✅ 그랜드코리아레저(주)(00557508) - 데이터 수집 완료
# ✅ 주식회사 베셀(00813389) - 데이터 수집 완료
# ✅ 주식회사 자비스(01174038) - 데이터 수집 완료
# ✅ 주식회사 케이티알파(00260958) - 데이터 수집 완료
# ✅ (주)WISCOM(00142865) - 데이터 수집 완료
# ✅ 삼영엠텍(주)(00250614) - 데이터 수집 완료
# ✅ 주식회사 윈스(00868705) - 데이터 수집 완료
# ✅ 넥스트엔터테인먼트월드 주식회사(00974927) - 데이터 수집 완료
# ✅ 주식회사 핌스(01405390) - 데이터 수집 완료
# ✅ 주식회사 신화콘텍(00925189) - 데이터 수집 완료
# ✅ (주)케이엘넷(00246620) - 데이터 수집 완료
# ✅ (주)한독크린텍(01069736) - 데이터 수집 완료
# ✅ (주)드림어스컴퍼니(00364467) - 데이터 수집 완료
# ✅ 다스코(주)(00353878) - 데이터 수집 완료
# ✅ (주)푸드나무(01259311) - 데이터 수집 완료
# ✅ 한국전력기술 주식회사(00159209) - 데이터 수집 완료
# ✅ 주식회사 플레이그램(00103130) - 데이터 수집 완료
# ✅ 주식회사 시디즈(00852087) - 데이터 수집 완료
# ✅ 비에이치아이 주식회사(00409788) - 데이터 수집 완료
# ✅ 주식회사 파인디지털(00264732) - 데이터 수집 완료
# ✅ 이건산업(주)(00145446) - 데이터 수집 완료
# ✅ 삼진제약 주식회사(00128412) - 데이터 수집 완료
# ✅ 엔브이에이치코리아 주식회사(00146436) - 데이터 수집 완료
# ✅ 주식회사 잉크테크(00261656) - 데이터 수집 완료
# ✅ 한창산업주식회사(00202839) - 데이터 수집 완료
# ✅ (주)링크제니시스(01109955) - 데이터 수집 완료
# ✅ 주식회사 오로스테크놀로지(01016479) - 데이터 수집 완료
# ✅ 더이앤엠 주식회사(00519252) - 데이터 수집 완료
# ✅ 에스티팜 주식회사(00871833) - 데이터 수집 완료
# ✅ 한라아이엠에스주식회사(00528515) - 데이터 수집 완료
# ✅ 주식회사 한국화장품제조(00160621) - 데이터 수집 완료
# ✅ 성우테크론 주식회사(00350482) - 데이터 수집 완료
# ✅ (주)에프앤가이드(00331016) - 데이터 수집 완료
# ✅ 화천기공(주)(00166519) - 데이터 수집 완료
# ✅ (주)에스제이그룹(01222432) - 데이터 수집 완료
# ✅ 주식회사 엔텔스(00415707) - 데이터 수집 완료
# ✅ 주식회사 이건홀딩스(00184889) - 데이터 수집 완료
# ✅ SK바이오팜(주)(00878696) - 데이터 수집 완료
# ✅ 한국주강주식회사(00159564) - 데이터 수집 완료
# ✅ 서울전자통신(주)(00130587) - 데이터 수집 완료
# ✅ 주식회사 한국가구(00156442) - 데이터 수집 완료
# ✅ 동아화성 주식회사(00199988) - 데이터 수집 완료
# ✅ 주식회사 예스코홀딩스(00105101) - 데이터 수집 완료
# ✅ 주식회사레인보우로보틱스(01261644) - 데이터 수집 완료
# ✅ 주식회사 풍산홀딩스(00155531) - 데이터 수집 완료
# ✅ 네이버(주)(00266961) - 데이터 수집 완료
# ✅ 주식회사 삼성출판사(00423690) - 데이터 수집 완료
# ✅ 메디포스트 주식회사(00453929) - 데이터 수집 완료
# ✅ 한솔홀딩스주식회사(00171636) - 데이터 수집 완료
# ✅ 유니퀘스트 주식회사(00414601) - 데이터 수집 완료
# ✅ 한국가스공사(주)(00261285) - 데이터 수집 완료
# ✅ 한국전력공사(00159193) - 데이터 수집 완료
# ✅ 포스코홀딩스(주)(00155319) - 데이터 수집 완료
# ✅ 덕산네오룩스(주)(01061558) - 데이터 수집 완료
# ✅ 한국지역난방공사(00159698) - 데이터 수집 완료
# ✅ 한솔제지주식회사(01060744) - 데이터 수집 완료
# ✅ (주)풍산(00684714) - 데이터 수집 완료
# ✅ 삼성전기(주)(00126371) - 데이터 수집 완료
# ✅ (주)카카오게임즈(01137383) - 데이터 수집 완료
# ✅ 현대건설(주)(00164478) - 데이터 수집 완료
# ✅ 두산에너빌리티주식회사(00159616) - 데이터 수집 완료
# ✅ 에스디바이오센서(주)(00854997) - 데이터 수집 완료
# ✅ 삼성중공업(00126478) - 데이터 수집 완료
# ✅ 평화산업(주)(00573579) - 데이터 수집 완료
# ✅ 롯데웰푸드(주)(01258507) - 데이터 수집 완료
# ✅ (주)대우건설(00124540) - 데이터 수집 완료
# ✅ 아세아제지(주)(00138729) - 데이터 수집 완료
# ✅ 주식회사 케이씨씨 글라스(01428203) - 데이터 수집 완료
# ✅ 현대로템 주식회사(00302926) - 데이터 수집 완료
# ✅ 주식회사 하이브(01204056) - 데이터 수집 완료
# ✅ (주)하이스틸(00435312) - 데이터 수집 완료
# ✅ 현대제철 주식회사(00145880) - 데이터 수집 완료
# ✅ 현대글로비스 주식회사(00360595) - 데이터 수집 완료
# ✅ 주식회사 비트컴퓨터(00231707) - 데이터 수집 완료
# ✅ 디엘이앤씨 주식회사(01524093) - 데이터 수집 완료
# ✅ 피에스케이홀딩스 주식회사(00208444) - 데이터 수집 완료
# ✅ 에스케이스퀘어 주식회사(01596425) - 데이터 수집 완료
# ✅ 주식회사 엔씨소프트(00261443) - 데이터 수집 완료
# ✅ 현대모비스주식회사(00164788) - 데이터 수집 완료
# ✅ 코웨이(주)(00170558) - 데이터 수집 완료
# ✅ 에스씨아이평가정보 주식회사(00260745) - 데이터 수집 완료
# ✅ (주)케이티스카이라이프(00349097) - 데이터 수집 완료
# ✅ 롯데칠성음료 주식회사(00120571) - 데이터 수집 완료
# ✅ 주식회사 현대백화점(00428251) - 데이터 수집 완료
# ✅ (주)원익머트리얼즈(00623661) - 데이터 수집 완료
# ✅ 주식회사 지에스리테일(00140177) - 데이터 수집 완료
# ✅ 넷마블 주식회사(00904672) - 데이터 수집 완료
# ✅ (주)웨이브일렉트로닉스(00526696) - 데이터 수집 완료
# ✅ (주)포스코인터내셔널(00124504) - 데이터 수집 완료
# ✅ SK가스(주)(00144164) - 데이터 수집 완료
# ✅ 에스케이디스커버리(주)(00131832) - 데이터 수집 완료
# ✅ (주)한독(00161046) - 데이터 수집 완료
# ✅ SK바이오사이언스 주식회사(01319899) - 데이터 수집 완료
# ✅ (주)한진칼(00983040) - 데이터 수집 완료
# ✅ 주식회사 에이치제이중공업(00633835) - 데이터 수집 완료
# ✅ (주)웅진씽크빅(00628189) - 데이터 수집 완료
# ✅ (주)시스웍(01188378) - 데이터 수집 완료
# ✅ 주식회사 슈피겐코리아(00917861) - 데이터 수집 완료
# ✅ 메가스터디교육(주)(01074862) - 데이터 수집 완료
# ✅ 에이팩트(00667425) - 데이터 수집 완료
# ✅ 아세아(주)(00138701) - 데이터 수집 완료
# ✅ 주식회사  오뚜기(00141529) - 데이터 수집 완료
# ✅ 아세아시멘트 주식회사(00990165) - 데이터 수집 완료
# ✅ (주)뷰웍스(00609324) - 데이터 수집 완료
# ✅ 에이텍모빌리티(01099861) - 데이터 수집 완료
# ✅ 아시아나항공(주)(00138792) - 데이터 수집 완료
# ✅ 자화전자(주)(00146861) - 데이터 수집 완료
# ✅ 오씨아이홀딩스 주식회사(00148896) - 데이터 수집 완료
# ✅ (주)LF(00593032) - 데이터 수집 완료
# ✅ 금호타이어(주)(00481454) - 데이터 수집 완료
# ✅ 주식회사 포스코엠텍(00128111) - 데이터 수집 완료
# ✅ 주식회사 대웅(00111810) - 데이터 수집 완료
# ✅ 주식회사 대웅제약(00427483) - 데이터 수집 완료
# ✅ 현대코퍼레이션홀딩스 주식회사(01108099) - 데이터 수집 완료
# ✅ 주식회사 루멘스(00406329) - 데이터 수집 완료
# ✅ 화일약품 주식회사(00188973) - 데이터 수집 완료
# ✅ 한올바이오파마 주식회사(00162586) - 데이터 수집 완료
# ✅ (주)보령(00123143) - 데이터 수집 완료
# ✅ 주식회사 서린바이오(00373447) - 데이터 수집 완료
# ✅ 주식회사 랩지노믹스(00545114) - 데이터 수집 완료
# ✅ 주식회사 유비쿼스홀딩스(00411385) - 데이터 수집 완료
# ✅ 대한제강 주식회사(00113225) - 데이터 수집 완료
# ✅ 주식회사 월덱스(00580065) - 데이터 수집 완료
# ✅ 주식회사 삼원강재(00191588) - 데이터 수집 완료
# ✅ 미원홀딩스 주식회사(00706715) - 데이터 수집 완료
# ✅ 주식회사 동남합성(00115065) - 데이터 수집 완료
# ✅ 대화제약(00210740) - 데이터 수집 완료
# ✅ 디와이파워주식회사(01059605) - 데이터 수집 완료
# ✅ 태경산업  주식회사(00153339) - 데이터 수집 완료
# ✅ 주식회사 사람인(00857480) - 데이터 수집 완료
# ✅ (주)씨젠(00788773) - 데이터 수집 완료
# ✅ 주식회사 진양홀딩스(00646732) - 데이터 수집 완료
# ✅ 롯데하이마트(주)(00158307) - 데이터 수집 완료
# ✅ 디엑스앤브이엑스(주)(00995993) - 데이터 수집 완료
# ✅ 주식회사 화인베스틸(00661847) - 데이터 수집 완료
# ✅ 주식회사 대호에이엘(00428729) - 데이터 수집 완료
# ✅ 마니커(00204208) - 데이터 수집 완료
# ✅ 진양산업 주식회사(00150439) - 데이터 수집 완료
# ✅ (주)더코디(00530413) - 데이터 수집 완료
# ✅ (주)우리로(00296005) - 데이터 수집 완료
# ✅ 데이터 저장 완료: 기업_재무제표_2023년_L4.xlsx, 기업_재무제표_2023년_L4.xlsx

# %% [markdown]
# #
# :------------------------------------------------------------------------------L5------------------------------------

# %%
import requests
import pandas as pd
import time

# DART API 인증키 (본인의 API 키 입력)
API_KEY = '85006d20472a255d5eae25ee265b5ed1b78d1386'

# DART 재무제표 API URL
FS_URL = "https://opendart.fss.or.kr/api/fnlttSinglAcntAll.json"

# 기업 리스트 엑셀 파일 읽기
file_path = "./corp_list_split.xlsx"  # 로컬 파일 경로
corporations_df = pd.read_excel(file_path, sheet_name="L5", dtype={'code': str})

# 데이터 저장을 위한 리스트
financial_data = []

# 자본변동표 관련 계정과목 필터링 리스트
exclude_accounts = [
    "자본금 변동", "기타포괄손익누계액", "이익잉여금 변동",
    "자본총계 변동", "기타자본항목 변동", "배당금 지급", "주식발행", "자본조정"
]

# 자본 관련 항목 리스트 (우선 재무상태표 항목을 우선하고, 없는 경우 첫 번째로 나온 항목 선택)
capital_related_accounts = ["자본총계", "기초자본", "자본금", "이익잉여금", "기타자본항목"]

# 기업별 재무제표 요청
for _, row in corporations_df.iterrows():
    corp_code = row['code']  # 기업 코드
    corp_name = row.get('name', '알 수 없음')  # 기업 이름

    params = {
        'crtfc_key': API_KEY,
        'corp_code': corp_code,
        'bsns_year': 2023,  # 연도
        'reprt_code': '11011',  # 사업보고서 (연결 재무제표)
        'fs_div': 'OFS'  # 개별 재무제표 (자본변동표 포함 X)
    }

    try:
        # API 요청
        response = requests.get(FS_URL, params=params, timeout=10)
        response.raise_for_status()
        data = response.json()

        if data.get('status') == '000':  # 정상 응답
            if 'list' in data and data['list']:
                unique_accounts = set()  # 중복 방지를 위한 set
                first_appearance_accounts = []  # 첫 번째로 나온 항목을 저장할 리스트

                for item in data['list']:
                    account_name = item['account_nm'].strip()
                    account_id = item.get('account_id', '데이터 없음')  # account_id 추가

                    # 자본변동표 관련 항목 제외
                    if any(excl in account_name for excl in exclude_accounts):
                        continue

                    # 자본 관련 계정 처리: 재무상태표에 있는 항목을 우선하고, 없으면 첫 번째 항목 사용
                    if any(account_name.startswith(capital_account) for capital_account in capital_related_accounts):
                        # 재무상태표에 있는 자본 항목을 우선 처리
                        if account_name not in unique_accounts:
                            unique_accounts.add(account_name)
                            financial_data.append({
                                "기업 이름": corp_name,
                                "기업 코드": corp_code,
                                "연도": 2023,
                                "계정과목명": account_name,
                                "account_id": account_id,  # account_id 추가
                                "금액": item.get('thstrm_amount', '데이터 없음'),  # 2023년 금액
                                "2022년 금액": item.get('frmtrm_amount', '데이터 없음'),  # 2022년 금액
                                "2021년 금액": item.get('lfy_amount', '데이터 없음')  # 2021년 금액
                            })
                    else:
                        # 첫 번째로 나온 자본 관련 항목을 선택하여 추가
                        if account_name not in first_appearance_accounts:
                            first_appearance_accounts.append(account_name)
                            financial_data.append({
                                "기업 이름": corp_name,
                                "기업 코드": corp_code,
                                "연도": 2023,
                                "계정과목명": account_name,
                                "account_id": account_id,  # account_id 추가
                                "금액": item.get('thstrm_amount', '데이터 없음'),  # 2023년 금액
                                "2022년 금액": item.get('frmtrm_amount', '데이터 없음'),  # 2022년 금액
                                "2021년 금액": item.get('lfy_amount', '데이터 없음')  # 2021년 금액
                            })

                print(f"✅ {corp_name}({corp_code}) - 데이터 수집 완료")
            else:
                print(f"⚠️ {corp_name}({corp_code}) - 재무 데이터 없음")
        else:
            print(f"❌ {corp_name}({corp_code}) - API 오류: {data.get('message', '알 수 없는 오류')}")

    except requests.exceptions.RequestException as e:
        print(f"🚨 {corp_name}({corp_code}) - 요청 실패: {e}")

    time.sleep(1)  # API 요청 간격 조정

# DataFrame 변환
df_5 = pd.DataFrame(financial_data)

# 결과 저장
output_excel = "기업_재무제표_2023년_L5.xlsx"

df_5.to_excel(output_excel, index=False)

print(f"✅ 데이터 저장 완료: {output_excel}, {output_excel}")
# Out:
# ✅ 주식회사 디티앤씨(00675594) - 데이터 수집 완료
# ✅ 덕산하이메탈 주식회사(00471068) - 데이터 수집 완료
# ✅ 주식회사 현대리바트(00300548) - 데이터 수집 완료
# ✅ KPX케미칼 주식회사(00191472) - 데이터 수집 완료
# ✅ 에어부산 주식회사(00651901) - 데이터 수집 완료
# ✅ KPX홀딩스 주식회사(00587466) - 데이터 수집 완료
# ✅ 케이에이치필룩스 주식회사(00193009) - 데이터 수집 완료
# ✅ 주식회사 에코바이브(00108065) - 데이터 수집 완료
# ✅ (주)비츠로시스(00201432) - 데이터 수집 완료
# ✅ (주)SG세계물산(00133511) - 데이터 수집 완료
# ✅ (주)와이지엔터테인먼트(00613318) - 데이터 수집 완료
# ✅ 세종공업주식회사(00134510) - 데이터 수집 완료
# ✅ 디씨엠 주식회사(00177199) - 데이터 수집 완료
# ✅ AK홀딩스(주)(00125080) - 데이터 수집 완료
# ✅ (주)서진오토모티브(00800145) - 데이터 수집 완료
# ✅ 옴니시스템 주식회사(00265005) - 데이터 수집 완료
# ✅ 주식회사 메디톡스(00580199) - 데이터 수집 완료
# ✅ 영화금속 주식회사(00141413) - 데이터 수집 완료
# ✅ 가온그룹㈜(00441304) - 데이터 수집 완료
# ✅ (주)수산중공업(00135111) - 데이터 수집 완료
# ✅ (주)에프엔씨엔터테인먼트(00925295) - 데이터 수집 완료
# ✅ 주식회사 케이엠(00242934) - 데이터 수집 완료
# ✅ 주식회사 케이지모빌리언스(00405278) - 데이터 수집 완료
# ✅ 부광약품(주)(00123718) - 데이터 수집 완료
# ✅ 사조산업 주식회사(00124799) - 데이터 수집 완료
# ✅ 태양금속공업 주식회사(00153755) - 데이터 수집 완료
# ✅ 주식회사 이랜텍(00206659) - 데이터 수집 완료
# ✅ ㈜예스티(00530556) - 데이터 수집 완료
# ✅ (주)키이스트(00353762) - 데이터 수집 완료
# ✅ 조광페인트 주식회사(00148920) - 데이터 수집 완료
# ✅ CS홀딩스주식회사(00149026) - 데이터 수집 완료
# ✅ 조선선재주식회사(00796994) - 데이터 수집 완료
# ✅ (주)엠디에스테크(00445841) - 데이터 수집 완료
# ✅ DSR제강주식회사(00151298) - 데이터 수집 완료
# ✅ 어보브반도체 주식회사(00591441) - 데이터 수집 완료
# ✅ (주)셀리버리(01182444) - 데이터 수집 완료
# ✅ 주식회사 유아이디(00400121) - 데이터 수집 완료
# ✅ 주식회사 코스나인(00442455) - 데이터 수집 완료
# ✅ 광동제약주식회사(00103592) - 데이터 수집 완료
# ✅ (주)씨제이이엔엠(00265324) - 데이터 수집 완료
# ✅ (주)육일씨엔에쓰(00843900) - 데이터 수집 완료
# ✅ 주식회사 이노와이어리스(00462121) - 데이터 수집 완료
# ✅ (주)비상교육(00520887) - 데이터 수집 완료
# ✅ 화천기계 주식회사(00166500) - 데이터 수집 완료
# ✅ (주)코아시아씨엠(01031502) - 데이터 수집 완료
# ✅ 대양전기공업(주)(00111193) - 데이터 수집 완료
# ✅ 삼화페인트공업(주)(00129387) - 데이터 수집 완료
# ✅ 코스맥스엔비티 주식회사(00656289) - 데이터 수집 완료
# ✅ 웰킵스하이텍 주식회사(00260611) - 데이터 수집 완료
# ✅ 주식회사 티플랙스(00497631) - 데이터 수집 완료
# ✅ (주)웰크론한텍(00487546) - 데이터 수집 완료
# ✅ 주식회사 쏠리드(00364403) - 데이터 수집 완료
# ✅ 한국알콜산업 주식회사(00158565) - 데이터 수집 완료
# ✅ 주식회사 에이디테크놀로지(00657002) - 데이터 수집 완료
# ✅ (주)케이탑자기관리부동산투자회사(00861076) - 데이터 수집 완료
# ✅ (주)체리부로(00216434) - 데이터 수집 완료
# ✅ 오상자이엘 주식회사(00226547) - 데이터 수집 완료
# ✅ 주식회사 슈프리마에이치큐(00599957) - 데이터 수집 완료
# ✅ (주)LG유플러스(00231363) - 데이터 수집 완료
# ✅ 휴림로봇(주)(00540429) - 데이터 수집 완료
# ✅ 주식회사 클라우드에어(00232821) - 데이터 수집 완료
# ✅ ㈜코아시아(00271501) - 데이터 수집 완료
# ✅ 코오롱플라스틱 주식회사(00241005) - 데이터 수집 완료
# ✅ 우원개발 주식회사(00363246) - 데이터 수집 완료
# ✅ (주)동방선기(00526678) - 데이터 수집 완료
# ✅ JW홀딩스(주)(00632304) - 데이터 수집 완료
# ✅ 주식회사 휴맥스홀딩스(00219440) - 데이터 수집 완료
# ✅ 주식회사 CMG제약(00380429) - 데이터 수집 완료
# ✅ 주식회사 아이엠(00609634) - 데이터 수집 완료
# ✅ 대상홀딩스 주식회사(00539274) - 데이터 수집 완료
# ✅ 주식회사 아이에이(00252269) - 데이터 수집 완료
# ✅ 주식회사 와이엔텍(00190756) - 데이터 수집 완료
# ✅ 일양약품(주)(00146454) - 데이터 수집 완료
# ✅ (주)비지에프(00219097) - 데이터 수집 완료
# ✅ 메디앙스(주)(00267854) - 데이터 수집 완료
# ✅ (주)제우스(00442570) - 데이터 수집 완료
# ✅ ㈜세아특수강(00133991) - 데이터 수집 완료
# ✅ (주)디스플레이테크(00371740) - 데이터 수집 완료
# ✅ (주)유니드(00159786) - 데이터 수집 완료
# ✅ (주)세아제강지주(00124197) - 데이터 수집 완료
# ✅ 씨에스윈드(주)(00670340) - 데이터 수집 완료
# ✅ 주식회사 디에이피(00303192) - 데이터 수집 완료
# ✅ (주)한샘(00161693) - 데이터 수집 완료
# ✅ (주)쎄노텍(01091054) - 데이터 수집 완료
# ✅ 주식회사 비비안(00107677) - 데이터 수집 완료
# ✅ (주)고려시멘트(01032583) - 데이터 수집 완료
# ✅ 코리아에프티 주식회사(00803425) - 데이터 수집 완료
# ✅ 주식회사테크윙(00535676) - 데이터 수집 완료
# ✅ 주식회사 퍼시스(00161709) - 데이터 수집 완료
# ✅ 주식회사 하림(00857727) - 데이터 수집 완료
# ✅ 시그네틱스(00158219) - 데이터 수집 완료
# ✅ 한국콜마주식회사(00939331) - 데이터 수집 완료
# ✅ (주)엘엑스하우시스(00759513) - 데이터 수집 완료
# ✅ (주)비츠로셀(00154718) - 데이터 수집 완료
# ✅ 하나마이크론 주식회사(00445054) - 데이터 수집 완료
# ✅ (주)노루홀딩스(00113508) - 데이터 수집 완료
# ✅ 한일철강㈜(00163196) - 데이터 수집 완료
# ✅ (주)노루페인트(00583442) - 데이터 수집 완료
# ✅ (주)엠에스씨(00121154) - 데이터 수집 완료
# ✅ 주식회사 백산(00122551) - 데이터 수집 완료
# ✅ 한국유니온제약 주식회사(00532855) - 데이터 수집 완료
# ✅ 주식회사 아이엘사이언스(01326279) - 데이터 수집 완료
# ✅ 주식회사 폴라리스오피스(00269852) - 데이터 수집 완료
# ✅ 에이치엘비테라퓨틱스(주)(00552859) - 데이터 수집 완료
# ✅ 서울식품공업(주)(00130879) - 데이터 수집 완료
# ✅ 동일산업 주식회사(00172936) - 데이터 수집 완료
# ✅ 주식회사 세이브존아이앤씨(00422895) - 데이터 수집 완료
# ✅ 주식회사 메디프론디비티(00391197) - 데이터 수집 완료
# ✅ 주식회사 대창스틸(00112721) - 데이터 수집 완료
# ✅ 주식회사 에스에너지(00585538) - 데이터 수집 완료
# ✅ 주식회사 에스지엔지(00264714) - 데이터 수집 완료
# ✅ 주식회사 서산(00130408) - 데이터 수집 완료
# ✅ 주식회사 팜스코(00260408) - 데이터 수집 완료
# ✅ 주식회사 세아제강(01325979) - 데이터 수집 완료
# ✅ (주)농심홀딩스(00459871) - 데이터 수집 완료
# ✅ 엔시트론 주식회사(00641393) - 데이터 수집 완료
# ✅ (주)풀무원(00155355) - 데이터 수집 완료
# ✅ 주식회사 심텍(01095722) - 데이터 수집 완료
# ✅ 한미반도체 주식회사(00161383) - 데이터 수집 완료
# ✅ 주식회사 디지틀조선일보(00231442) - 데이터 수집 완료
# ✅ JW생명과학(주)(00225706) - 데이터 수집 완료
# ✅ (주)벽산(00122898) - 데이터 수집 완료
# ✅ 디엘건설 주식회사(00128971) - 데이터 수집 완료
# ✅ 한세예스24홀딩스㈜(00161976) - 데이터 수집 완료
# ✅ 한세실업 주식회사(00728638) - 데이터 수집 완료
# ✅ 주식회사 엘오티베큠(00484682) - 데이터 수집 완료
# ✅ 에이치엘비제약 주식회사(00336817) - 데이터 수집 완료
# ✅ 주식회사창해에탄올(00123523) - 데이터 수집 완료
# ✅ (주)태경비케이(00122481) - 데이터 수집 완료
# ✅ 대한광통신 주식회사(00113261) - 데이터 수집 완료
# ✅ 한솔아이원스 주식회사(00625942) - 데이터 수집 완료
# ✅ 주식회사 동방아그로(00115384) - 데이터 수집 완료
# ✅ (주)시큐브(00402110) - 데이터 수집 완료
# ✅ 주식회사 에이프로젠(00152385) - 데이터 수집 완료
# ✅ (주)테크엘(00370255) - 데이터 수집 완료
# ✅ 주식회사 지엔코(00258102) - 데이터 수집 완료
# ✅ (주) 클래시스(01061327) - 데이터 수집 완료
# ✅ 일진디스플레이(00198697) - 데이터 수집 완료
# ✅ 주식회사 썸에이지(01049422) - 데이터 수집 완료
# ✅ (주)에스피씨삼립(00125530) - 데이터 수집 완료
# ✅ 세기상사 주식회사(00133618) - 데이터 수집 완료
# ✅ 주식회사 고영테크놀러지(00579999) - 데이터 수집 완료
# ✅ 주식회사 인터플렉스(00369170) - 데이터 수집 완료
# ✅ 주식회사 세중(00264671) - 데이터 수집 완료
# ✅ (주)좋은사람들(00205003) - 데이터 수집 완료
# ✅ 인터지스 주식회사(00151368) - 데이터 수집 완료
# ✅ (주)지니틱스(01318933) - 데이터 수집 완료
# ✅ 주식회사 협진(00808068) - 데이터 수집 완료
# ✅ 제이씨케미칼 주식회사(00664853) - 데이터 수집 완료
# ✅ 비디아이 주식회사(00610490) - 데이터 수집 완료
# ✅ 콜마비앤에이치(주)(01032404) - 데이터 수집 완료
# ✅ 한국화장품 주식회사(00823429) - 데이터 수집 완료
# ✅ 엘지이노텍 주식회사(00105961) - 데이터 수집 완료
# ✅ (주)스마트솔루션즈(00763358) - 데이터 수집 완료
# ✅ 주식회사 와이지-원(00139719) - 데이터 수집 완료
# ✅ 주식회사 파루(00266934) - 데이터 수집 완료
# ✅ 피에스텍 주식회사(00155638) - 데이터 수집 완료
# ✅ 주식회사 성안(00132868) - 데이터 수집 완료
# ✅ 주식회사 상아프론테크(00181299) - 데이터 수집 완료
# ✅ (주)세아베스틸지주(00106669) - 데이터 수집 완료
# ✅ (주)세아홀딩스(00377610) - 데이터 수집 완료
# ✅ 주식회사 모베이스전자(00137234) - 데이터 수집 완료
# ✅ 주식회사 디에스이엔 (舊.주식회사 엠피대산)(00390860) - 데이터 수집 완료
# ✅ 주식회사 서흥(00131692) - 데이터 수집 완료
# ✅ 주식회사 태웅(00186799) - 데이터 수집 완료
# ✅ 주식회사 에스피지(00220686) - 데이터 수집 완료
# ✅ 주식회사 이미지스테크놀로지(00694942) - 데이터 수집 완료
# ✅ 인선이엔티 주식회사(00375931) - 데이터 수집 완료
# ✅ 동양파일 주식회사(00993931) - 데이터 수집 완료
# ✅ 그린케미칼(주)(00454946) - 데이터 수집 완료
# ✅ 주식회사 세우글로벌(00134176) - 데이터 수집 완료
# ✅ 국도화학 주식회사(00104388) - 데이터 수집 완료
# ✅ 주식회사 아이디스(00883980) - 데이터 수집 완료
# ✅ 대아티아이(주)(00318316) - 데이터 수집 완료
# ✅ 주식회사 삼익악기(00127857) - 데이터 수집 완료
# ✅ (주)셀트리온제약(00541349) - 데이터 수집 완료
# ✅ 주식회사 휴비스(00362238) - 데이터 수집 완료
# ✅ (주)로보스타(00536523) - 데이터 수집 완료
# ✅ 제주맥주(주)(01230255) - 데이터 수집 완료
# ✅ 주식회사 내츄럴엔도텍(00923792) - 데이터 수집 완료
# ✅ 주식회사 탑엔지니어링(00366845) - 데이터 수집 완료
# ❌ 비케이탑스(00273615) - API 오류: 조회된 데이타가 없습니다.
# ✅ 이즈미디어(00861720) - 데이터 수집 완료
# ❌ 코원플레이(00361266) - API 오류: 조회된 데이타가 없습니다.
# ✅ 이오플로우 주식회사(01274310) - 데이터 수집 완료
# ✅ 주식회사 에이엔피(00143314) - 데이터 수집 완료
# ✅ 주식회사 국보디자인(00253985) - 데이터 수집 완료
# ✅ 주식회사 나노엔텍(00230425) - 데이터 수집 완료
# ✅ (주)포스코퓨처엠(00155276) - 데이터 수집 완료
# ✅ 데이터 저장 완료: 기업_재무제표_2023년_L5.xlsx, 기업_재무제표_2023년_L5.xlsx

# %%
df_fn = pd.concat([df_1,df_2,df_3,df_4,df_5])
df_fn.to_excel('상장법인재무제표_중복제거.xlsx')
