# %% [markdown]
# <a href="https://colab.research.google.com/github/Tom-Jung/Tom-Jung/blob/main/API_DART.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas as pd

# DART API 키 입력
API_KEY = "85006d20472a255d5eae25ee265b5ed1b78d1386"

# 재무제표 요청 URL
BASE_URL = "https://opendart.fss.or.kr/api/fnlttSinglAcntAll.json"

# %%
def get_financial_statement(corp_code: str, year: str, fs_div: str = "CFS"):
    """
    DART API를 통해 재무제표 데이터를 가져오는 함수
    :param corp_code: DART 시스템의 고유 회사 코드
    :param year: 조회 연도 (예: 2022)
    :param fs_div: 재무제표 구분 (CFS: 연결, OFS: 개별)
    :return: DataFrame 형태의 재무제표 데이터
    """
    params = {
        "crtfc_key": API_KEY,
        "corp_code": corp_code,
        "bsns_year": year,
        "reprt_code": "11013",  # 11011: 사업보고서
        "fs_div": fs_div
    }

    # API 요청
    response = requests.get(BASE_URL, params=params)
    data = response.json()

    if data['status'] != '000':
        print(f"API 오류: {data['message']}")
        return None

    # JSON 데이터를 DataFrame으로 변환
    reports = data['list']
    df = pd.DataFrame(reports)

    # 주요 컬럼 확인 및 데이터 정리
    expected_columns = ['sj_nm', 'account_nm', 'thstrm_amount', 'frmtrm_amount', 'bfefrmtrm_amount']
    available_columns = [col for col in expected_columns if col in df.columns]

    if not available_columns:
        print("유효한 재무제표 데이터가 없습니다.")
        return None

    df = df[available_columns]

    # 컬럼 이름 매핑
    column_mapping = {
        'sj_nm': '재무제표명',
        'account_nm': '계정명',
        'thstrm_amount': '당기 금액',
        'frmtrm_amount': '전기 금액',
        'bfefrmtrm_amount': '전전기 금액'
    }
    df.rename(columns=column_mapping, inplace=True)

    # 결측값 및 데이터 정제
    df.replace('', '0', inplace=True)
    numeric_columns = ['당기 금액', '전기 금액', '전전기 금액']
    for col in numeric_columns:
        if col in df.columns:
            df[col] = pd.to_numeric(df[col])

    return df

# 예제 실행: 삼성전자(00126380) 2022년 재무제표 가져오기
corp_code = "00126380"  # DART에서 제공하는 회사 코드
year = "2022"
financial_data = get_financial_statement(corp_code, year)

if financial_data is not None:
    print(financial_data)
    # 엑셀로 저장
    financial_data.to_excel("financial_statement.xlsx", index=False)
# Out:
#      재무제표명              계정명            당기 금액         전기 금액
# 0    재무상태표             유동자산  232369082000000  2.181632e+14
# 1    재무상태표         현금및현금성자산   48944982000000  3.903142e+13
# 2    재무상태표           단기금융상품   75121426000000  8.170899e+13
# 3    재무상태표      단기상각후원가금융자산    1755225000000  3.369034e+12
# 4    재무상태표  단기당기손익-공정가치금융자산      53056000000  4.075700e+10
# ..     ...              ...              ...           ...
# 169  자본변동표             기말자본    -652689000000           NaN
# 170  자본변동표             기말자본  306391870000000           NaN
# 171  자본변동표             기말자본    8899049000000           NaN
# 172  자본변동표             기말자본  315290919000000           NaN
# 173  자본변동표             기말자본  301743152000000           NaN
#
# [174 rows x 4 columns]

# %%
# 손익계산서의 매출액, 매출원가, 판관비, 영업손익만 추출

# 재무제표 요청 URL
BASE_URL = "https://opendart.fss.or.kr/api/fnlttSinglAcntAll.json"

def get_filtered_financial_statement(corp_code: str, year: str, fs_div: str = "CFS"):
    """
    손익계산서에서 매출액, 매출원가, 판관비, 영업손익만 추출하는 함수
    """
    params = {
        "crtfc_key": API_KEY,
        "corp_code": corp_code,
        "bsns_year": year,
        "reprt_code": "11011",  # 11011: 사업보고서
        "fs_div": fs_div
    }

    # API 요청
    response = requests.get(BASE_URL, params=params)
    data = response.json()

    if data['status'] != '000':
        print(f"API 오류: {data['message']}")
        return None

    # JSON 데이터를 DataFrame으로 변환
    reports = data['list']
    df = pd.DataFrame(reports)

    # 손익계산서 항목 필터링 조건
    target_accounts = ["매출액", "매출원가", "판매비와관리비", "영업이익"]

    # 필요한 컬럼만 추출
    if not df.empty:
        df = df[df['account_nm'].isin(target_accounts)]
        df = df[['sj_nm', 'account_nm', 'thstrm_amount', 'frmtrm_amount']]

        # 컬럼 이름 매핑
        df.columns = ['재무제표명', '계정명', '당기 금액', '전기 금액']

        # 결측값 및 데이터 정제
        df.replace('', '0', inplace=True)
        df[['당기 금액', '전기 금액']] = df[['당기 금액', '전기 금액']].apply(pd.to_numeric)

    return df

# 예제 실행: 삼성전자(00126380) 2022년 손익계산서 주요 항목 추출
corp_code = "00126380"  # DART에서 제공하는 회사 코드
year = "2022"
filtered_financial_data = get_filtered_financial_statement(corp_code, year)

if filtered_financial_data is not None:
    print(filtered_financial_data)
    # 엑셀로 저장
    filtered_financial_data.to_excel("income_statement_filtered.xlsx", index=False)
# Out:
#     재무제표명      계정명            당기 금액            전기 금액
# 54  손익계산서     매출원가  190041770000000  166411342000000
# 56  손익계산서  판매비와관리비   68812960000000   61559601000000
# 57  손익계산서     영업이익   43376630000000   51633856000000

# %%
import requests
import pandas as pd
import xml.etree.ElementTree as ET
import os

# API 키 입력
API_KEY = "85006d20472a255d5eae25ee265b5ed1b78d1386"

# 기업 코드 요청 URL
CORP_CODE_URL = f"https://opendart.fss.or.kr/api/corpCode.xml?crtfc_key={API_KEY}"
FINANCIAL_URL = "https://opendart.fss.or.kr/api/fnlttSinglAcntAll.json"

def download_corp_codes():
    """기업 코드 XML 파일 다운로드 및 파싱"""
    response = requests.get(CORP_CODE_URL)
    xml_path = "corpCode.xml"

    # XML 파일 저장
    with open(xml_path, "wb") as file:
        file.write(response.content)

    # XML 파싱
    tree = ET.parse(xml_path)
    root = tree.getroot()

    # 외감 기업 코드 및 이름 추출
    corp_list = []
    for corp in root.findall('list'):
        corp_code = corp.find('corp_code').text
        corp_name = corp.find('corp_name').text
        stock_code = corp.find('stock_code').text

        # 외감기업(stock_code 없는 기업 포함)
        if stock_code is None or stock_code.strip() == "":
            corp_list.append((corp_code, corp_name))

    return corp_list

def get_financial_data(corp_code: str, year: str):
    """특정 기업의 재무제표 데이터 수집"""
    params = {
        "crtfc_key": API_KEY,
        "corp_code": corp_code,
        "bsns_year": year,
        "reprt_code": "11011",  # 사업보고서
        "fs_div": "CFS"  # 연결재무제표
    }

    response = requests.get(FINANCIAL_URL, params=params)
    data = response.json()

    if data['status'] != '000':
        print(f"기업 코드 {corp_code} - API 오류: {data['message']}")
        return None

    # 손익계산서 필터링 항목
    target_accounts = ["매출액", "매출원가", "판매비와관리비", "영업이익"]
    reports = data.get('list', [])
    df = pd.DataFrame(reports)

    if not df.empty:
        df = df[df['account_nm'].isin(target_accounts)]
        df = df[['sj_nm', 'account_nm', 'thstrm_amount', 'frmtrm_amount']]
        df.columns = ['재무제표명', '계정명', '당기 금액', '전기 금액']
        df.replace('', '0', inplace=True)
        df[['당기 금액', '전기 금액']] = df[['당기 금액', '전기 금액']].apply(pd.to_numeric, errors='coerce').fillna(0)
        return df

    return None

def collect_all_financials(year: str):
    """모든 외감 기업의 재무제표 데이터를 수집하여 엑셀로 저장"""
    corp_list = download_corp_codes()
    all_data = []

    for corp_code, corp_name in corp_list:
        print(f"기업 {corp_name}({corp_code}) 재무제표 수집 중...")
        df = get_financial_data(corp_code, year)
        if df is not None:
            df['기업명'] = corp_name
            all_data.append(df)

    # 전체 데이터 통합
    if all_data:
        final_df = pd.concat(all_data, ignore_index=True)
        final_df.to_excel(f"financial_statements_{year}.xlsx", index=False)
        print(f"{year}년도 외감기업 재무제표 수집 완료!")
    else:
        print("수집된 데이터가 없습니다.")

# 실행: 모든 외감기업의 2022년 재무제표 수집
collect_all_financials("2022")
# Out:
# Traceback (most recent call last):
#
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-18-2e4674b3f02e>", line 92, in <cell line: 0>
#     collect_all_financials("2022")
#
#   File "<ipython-input-18-2e4674b3f02e>", line 73, in collect_all_financials
#     corp_list = download_corp_codes()
#
#   File "<ipython-input-18-2e4674b3f02e>", line 23, in download_corp_codes
#     tree = ET.parse(xml_path)
#
#   File "/usr/lib/python3.11/xml/etree/ElementTree.py", line 1219, in parse
#     tree.parse(source, parser)
#
#   File "/usr/lib/python3.11/xml/etree/ElementTree.py", line 581, in parse
#     self._root = parser._parse_whole(source)
#
#   File "<string>", line unknown
# ParseError: not well-formed (invalid token): line 1, column 2

# %%
import requests
import pandas as pd
import xml.etree.ElementTree as ET
import io

# API 키 입력
API_KEY = "85006d20472a255d5eae25ee265b5ed1b78d1386"

# 기업 코드 요청 URL
CORP_CODE_URL = f"https://opendart.fss.or.kr/api/corpCode.xml?crtfc_key={API_KEY}"

def download_corp_codes():
    """기업 코드 XML 파일 다운로드 및 파싱"""
    response = requests.get(CORP_CODE_URL)

    # 응답이 XML인지 확인
    if response.headers['Content-Type'] != 'application/xml':
        print("응답 형식이 XML이 아닙니다. 응답 내용:")
        print(response.text)
        return []

    # XML 파싱
    try:
        tree = ET.ElementTree(ET.fromstring(response.content))
        root = tree.getroot()

        # 외감 기업 코드 및 이름 추출
        corp_list = []
        for corp in root.findall('list'):
            corp_code = corp.find('corp_code').text
            corp_name = corp.find('corp_name').text
            stock_code = corp.find('stock_code').text

            # 외감기업 (stock_code 없는 기업 포함)
            if stock_code is None or stock_code.strip() == "":
                corp_list.append((corp_code, corp_name))

        return corp_list
    except ET.ParseError as e:
        print("XML 파싱 오류:", e)
        return []

# 테스트 실행
corp_list = download_corp_codes()
if corp_list:
    print(f"{len(corp_list)}개의 기업 코드가 수집되었습니다.")
else:
    print("기업 코드 수")

# %%
import requests
import pandas as pd
import xml.etree.ElementTree as ET
import io

# API 키 설정
API_KEY = "85006d20472a255d5eae25ee265b5ed1b78d1386"

# API URL 설정
CORP_CODE_URL = f"https://opendart.fss.or.kr/api/corpCode.xml?crtfc_key={API_KEY}"
FINANCIAL_URL = "https://opendart.fss.or.kr/api/fnlttSinglAcntAll.json"

def download_corp_codes():
    """외감기업 코드를 다운로드 및 파싱"""
    response = requests.get(CORP_CODE_URL)

    # 인코딩 설정 및 XML 읽기
    response.encoding = response.apparent_encoding
    xml_data = response.content.decode(response.encoding)

    # XML 파싱
    root = ET.fromstring(xml_data)

    # 외감 기업 코드 및 이름 추출
    corp_list = []
    for corp in root.findall('list'):
        corp_code = corp.find('corp_code').text
        corp_name = corp.find('corp_name').text
        stock_code = corp.find('stock_code').text

        # 외감 기업(stock_code 없는 기업 포함)
        if stock_code is None or stock_code.strip() == "":
            corp_list.append((corp_code, corp_name))

    return corp_list

def get_financial_data(corp_code: str, year: str):
    """특정 기업의 손익계산서 주요 항목 수집"""
    params = {
        "crtfc_key": API_KEY,
        "corp_code": corp_code,
        "bsns_year": year,
        "reprt_code": "11011",  # 사업보고서
        "fs_div": "CFS"  # 연결재무제표
    }

    response = requests.get(FINANCIAL_URL, params=params)
    data = response.json()

    if data['status'] != '000':
        print(f"기업 코드 {corp_code} - API 오류: {data['message']}")
        return None

    # 손익계산서 필터링 항목
    target_accounts = ["매출액", "매출원가", "판매비와관리비", "영업이익"]
    reports = data.get('list', [])
    df = pd.DataFrame(reports)

    if not df.empty:
        df = df[df['account_nm'].isin(target_accounts)]
        df = df[['sj_nm', 'account_nm', 'thstrm_amount', 'frmtrm_amount']]
        df.columns = ['재무제표명', '계정명', '당기 금액', '전기 금액']
        df.replace('', '0', inplace=True)
        df[['당기 금액', '전기 금액']] = df[['당기 금액', '전기 금액']].apply(pd.to_numeric, errors='coerce').fillna(0)
        return df

    return None

def collect_all_financials(year: str):
    """모든 외감기업의 재무제표 데이터를 수집하여 엑셀로 저장"""
    corp_list = download_corp_codes()
    all_data = []

    for corp_code, corp_name in corp_list:
        print(f"기업 {corp_name}({corp_code}) 재무제표 수집 중...")
        df = get_financial_data(corp_code, year)
        if df is not None:
            df['기업명'] = corp_name
            all_data.append(df)

    # 전체 데이터 통합
    if all_data:
        final_df = pd.concat(all_data, ignore_index=True)
        final_df.to_excel(f"financial_statements_{year}.xlsx", index=False)
        print(f"{year}년도 외감기업 재무제표 수집 완료!")
    else:
        print("수집된 데이터가 없습니다.")

# 실행: 모든 외감기업의 2022년 재무제표 수집
collect_all_financials("2022")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-65c2db5f156f> in <cell line: 0>()
#      88
#      89 # 실행: 모든 외감기업의 2022년 재무제표 수집
# ---> 90 collect_all_financials("2022")
#
# <ipython-input-22-65c2db5f156f> in collect_all_financials(year)
#      69 def collect_all_financials(year: str):
#      70     """모든 외감기업의 재무제표 데이터를 수집하여 엑셀로 저장"""
# ---> 71     corp_list = download_corp_codes()
#      72     all_data = []
#      73
#
# <ipython-input-22-65c2db5f156f> in download_corp_codes()
#      17     # 인코딩 설정 및 XML 읽기
#      18     response.encoding = response.apparent_encoding
# ---> 19     xml_data = response.content.decode(response.encoding)
#      20
#      21     # XML 파싱
#
# TypeError: decode() argument 'encoding' must be str, not None

# %%
import requests
import pandas as pd
import xml.etree.ElementTree as ET

# API 키 설정
API_KEY = "85006d20472a255d5eae25ee265b5ed1b78d1386"

# API URL 설정
CORP_CODE_URL = f"https://opendart.fss.or.kr/api/corpCode.xml?crtfc_key={API_KEY}"
FINANCIAL_URL = "https://opendart.fss.or.kr/api/fnlttSinglAcntAll.json"

def download_corp_codes():
    """외감기업 코드를 다운로드 및 파싱"""
    response = requests.get(CORP_CODE_URL)

    # 인코딩 설정: 'utf-8'을 기본으로 설정
    encoding = response.apparent_encoding if response.apparent_encoding else 'utf-8'
    xml_data = response.content.decode(encoding)

    # XML 파싱
    root = ET.fromstring(xml_data)

    # 외감 기업 코드 및 이름 추출
    corp_list = []
    for corp in root.findall('list'):
        corp_code = corp.find('corp_code').text
        corp_name = corp.find('corp_name').text
        stock_code = corp.find('stock_code').text

        # 외감기업 (stock_code 없는 기업 포함)
        if stock_code is None or stock_code.strip() == "":
            corp_list.append((corp_code, corp_name))

    return corp_list

def get_financial_data(corp_code: str, year: str):
    """특정 기업의 손익계산서 주요 항목 수집"""
    params = {
        "crtfc_key": API_KEY,
        "corp_code": corp_code,
        "bsns_year": year,
        "reprt_code": "11011",  # 사업보고서
        "fs_div": "CFS"  # 연결재무제표
    }

    response = requests.get(FINANCIAL_URL, params=params)
    data = response.json()

    if data['status'] != '000':
        print(f"기업 코드 {corp_code} - API 오류: {data['message']}")
        return None

    # 손익계산서 필터링 항목
    target_accounts = ["매출액", "매출원가", "판매비와관리비", "영업이익"]
    reports = data.get('list', [])
    df = pd.DataFrame(reports)

    if not df.empty:
        df = df[df['account_nm'].isin(target_accounts)]
        df = df[['sj_nm', 'account_nm', 'thstrm_amount', 'frmtrm_amount']]
        df.columns = ['재무제표명', '계정명', '당기 금액', '전기 금액']
        df.replace('', '0', inplace=True)
        df[['당기 금액', '전기 금액']] = df[['당기 금액', '전기 금액']].apply(pd.to_numeric, errors='coerce').fillna(0)
        return df

    return None

def collect_all_financials(year: str):
    """모든 외감기업의 재무제표 데이터를 수집하여 엑셀로 저장"""
    corp_list = download_corp_codes()
    all_data = []

    for corp_code, corp_name in corp_list:
        print(f"기업 {corp_name}({corp_code}) 재무제표 수집 중...")
        df = get_financial_data(corp_code, year)
        if df is not None:
            df['기업명'] = corp_name
            all_data.append(df)

    # 전체 데이터 통합
    if all_data:
        final_df = pd.concat(all_data, ignore_index=True)
        final_df.to_excel(f"financial_statements_{year}.xlsx", index=False)
        print(f"{year}년도 외감기업 재무제표 수집 완료!")
    else:
        print("수집된 데이터가 없습니다.")

# 실행: 모든 외감기업의 2022년 재무제표 수집
collect_all_financials("2022")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-24-3e8ad4cd9724> in <cell line: 0>()
#      87
#      88 # 실행: 모든 외감기업의 2022년 재무제표 수집
# ---> 89 collect_all_financials("2022")
#
# <ipython-input-24-3e8ad4cd9724> in collect_all_financials(year)
#      68 def collect_all_financials(year: str):
#      69     """모든 외감기업의 재무제표 데이터를 수집하여 엑셀로 저장"""
# ---> 70     corp_list = download_corp_codes()
#      71     all_data = []
#      72
#
# <ipython-input-24-3e8ad4cd9724> in download_corp_codes()
#      16     # 인코딩 설정: 'utf-8'을 기본으로 설정
#      17     encoding = response.apparent_encoding if response.apparent_encoding else 'utf-8'
# ---> 18     xml_data = response.content.decode(encoding)
#      19
#      20     # XML 파싱
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x8c in position 10: invalid start byte

# %%
import requests
import pandas as pd
import xml.etree.ElementTree as ET
import zipfile
import io

API_KEY = "85006d20472a255d5eae25ee265b5ed1b78d1386"

CORP_CODE_URL = f"https://opendart.fss.or.kr/api/corpCode.xml?crtfc_key={API_KEY}"
FINANCIAL_URL = "https://opendart.fss.or.kr/api/fnlttSinglAcntAll.json"

def download_corp_codes():
    """기업 코드 파일 다운로드 후 압축 해제 및 XML 파싱"""
    response = requests.get(CORP_CODE_URL)

    if response.status_code == 200:
        with zipfile.ZipFile(io.BytesIO(response.content)) as z:
            file_name = z.namelist()[0]
            with z.open(file_name) as xml_file:
                xml_data = xml_file.read().decode("utf-8")

        # XML 파싱
        root = ET.fromstring(xml_data)

        # 외감 기업 코드 및 이름 추출
        corp_list = []
        for corp in root.findall('list'):
            corp_code = corp.find('corp_code').text
            corp_name = corp.find('corp_name').text
            stock_code = corp.find('stock_code').text

            # 외감기업 (stock_code 없는 기업 포함)
            if stock_code is None or stock_code.strip() == "":
                corp_list.append((corp_code, corp_name))

        return corp_list
    else:
        print(f"기업 코드 다운로드 오류: {response.status_code}")
        return []

def get_financial_data(corp_code: str, year: str):
    """특정 기업의 손익계산서 주요 항목 수집"""
    params = {
        "crtfc_key": API_KEY,
        "corp_code": corp_code,
        "bsns_year": year,
        "reprt_code": "11011",  # 사업보고서
        "fs_div": "CFS"  # 연결재무제표
    }

    response = requests.get(FINANCIAL_URL, params=params)
    data = response.json()

    if data['status'] != '000':
        print(f"기업 코드 {corp_code} - API 오류: {data['message']}")
        return None

    # 손익계산서 필터링 항목
    target_accounts = ["매출액", "매출원가", "판매비와관리비", "영업이익"]
    reports = data.get('list', [])
    df = pd.DataFrame(reports)

    if not df.empty:
        df = df[df['account_nm'].isin(target_accounts)]
        df = df[['sj_nm', 'account_nm', 'thstrm_amount', 'frmtrm_amount']]
        df.columns = ['재무제표명', '계정명', '당기 금액', '전기 금액']
        df.replace('', '0', inplace=True)
        df[['당기 금액', '전기 금액']] = df[['당기 금액', '전기 금액']].apply(pd.to_numeric, errors='coerce').fillna(0)
        return df

    return None

def collect_all_financials(year: str):
    """모든 외감기업의 재무제표 데이터를 수집하여 엑셀로 저장"""
    corp_list = download_corp_codes()
    all_data = []

    for corp_code, corp_name in corp_list:
        print(f"기업 {corp_name}({corp_code}) 재무제표 수집 중...")
        df = get_financial_data(corp_code, year)
        if df is not None:
            df['기업명'] = corp_name
            all_data.append(df)

    # 전체 데이터 통합
    if all_data:
        final_df = pd.concat(all_data, ignore_index=True)
        final_df.to_excel(f"financial_statements_{year}.xlsx", index=False)
        print(f"{year}년도 외감기업 재무제표 수집 완료!")
    else:
        print("수집된 데이터가 없습니다.")

# 실행: 모든 외감기업의 2022년 재무제표 수집
collect_all_financials("2022")
# Out:
# 기업 다코(00434003) 재무제표 수집 중...
# 기업 코드 00434003 - API 오류: 조회된 데이타가 없습니다.
# 기업 굿앤엘에스(00430964) 재무제표 수집 중...
# 기업 코드 00430964 - API 오류: 조회된 데이타가 없습니다.
# 기업 크레디피아제이십오차유동화전문회사(00388953) 재무제표 수집 중...
# 기업 코드 00388953 - API 오류: 조회된 데이타가 없습니다.
# 기업 연방건설산업(00179984) 재무제표 수집 중...
# 기업 코드 00179984 - API 오류: 조회된 데이타가 없습니다.
# 기업 브룩스피알아이오토메이션잉크(00420143) 재무제표 수집 중...
# 기업 코드 00420143 - API 오류: 조회된 데이타가 없습니다.
# 기업 매경아이비아이(00401111) 재무제표 수집 중...
# 기업 코드 00401111 - API 오류: 조회된 데이타가 없습니다.
# 기업 캐드뱅크(00435534) 재무제표 수집 중...
# 기업 코드 00435534 - API 오류: 조회된 데이타가 없습니다.
# 기업 엠와이오피삼차유동화전문유한회사(00430186) 재무제표 수집 중...
# 기업 코드 00430186 - API 오류: 조회된 데이타가 없습니다.
# 기업 엠와이오피이차유동화전문유한회사(00430201) 재무제표 수집 중...
# 기업 코드 00430201 - API 오류: 조회된 데이타가 없습니다.
# 기업 엠와이오피일차유동화전문유한회사(00430210) 재무제표 수집 중...
# 기업 코드 00430210 - API 오류: 조회된 데이타가 없습니다.
# 기업 포스미디어(00430229) 재무제표 수집 중...
# 기업 코드 00430229 - API 오류: 조회된 데이타가 없습니다.
# 기업 축복할렐루야(00140432) 재무제표 수집 중...
# 기업 코드 00140432 - API 오류: 조회된 데이타가 없습니다.
# 기업 한국전자화학(00426208) 재무제표 수집 중...
# 기업 코드 00426208 - API 오류: 조회된 데이타가 없습니다.
# 기업 ConnachtCapitalMarketInvestmentLtd.(00433262) 재무제표 수집 중...
# 기업 코드 00433262 - API 오류: 조회된 데이타가 없습니다.
# 기업 선진아이티(00433749) 재무제표 수집 중...
# 기업 코드 00433749 - API 오류: 조회된 데이타가 없습니다.
# 기업 팀스코리아(00433785) 재무제표 수집 중...
# 기업 코드 00433785 - API 오류: 조회된 데이타가 없습니다.
# 기업 에넥스하이테크(00196079) 재무제표 수집 중...
# 기업 코드 00196079 - API 오류: 조회된 데이타가 없습니다.
# 기업 세이스텝바이스텝혼합형펀드(00435048) 재무제표 수집 중...
# 기업 코드 00435048 - API 오류: 조회된 데이타가 없습니다.
# 기업 유리알파헷지채권혼합형펀드(00435057) 재무제표 수집 중...
# 기업 코드 00435057 - API 오류: 조회된 데이타가 없습니다.
# 기업 한기술정보통신(00108843) 재무제표 수집 중...
# 기업 코드 00108843 - API 오류: 조회된 데이타가 없습니다.
# 기업 다움종합건설(00443232) 재무제표 수집 중...
# 기업 코드 00443232 - API 오류: 조회된 데이타가 없습니다.
# 기업 한국애치슨(00248293) 재무제표 수집 중...
# 기업 코드 00248293 - API 오류: 조회된 데이타가 없습니다.
# 기업 고은상사(00455662) 재무제표 수집 중...
# 기업 코드 00455662 - API 오류: 조회된 데이타가 없습니다.
# 기업 조흥종합건설(00149318) 재무제표 수집 중...
# 기업 코드 00149318 - API 오류: 조회된 데이타가 없습니다.
# 기업 유니즈유통(00451347) 재무제표 수집 중...
# 기업 코드 00451347 - API 오류: 조회된 데이타가 없습니다.
# 기업 창대화장품(00415105) 재무제표 수집 중...
# 기업 코드 00415105 - API 오류: 조회된 데이타가 없습니다.
# 기업 문화종합건설(00420824) 재무제표 수집 중...
# 기업 코드 00420824 - API 오류: 조회된 데이타가 없습니다.
# 기업 한국종합미디어(00389439) 재무제표 수집 중...
# 기업 코드 00389439 - API 오류: 조회된 데이타가 없습니다.
# 기업 아이펜텍(00454016) 재무제표 수집 중...
# 기업 코드 00454016 - API 오류: 조회된 데이타가 없습니다.
# 기업 대홍염공(00452072) 재무제표 수집 중...
# 기업 코드 00452072 - API 오류: 조회된 데이타가 없습니다.
# 기업 지오항공여행사(00437602) 재무제표 수집 중...
# 기업 코드 00437602 - API 오류: 조회된 데이타가 없습니다.
# 기업 헤이아니타코리아(00365518) 재무제표 수집 중...
# 기업 코드 00365518 - API 오류: 조회된 데이타가 없습니다.
# 기업 태산산업개발(00246967) 재무제표 수집 중...
# 기업 코드 00246967 - API 오류: 조회된 데이타가 없습니다.
# 기업 군포종합시장(00445559) 재무제표 수집 중...
# 기업 코드 00445559 - API 오류: 조회된 데이타가 없습니다.
# 기업 기우(00444657) 재무제표 수집 중...
# 기업 코드 00444657 - API 오류: 조회된 데이타가 없습니다.
# 기업 라시도(00448936) 재무제표 수집 중...
# 기업 코드 00448936 - API 오류: 조회된 데이타가 없습니다.
# 기업 예전미디어(00405658) 재무제표 수집 중...
# 기업 코드 00405658 - API 오류: 조회된 데이타가 없습니다.
# 기업 세미가(00410818) 재무제표 수집 중...
# 기업 코드 00410818 - API 오류: 조회된 데이타가 없습니다.
# 기업 대닉스(00416061) 재무제표 수집 중...
# 기업 코드 00416061 - API 오류: 조회된 데이타가 없습니다.
# 기업 인포핸드(00448909) 재무제표 수집 중...
# 기업 코드 00448909 - API 오류: 조회된 데이타가 없습니다.
# 기업 지현개발(00445407) 재무제표 수집 중...
# 기업 코드 00445407 - API 오류: 조회된 데이타가 없습니다.
# 기업 한국부동산신탁제일차유동화전문유한회사(00421647) 재무제표 수집 중...
# 기업 코드 00421647 - API 오류: 조회된 데이타가 없습니다.
# 기업 ISCCaymanLtd.(00421425) 재무제표 수집 중...
# 기업 코드 00421425 - API 오류: 조회된 데이타가 없습니다.
# 기업 연산(00423265) 재무제표 수집 중...
# 기업 코드 00423265 - API 오류: 조회된 데이타가 없습니다.
# 기업 씨케이알유동화전문유한회사(00423292) 재무제표 수집 중...
# 기업 코드 00423292 - API 오류: 조회된 데이타가 없습니다.
# 기업 디에스피(00420602) 재무제표 수집 중...
# 기업 코드 00420602 - API 오류: 조회된 데이타가 없습니다.
# 기업 LOMBARDKOREAILIMITED(00307505) 재무제표 수집 중...
# 기업 코드 00307505 - API 오류: 조회된 데이타가 없습니다.
# 기업 우신투자자문(00241397) 재무제표 수집 중...
# 기업 코드 00241397 - API 오류: 조회된 데이타가 없습니다.
# 기업 외환카드제오차유동화전문유한회사(00421896) 재무제표 수집 중...
# 기업 코드 00421896 - API 오류: 조회된 데이타가 없습니다.
# 기업 태연(00365712) 재무제표 수집 중...
# 기업 코드 00365712 - API 오류: 조회된 데이타가 없습니다.
# 기업 글로벌금강제일차유동화전문유한회사(00388616) 재무제표 수집 중...
# 기업 코드 00388616 - API 오류: 조회된 데이타가 없습니다.
# 기업 글로벌렌탈(00230407) 재무제표 수집 중...
# 기업 코드 00230407 - API 오류: 조회된 데이타가 없습니다.
# 기업 뤼미에르에셋(00423566) 재무제표 수집 중...
# 기업 코드 00423566 - API 오류: 조회된 데이타가 없습니다.
# 기업 바사라엔터테인먼트(00423274) 재무제표 수집 중...
# 기업 코드 00423274 - API 오류: 조회된 데이타가 없습니다.
# 기업 대백유동화전문유한회사(00419688) 재무제표 수집 중...
# 기업 코드 00419688 - API 오류: 조회된 데이타가 없습니다.
# 기업 아이키키(00419712) 재무제표 수집 중...
# 기업 코드 00419712 - API 오류: 조회된 데이타가 없습니다.
# 기업 진명씨앤씨(00414665) 재무제표 수집 중...
# 기업 코드 00414665 - API 오류: 조회된 데이타가 없습니다.
# 기업 한경핫벤처(00421869) 재무제표 수집 중...
# 기업 코드 00421869 - API 오류: 조회된 데이타가 없습니다.
# 기업 우리부동산제일차유동화전문유한회사(00421957) 재무제표 수집 중...
# 기업 코드 00421957 - API 오류: 조회된 데이타가 없습니다.
# 기업 영진상운(00255442) 재무제표 수집 중...
# 기업 코드 00255442 - API 오류: 조회된 데이타가 없습니다.
# 기업 한국토지신탁제오차유동화전문유한회사(00427517) 재무제표 수집 중...
# 기업 코드 00427517 - API 오류: 조회된 데이타가 없습니다.
# 기업 다드림커뮤니케이션(00376152) 재무제표 수집 중...
# 기업 코드 00376152 - API 오류: 조회된 데이타가 없습니다.
# 기업 ARISAIGASIANSMALLCOMPANIESFUND(L)BHD(00382241) 재무제표 수집 중...
# 기업 코드 00382241 - API 오류: 조회된 데이타가 없습니다.
# 기업 싱가포르개발은행서울지점(00431501) 재무제표 수집 중...
# 기업 코드 00431501 - API 오류: 조회된 데이타가 없습니다.
# 기업 KTB혼합형펀드(00434289) 재무제표 수집 중...
# 기업 코드 00434289 - API 오류: 조회된 데이타가 없습니다.
# 기업 KTB플러스찬스혼합형펀드(00434298) 재무제표 수집 중...
# 기업 코드 00434298 - API 오류: 조회된 데이타가 없습니다.
# 기업 KTB포트폴리오스타혼합형펀드(00434313) 재무제표 수집 중...
# 기업 코드 00434313 - API 오류: 조회된 데이타가 없습니다.
# 기업 KTB에버스타혼합형펀드(00434322) 재무제표 수집 중...
# 기업 코드 00434322 - API 오류: 조회된 데이타가 없습니다.
# 기업 나노이앤씨(00429463) 재무제표 수집 중...
# 기업 코드 00429463 - API 오류: 조회된 데이타가 없습니다.
# 기업 지산엔터프라이즈(00429515) 재무제표 수집 중...
# 기업 코드 00429515 - API 오류: 조회된 데이타가 없습니다.
# 기업 유아이에스코리아(00432175) 재무제표 수집 중...
# 기업 코드 00432175 - API 오류: 조회된 데이타가 없습니다.
# 기업 트리플에스유동화전문유한회사(00387033) 재무제표 수집 중...
# 기업 코드 00387033 - API 오류: 조회된 데이타가 없습니다.
# 기업 크레디피아제이십일차유동화전문유한회사(00384045) 재무제표 수집 중...
# 기업 코드 00384045 - API 오류: 조회된 데이타가 없습니다.
# 기업 싱가포르개발은행(00431608) 재무제표 수집 중...
# 기업 코드 00431608 - API 오류: 조회된 데이타가 없습니다.
# 기업 엘지팩토링제일차유동화전문유한회사(00431705) 재무제표 수집 중...
# 기업 코드 00431705 - API 오류: 조회된 데이타가 없습니다.
# 기업 이피에스뱅크(00430256) 재무제표 수집 중...
# 기업 코드 00430256 - API 오류: 조회된 데이타가 없습니다.
# 기업 이라이프네트워크(00431167) 재무제표 수집 중...
# 기업 코드 00431167 - API 오류: 조회된 데이타가 없습니다.
# 기업 덕성(00432315) 재무제표 수집 중...
# 기업 코드 00432315 - API 오류: 조회된 데이타가 없습니다.
# 기업 타오건설(00413134) 재무제표 수집 중...
# 기업 코드 00413134 - API 오류: 조회된 데이타가 없습니다.
# 기업 장원코리아(00435376) 재무제표 수집 중...
# 기업 코드 00435376 - API 오류: 조회된 데이타가 없습니다.
# 기업 대신통상(00110909) 재무제표 수집 중...
# 기업 코드 00110909 - API 오류: 조회된 데이타가 없습니다.
# 기업 서울교육(00220695) 재무제표 수집 중...
# 기업 코드 00220695 - API 오류: 조회된 데이타가 없습니다.
# 기업 보성패션(00211794) 재무제표 수집 중...
# 기업 코드 00211794 - API 오류: 조회된 데이타가 없습니다.
# 기업 넥스탑(00454496) 재무제표 수집 중...
# 기업 코드 00454496 - API 오류: 조회된 데이타가 없습니다.
# 기업 마니빌(00455592) 재무제표 수집 중...
# 기업 코드 00455592 - API 오류: 조회된 데이타가 없습니다.
# 기업 제이엘코프(00370796) 재무제표 수집 중...
# 기업 코드 00370796 - API 오류: 조회된 데이타가 없습니다.
# 기업 컴마을(00199401) 재무제표 수집 중...
# 기업 코드 00199401 - API 오류: 조회된 데이타가 없습니다.
# 기업 삼신크리에이션(00369596) 재무제표 수집 중...
# 기업 코드 00369596 - API 오류: 조회된 데이타가 없습니다.
# 기업 호한통상(00210078) 재무제표 수집 중...
# 기업 코드 00210078 - API 오류: 조회된 데이타가 없습니다.
# 기업 케이엠티(00363398) 재무제표 수집 중...
# 기업 코드 00363398 - API 오류: 조회된 데이타가 없습니다.
# 기업 대백가구(00110042) 재무제표 수집 중...
# 기업 코드 00110042 - API 오류: 조회된 데이타가 없습니다.
# 기업 청빛산업개발(00364324) 재무제표 수집 중...
# 기업 코드 00364324 - API 오류: 조회된 데이타가 없습니다.
# 기업 삼양전자(00248017) 재무제표 수집 중...
# 기업 코드 00248017 - API 오류: 조회된 데이타가 없습니다.
# 기업 숭민코리아유통(00452179) 재무제표 수집 중...
# 기업 코드 00452179 - API 오류: 조회된 데이타가 없습니다.
# 기업 유오티앤씨(00413754) 재무제표 수집 중...
# 기업 코드 00413754 - API 오류: 조회된 데이타가 없습니다.
# 기업 한라스페코중공업(00343163) 재무제표 수집 중...
# 기업 코드 00343163 - API 오류: 조회된 데이타가 없습니다.
# 기업 알본(00452513) 재무제표 수집 중...
# 기업 코드 00452513 - API 오류: 조회된 데이타가 없습니다.
# 기업 상일디지털(00435978) 재무제표 수집 중...
# 기업 코드 00435978 - API 오류: 조회된 데이타가 없습니다.
# 기업 서전어패럴(00368153) 재무제표 수집 중...
# 기업 코드 00368153 - API 오류: 조회된 데이타가 없습니다.
# 기업 웰비스트랜스(00455149) 재무제표 수집 중...
# 기업 코드 00455149 - API 오류: 조회된 데이타가 없습니다.
# 기업 한국키엔스(00249946) 재무제표 수집 중...
# 기업 코드 00249946 - API 오류: 조회된 데이타가 없습니다.
# 기업 대신생명보험(00110839) 재무제표 수집 중...
# 기업 코드 00110839 - API 오류: 조회된 데이타가 없습니다.
# 기업 대성메디테크(00293798) 재무제표 수집 중...
# 기업 코드 00293798 - API 오류: 조회된 데이타가 없습니다.
# 기업 대한알루미늄공업(00113119) 재무제표 수집 중...
# 기업 코드 00113119 - API 오류: 조회된 데이타가 없습니다.
# 기업 남성엠케이(00424389) 재무제표 수집 중...
# 기업 코드 00424389 - API 오류: 조회된 데이타가 없습니다.
# 기업 씨엠액텍(00424486) 재무제표 수집 중...
# 기업 코드 00424486 - API 오류: 조회된 데이타가 없습니다.
# 기업 한국부동산신탁(00224734) 재무제표 수집 중...
# 기업 코드 00224734 - API 오류: 조회된 데이타가 없습니다.
# 기업 주은산업(00197713) 재무제표 수집 중...
# 기업 코드 00197713 - API 오류: 조회된 데이타가 없습니다.
# 기업 신엘지프라이머리제이차유동화전문유한회사(00421948) 재무제표 수집 중...
# 기업 코드 00421948 - API 오류: 조회된 데이타가 없습니다.
# 기업 데코제일차유동화전문유한회사(00422381) 재무제표 수집 중...
# 기업 코드 00422381 - API 오류: 조회된 데이타가 없습니다.
# 기업 뉴스테이트삼차모기지유동화전문유한회사(00350446) 재무제표 수집 중...
# 기업 코드 00350446 - API 오류: 조회된 데이타가 없습니다.
# 기업 엘지수퍼센터(00396642) 재무제표 수집 중...
# 기업 코드 00396642 - API 오류: 조회된 데이타가 없습니다.
# 기업 아이클릭세븐(00425449) 재무제표 수집 중...
# 기업 코드 00425449 - API 오류: 조회된 데이타가 없습니다.
# 기업 월드인코레스(00425458) 재무제표 수집 중...
# 기업 코드 00425458 - API 오류: 조회된 데이타가 없습니다.
# 기업 코리아픽시컴(00425333) 재무제표 수집 중...
# 기업 코드 00425333 - API 오류: 조회된 데이타가 없습니다.
# 기업 산은부동산제사차유동화전문유한회사(00424617) 재무제표 수집 중...
# 기업 코드 00424617 - API 오류: 조회된 데이타가 없습니다.
# 기업 글로벌자이언트시스템(00424006) 재무제표 수집 중...
# 기업 코드 00424006 - API 오류: 조회된 데이타가 없습니다.
# 기업 신클레어(00424051) 재무제표 수집 중...
# 기업 코드 00424051 - API 오류: 조회된 데이타가 없습니다.
# 기업 에이에스피기업구조조정전문(00403599) 재무제표 수집 중...
# 기업 코드 00403599 - API 오류: 조회된 데이타가 없습니다.
# 기업 Marubeni-ItochuSteelInc.(00425519) 재무제표 수집 중...
# 기업 코드 00425519 - API 오류: 조회된 데이타가 없습니다.
# 기업 신한(00224585) 재무제표 수집 중...
# 기업 코드 00224585 - API 오류: 조회된 데이타가 없습니다.
# 기업 우리모아제이차유동화전문유한회사(00429524) 재무제표 수집 중...
# 기업 코드 00429524 - API 오류: 조회된 데이타가 없습니다.
# 기업 글로벌사모안정혼합형펀드(00429533) 재무제표 수집 중...
# 기업 코드 00429533 - API 오류: 조회된 데이타가 없습니다.
# 기업 파워외환카드제팔차유동화전문유한회사(00432722) 재무제표 수집 중...
# 기업 코드 00432722 - API 오류: 조회된 데이타가 없습니다.
# 기업 파워외환카드제오차유동화전문유한회사(00432786) 재무제표 수집 중...
# 기업 코드 00432786 - API 오류: 조회된 데이타가 없습니다.
# 기업 영퓨처(00429728) 재무제표 수집 중...
# 기업 코드 00429728 - API 오류: 조회된 데이타가 없습니다.
# 기업 코로볼틴펀드리미티드(00428668) 재무제표 수집 중...
# 기업 코드 00428668 - API 오류: 조회된 데이타가 없습니다.
# 기업 대창크랑크(00430751) 재무제표 수집 중...
# 기업 코드 00430751 - API 오류: 조회된 데이타가 없습니다.
# 기업 허츠제일차유동화전문유한회사(00385372) 재무제표 수집 중...
# 기업 코드 00385372 - API 오류: 조회된 데이타가 없습니다.
# 기업 새암교육(00431680) 재무제표 수집 중...
# 기업 코드 00431680 - API 오류: 조회된 데이타가 없습니다.
# 기업 반지종합상가(00386308) 재무제표 수집 중...
# 기업 코드 00386308 - API 오류: 조회된 데이타가 없습니다.
# 기업 동서산업건설(가칭)(00256450) 재무제표 수집 중...
# 기업 코드 00256450 - API 오류: 조회된 데이타가 없습니다.
# 기업 대우종합기계(가칭)(00290816) 재무제표 수집 중...
# 기업 코드 00290816 - API 오류: 조회된 데이타가 없습니다.
# 기업 대우조선공업(가칭)(00291532) 재무제표 수집 중...
# 기업 코드 00291532 - API 오류: 조회된 데이타가 없습니다.
# 기업 삼일상호저축은행(00127990) 재무제표 수집 중...
# 기업 코드 00127990 - API 오류: 조회된 데이타가 없습니다.
# 기업 케이디에스에스(00431565) 재무제표 수집 중...
# 기업 코드 00431565 - API 오류: 조회된 데이타가 없습니다.
# 기업 비젼케이파트너스(00399959) 재무제표 수집 중...
# 기업 코드 00399959 - API 오류: 조회된 데이타가 없습니다.
# 기업 리버랜드(00430238) 재무제표 수집 중...
# 기업 코드 00430238 - API 오류: 조회된 데이타가 없습니다.
# 기업 동양선재(00263034) 재무제표 수집 중...
# 기업 코드 00263034 - API 오류: 조회된 데이타가 없습니다.
# 기업 춘천미도파(00205298) 재무제표 수집 중...
# 기업 코드 00205298 - API 오류: 조회된 데이타가 없습니다.
# 기업 거버너스M&A사모펀드3호(00431042) 재무제표 수집 중...
# 기업 코드 00431042 - API 오류: 조회된 데이타가 없습니다.
# 기업 아이앤비골드문브이에이치(00348715) 재무제표 수집 중...
# 기업 코드 00348715 - API 오류: 조회된 데이타가 없습니다.
# 기업 체리미디어(00447964) 재무제표 수집 중...
# 기업 코드 00447964 - API 오류: 조회된 데이타가 없습니다.
# 기업 경원하이텍(00448361) 재무제표 수집 중...
# 기업 코드 00448361 - API 오류: 조회된 데이타가 없습니다.
# 기업 중원화학(00185851) 재무제표 수집 중...
# 기업 코드 00185851 - API 오류: 조회된 데이타가 없습니다.
# 기업 나크나인(00445735) 재무제표 수집 중...
# 기업 코드 00445735 - API 오류: 조회된 데이타가 없습니다.
# 기업 동남해상관광호텔(00385770) 재무제표 수집 중...
# 기업 코드 00385770 - API 오류: 조회된 데이타가 없습니다.
# 기업 한성선박(00319245) 재무제표 수집 중...
# 기업 코드 00319245 - API 오류: 조회된 데이타가 없습니다.
# 기업 삼성콘크리트공업(00126502) 재무제표 수집 중...
# 기업 코드 00126502 - API 오류: 조회된 데이타가 없습니다.
# 기업 엠알더블유테크노로지(00363440) 재무제표 수집 중...
# 기업 코드 00363440 - API 오류: 조회된 데이타가 없습니다.
# 기업 제이에이치홀딩스(00445522) 재무제표 수집 중...
# 기업 코드 00445522 - API 오류: 조회된 데이타가 없습니다.
# 기업 동연산업(00320302) 재무제표 수집 중...
# 기업 코드 00320302 - API 오류: 조회된 데이타가 없습니다.
# 기업 우양주택건설(00444958) 재무제표 수집 중...
# 기업 코드 00444958 - API 오류: 조회된 데이타가 없습니다.
# 기업 해진하우징(00441836) 재무제표 수집 중...
# 기업 코드 00441836 - API 오류: 조회된 데이타가 없습니다.
# 기업 효헌산업(00445629) 재무제표 수집 중...
# 기업 코드 00445629 - API 오류: 조회된 데이타가 없습니다.
# 기업 우림산업개발(00454052) 재무제표 수집 중...
# 기업 코드 00454052 - API 오류: 조회된 데이타가 없습니다.
# 기업 에이스하이테크(00454414) 재무제표 수집 중...
# 기업 코드 00454414 - API 오류: 조회된 데이타가 없습니다.
# 기업 해표푸드서비스(00196857) 재무제표 수집 중...
# 기업 코드 00196857 - API 오류: 조회된 데이타가 없습니다.
# 기업 에프씨산업(00413383) 재무제표 수집 중...
# 기업 코드 00413383 - API 오류: 조회된 데이타가 없습니다.
# 기업 극동뉴메릭(00225098) 재무제표 수집 중...
# 기업 코드 00225098 - API 오류: 조회된 데이타가 없습니다.
# 기업 서울드림랜드(00410304) 재무제표 수집 중...
# 기업 코드 00410304 - API 오류: 조회된 데이타가 없습니다.
# 기업 한국미라이공업(00310998) 재무제표 수집 중...
# 기업 코드 00310998 - API 오류: 조회된 데이타가 없습니다.
# 기업 21세기화장품(00415114) 재무제표 수집 중...
# 기업 코드 00415114 - API 오류: 조회된 데이타가 없습니다.
# 기업 광명산업(00451000) 재무제표 수집 중...
# 기업 코드 00451000 - API 오류: 조회된 데이타가 없습니다.
# 기업 다음솔루션(00369985) 재무제표 수집 중...
# 기업 코드 00369985 - API 오류: 조회된 데이타가 없습니다.
# 기업 정우조명(00371670) 재무제표 수집 중...
# 기업 코드 00371670 - API 오류: 조회된 데이타가 없습니다.
# 기업 모바일웰컴(00401430) 재무제표 수집 중...
# 기업 코드 00401430 - API 오류: 조회된 데이타가 없습니다.
# 기업 푸른건설(00247027) 재무제표 수집 중...
# 기업 코드 00247027 - API 오류: 조회된 데이타가 없습니다.
# 기업 월다크(00144058) 재무제표 수집 중...
# 기업 코드 00144058 - API 오류: 조회된 데이타가 없습니다.
# 기업 길도건업(00416867) 재무제표 수집 중...
# 기업 코드 00416867 - API 오류: 조회된 데이타가 없습니다.
# 기업 원일스포지움(00456263) 재무제표 수집 중...
# 기업 코드 00456263 - API 오류: 조회된 데이타가 없습니다.
# 기업 용인자원(00436339) 재무제표 수집 중...
# 기업 코드 00436339 - API 오류: 조회된 데이타가 없습니다.
# 기업 마산강관(00120748) 재무제표 수집 중...
# 기업 코드 00120748 - API 오류: 조회된 데이타가 없습니다.
# 기업 세창철강공업(00386724) 재무제표 수집 중...
# 기업 코드 00386724 - API 오류: 조회된 데이타가 없습니다.
# 기업 재무와정보(00255390) 재무제표 수집 중...
# 기업 코드 00255390 - API 오류: 조회된 데이타가 없습니다.
# 기업 대양중공업(00455547) 재무제표 수집 중...
# 기업 코드 00455547 - API 오류: 조회된 데이타가 없습니다.
# 기업 이에이지씨(00233398) 재무제표 수집 중...
# 기업 코드 00233398 - API 오류: 조회된 데이타가 없습니다.
# 기업 페타코페트로륨(00405065) 재무제표 수집 중...
# 기업 코드 00405065 - API 오류: 조회된 데이타가 없습니다.
# 기업 MarubeniCorporation(00425537) 재무제표 수집 중...
# 기업 코드 00425537 - API 오류: 조회된 데이타가 없습니다.
# 기업 캐피탈라인(00424158) 재무제표 수집 중...
# 기업 코드 00424158 - API 오류: 조회된 데이타가 없습니다.
# 기업 건설증권(00100920) 재무제표 수집 중...
# 기업 코드 00100920 - API 오류: 조회된 데이타가 없습니다.
# 기업 일진전자통신(00370167) 재무제표 수집 중...
# 기업 코드 00370167 - API 오류: 조회된 데이타가 없습니다.
# 기업 오픈솔루션(00409131) 재무제표 수집 중...
# 기업 코드 00409131 - API 오류: 조회된 데이타가 없습니다.
# 기업 AMERICAORIENTALGROUP(00424194) 재무제표 수집 중...
# 기업 코드 00424194 - API 오류: 조회된 데이타가 없습니다.
# 기업 mvp창업투자(00364713) 재무제표 수집 중...
# 기업 코드 00364713 - API 오류: 조회된 데이타가 없습니다.
# 기업 라이져(00408901) 재무제표 수집 중...
# 기업 코드 00408901 - API 오류: 조회된 데이타가 없습니다.
# 기업 한라시멘트(00161170) 재무제표 수집 중...
# 기업 코드 00161170 - API 오류: 조회된 데이타가 없습니다.
# 기업 한국알리안츠화재해상보험(00423557) 재무제표 수집 중...
# 기업 코드 00423557 - API 오류: 조회된 데이타가 없습니다.
# 기업 코리아벌처투자(00307444) 재무제표 수집 중...
# 기업 코드 00307444 - API 오류: 조회된 데이타가 없습니다.
# 기업 티에스케이지(00370468) 재무제표 수집 중...
# 기업 코드 00370468 - API 오류: 조회된 데이타가 없습니다.
# 기업 텔레닉스(00424219) 재무제표 수집 중...
# 기업 코드 00424219 - API 오류: 조회된 데이타가 없습니다.
# 기업 유니텍워터시스템즈(00424185) 재무제표 수집 중...
# 기업 코드 00424185 - API 오류: 조회된 데이타가 없습니다.
# 기업 거륜씨앤씨(00424556) 재무제표 수집 중...
# 기업 코드 00424556 - API 오류: 조회된 데이타가 없습니다.
# 기업 문화(00121631) 재무제표 수집 중...
# 기업 코드 00121631 - API 오류: 조회된 데이타가 없습니다.
# 기업 모비도미(00424866) 재무제표 수집 중...
# 기업 코드 00424866 - API 오류: 조회된 데이타가 없습니다.
# 기업 에이치케이인베스트먼트유동화전문유한회사(00424884) 재무제표 수집 중...
# 기업 코드 00424884 - API 오류: 조회된 데이타가 없습니다.
# 기업 LiquidmetalTechnologies(00424927) 재무제표 수집 중...
# 기업 코드 00424927 - API 오류: 조회된 데이타가 없습니다.
# 기업 모멘타(케이만)(00423797) 재무제표 수집 중...
# 기업 코드 00423797 - API 오류: 조회된 데이타가 없습니다.
# 기업 KTB프라임8호혼합형사모펀드(00433350) 재무제표 수집 중...
# 기업 코드 00433350 - API 오류: 조회된 데이타가 없습니다.
# 기업 유리명품장기채권형사모펀드3호(00433369) 재무제표 수집 중...
# 기업 코드 00433369 - API 오류: 조회된 데이타가 없습니다.
# 기업 유리유니콘채권혼합형펀드(00433378) 재무제표 수집 중...
# 기업 코드 00433378 - API 오류: 조회된 데이타가 없습니다.
# 기업 맥쿼리아이엠엠프라임7호채권형사모펀드(00433387) 재무제표 수집 중...
# 기업 코드 00433387 - API 오류: 조회된 데이타가 없습니다.
# 기업 마이에셋애국성장형이호펀드(00433420) 재무제표 수집 중...
# 기업 코드 00433420 - API 오류: 조회된 데이타가 없습니다.
# 기업 채권플러스알파2호펀드(00433457) 재무제표 수집 중...
# 기업 코드 00433457 - API 오류: 조회된 데이타가 없습니다.
# 기업 마이다스사모프라임안정형2호펀드(00433466) 재무제표 수집 중...
# 기업 코드 00433466 - API 오류: 조회된 데이타가 없습니다.
# 기업 테크포인트(00376073) 재무제표 수집 중...
# 기업 코드 00376073 - API 오류: 조회된 데이타가 없습니다.
# 기업 부국개발(00234306) 재무제표 수집 중...
# 기업 코드 00234306 - API 오류: 조회된 데이타가 없습니다.
# 기업 세닥에듀케이션(00429418) 재무제표 수집 중...
# 기업 코드 00429418 - API 오류: 조회된 데이타가 없습니다.
# 기업 에이치엘홀딩스에스에이(00429977) 재무제표 수집 중...
# 기업 코드 00429977 - API 오류: 조회된 데이타가 없습니다.
# 기업 크레디리요네증권(00340786) 재무제표 수집 중...
# 기업 코드 00340786 - API 오류: 조회된 데이타가 없습니다.
# 기업 케이티인더스트리(00218928) 재무제표 수집 중...
# 기업 코드 00218928 - API 오류: 조회된 데이타가 없습니다.
# 기업 김천상호저축은행(00106793) 재무제표 수집 중...
# 기업 코드 00106793 - API 오류: 조회된 데이타가 없습니다.
# 기업 이화홀딩스(00378886) 재무제표 수집 중...
# 기업 코드 00378886 - API 오류: 조회된 데이타가 없습니다.
# 기업 미래에셋유니온사모혼합형펀드2호(00433484) 재무제표 수집 중...
# 기업 코드 00433484 - API 오류: 조회된 데이타가 없습니다.
# 기업 맥쿼리아이엠엠액티브채권형사모펀드3호(00433493) 재무제표 수집 중...
# 기업 코드 00433493 - API 오류: 조회된 데이타가 없습니다.
# 기업 맥쿼리아이엠엠프라임6호혼합형사모펀드(00433509) 재무제표 수집 중...
# 기업 코드 00433509 - API 오류: 조회된 데이타가 없습니다.
# 기업 유리명품장기채권형사모펀드2호(00433518) 재무제표 수집 중...
# 기업 코드 00433518 - API 오류: 조회된 데이타가 없습니다.
# 기업 신우쉬핑(00406596) 재무제표 수집 중...
# 기업 코드 00406596 - API 오류: 조회된 데이타가 없습니다.
# 기업 동흥컨설팅(00443001) 재무제표 수집 중...
# 기업 코드 00443001 - API 오류: 조회된 데이타가 없습니다.
# 기업 디조콤(00363741) 재무제표 수집 중...
# 기업 코드 00363741 - API 오류: 조회된 데이타가 없습니다.
# 기업 맘모스산업개발(00436375) 재무제표 수집 중...
# 기업 코드 00436375 - API 오류: 조회된 데이타가 없습니다.
# 기업 아성(00222277) 재무제표 수집 중...
# 기업 코드 00222277 - API 오류: 조회된 데이타가 없습니다.
# 기업 디토정보기술(00446284) 재무제표 수집 중...
# 기업 코드 00446284 - API 오류: 조회된 데이타가 없습니다.
# 기업 오우디앤씨(00446682) 재무제표 수집 중...
# 기업 코드 00446682 - API 오류: 조회된 데이타가 없습니다.
# 기업 에어웨이엑스프레스(00139995) 재무제표 수집 중...
# 기업 코드 00139995 - API 오류: 조회된 데이타가 없습니다.
# 기업 탑월드(00444602) 재무제표 수집 중...
# 기업 코드 00444602 - API 오류: 조회된 데이타가 없습니다.
# 기업 진로종합유통(00150314) 재무제표 수집 중...
# 기업 코드 00150314 - API 오류: 조회된 데이타가 없습니다.
# 기업 케이에프텍(00231840) 재무제표 수집 중...
# 기업 코드 00231840 - API 오류: 조회된 데이타가 없습니다.
# 기업 나토상사(00236243) 재무제표 수집 중...
# 기업 코드 00236243 - API 오류: 조회된 데이타가 없습니다.
# 기업 지오이네트(00309479) 재무제표 수집 중...
# 기업 코드 00309479 - API 오류: 조회된 데이타가 없습니다.
# 기업 이십일세기종합건설(00447034) 재무제표 수집 중...
# 기업 코드 00447034 - API 오류: 조회된 데이타가 없습니다.
# 기업 일현건설(00447496) 재무제표 수집 중...
# 기업 코드 00447496 - API 오류: 조회된 데이타가 없습니다.
# 기업 삼영기공(00300928) 재무제표 수집 중...
# 기업 코드 00300928 - API 오류: 조회된 데이타가 없습니다.
# 기업 삼능주택(00317566) 재무제표 수집 중...
# 기업 코드 00317566 - API 오류: 조회된 데이타가 없습니다.
# 기업 동해(00412001) 재무제표 수집 중...
# 기업 코드 00412001 - API 오류: 조회된 데이타가 없습니다.
# 기업 풍광직물(00155407) 재무제표 수집 중...
# 기업 코드 00155407 - API 오류: 조회된 데이타가 없습니다.
# 기업 기성텍스타일(00443542) 재무제표 수집 중...
# 기업 코드 00443542 - API 오류: 조회된 데이타가 없습니다.
# 기업 제텍스바론(00179726) 재무제표 수집 중...
# 기업 코드 00179726 - API 오류: 조회된 데이타가 없습니다.
# 기업 국제개발(00300982) 재무제표 수집 중...
# 기업 코드 00300982 - API 오류: 조회된 데이타가 없습니다.
# 기업 유유후마킬라(00298818) 재무제표 수집 중...
# 기업 코드 00298818 - API 오류: 조회된 데이타가 없습니다.
# 기업 피앤씨미디어(00424644) 재무제표 수집 중...
# 기업 코드 00424644 - API 오류: 조회된 데이타가 없습니다.
# 기업 비앤에프투자자문(00350570) 재무제표 수집 중...
# 기업 코드 00350570 - API 오류: 조회된 데이타가 없습니다.
# 기업 한국부동산신탁제이차유동화전문유한회사(00424316) 재무제표 수집 중...
# 기업 코드 00424316 - API 오류: 조회된 데이타가 없습니다.
# 기업 에이텍(00368551) 재무제표 수집 중...
# 기업 코드 00368551 - API 오류: 조회된 데이타가 없습니다.
# 기업 덕경종합건설(00424307) 재무제표 수집 중...
# 기업 코드 00424307 - API 오류: 조회된 데이타가 없습니다.
# 기업 글로벌스페셜혼합형사모펀드(00425078) 재무제표 수집 중...
# 기업 코드 00425078 - API 오류: 조회된 데이타가 없습니다.
# 기업 태화(00154499) 재무제표 수집 중...
# 기업 코드 00154499 - API 오류: 조회된 데이타가 없습니다.
# 기업 씨앤앰유동화전문유한회사(00424653) 재무제표 수집 중...
# 기업 코드 00424653 - API 오류: 조회된 데이타가 없습니다.
# 기업 온누리방송(00414522) 재무제표 수집 중...
# 기업 코드 00414522 - API 오류: 조회된 데이타가 없습니다.
# 기업 케이티엠(00425120) 재무제표 수집 중...
# 기업 코드 00425120 - API 오류: 조회된 데이타가 없습니다.
# 기업 아이앤비골드문컨설팅(00356723) 재무제표 수집 중...
# 기업 코드 00356723 - API 오류: 조회된 데이타가 없습니다.
# 기업 동국제강제일차유동화전문유한회사(00375506) 재무제표 수집 중...
# 기업 코드 00375506 - API 오류: 조회된 데이타가 없습니다.
# 기업 밸류노믹스기업구조조정전문회사(00424769) 재무제표 수집 중...
# 기업 코드 00424769 - API 오류: 조회된 데이타가 없습니다.
# 기업 조창(00223300) 재무제표 수집 중...
# 기업 코드 00223300 - API 오류: 조회된 데이타가 없습니다.
# 기업 영지통상(00360294) 재무제표 수집 중...
# 기업 코드 00360294 - API 오류: 조회된 데이타가 없습니다.
# 기업 RosewellConsulting&InvestmentLtd.(00425209) 재무제표 수집 중...
# 기업 코드 00425209 - API 오류: 조회된 데이타가 없습니다.
# 기업 유리시티즌장기채권형사모펀드(00433527) 재무제표 수집 중...
# 기업 코드 00433527 - API 오류: 조회된 데이타가 없습니다.
# 기업 KTB장기채권형사모펀드3호(00433536) 재무제표 수집 중...
# 기업 코드 00433536 - API 오류: 조회된 데이타가 없습니다.
# 기업 KTB장기채권형사모펀드4호(00433545) 재무제표 수집 중...
# 기업 코드 00433545 - API 오류: 조회된 데이타가 없습니다.
# 기업 맥쿼리아이엠엠포세이돈채권형사모펀드4호(00433554) 재무제표 수집 중...
# 기업 코드 00433554 - API 오류: 조회된 데이타가 없습니다.
# 기업 마이에셋애국안정형1호펀드(00433563) 재무제표 수집 중...
# 기업 코드 00433563 - API 오류: 조회된 데이타가 없습니다.
# 기업 노보스(00434702) 재무제표 수집 중...
# 기업 코드 00434702 - API 오류: 조회된 데이타가 없습니다.
# 기업 세이유니온채권혼합형사모펀드(00434711) 재무제표 수집 중...
# 기업 코드 00434711 - API 오류: 조회된 데이타가 없습니다.
# 기업 LG드림혼합형펀드(00434720) 재무제표 수집 중...
# 기업 코드 00434720 - API 오류: 조회된 데이타가 없습니다.
# 기업 알파그로스주식형펀드(00434739) 재무제표 수집 중...
# 기업 코드 00434739 - API 오류: 조회된 데이타가 없습니다.
# 기업 유리알파헷지채권혼합형사모펀드(00434748) 재무제표 수집 중...
# 기업 코드 00434748 - API 오류: 조회된 데이타가 없습니다.
# 기업 알파헷지이기욱혼합형펀드(00434757) 재무제표 수집 중...
# 기업 코드 00434757 - API 오류: 조회된 데이타가 없습니다.
# 기업 맥쿼리IMM홀인원채권형펀드(00434775) 재무제표 수집 중...
# 기업 코드 00434775 - API 오류: 조회된 데이타가 없습니다.
# 기업 유리시장중립채권형사모펀드(00434793) 재무제표 수집 중...
# 기업 코드 00434793 - API 오류: 조회된 데이타가 없습니다.
# 기업 유리알파30채권혼합형사모펀드(00434809) 재무제표 수집 중...
# 기업 코드 00434809 - API 오류: 조회된 데이타가 없습니다.
# 기업 파워외환카드제사차유동화전문유한회사(00432573) 재무제표 수집 중...
# 기업 코드 00432573 - API 오류: 조회된 데이타가 없습니다.
# 기업 파워외환카드제이차유동화전문유한회사(00432607) 재무제표 수집 중...
# 기업 코드 00432607 - API 오류: 조회된 데이타가 없습니다.
# 기업 케드제이차유동화전문유한회사(00432643) 재무제표 수집 중...
# 기업 코드 00432643 - API 오류: 조회된 데이타가 없습니다.
# 기업 굿윌경영자문(00323390) 재무제표 수집 중...
# 기업 코드 00323390 - API 오류: 조회된 데이타가 없습니다.
# 기업 국제금속산업(00412861) 재무제표 수집 중...
# 기업 코드 00412861 - API 오류: 조회된 데이타가 없습니다.
# 기업 덕정무역(00443913) 재무제표 수집 중...
# ---------------------------------------------------------------------------
# SSLEOFError                               Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     463             try:
# --> 464                 self._validate_conn(conn)
#     465             except (SocketTimeout, BaseSSLError) as e:
#
# /usr/local/lib/python3.11/dist-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#    1092         if conn.is_closed:
# -> 1093             conn.connect()
#    1094
#
# /usr/local/lib/python3.11/dist-packages/urllib3/connection.py in connect(self)
#     740
# --> 741             sock_and_verified = _ssl_wrap_socket_and_match_hostname(
#     742                 sock=sock,
#
# /usr/local/lib/python3.11/dist-packages/urllib3/connection.py in _ssl_wrap_socket_and_match_hostname(sock, cert_reqs, ssl_version, ssl_minimum_version, ssl_maximum_version, cert_file, key_file, key_password, ca_certs, ca_cert_dir, ca_cert_data, assert_hostname, assert_fingerprint, server_hostname, ssl_context, tls_in_tls)
#     919
# --> 920     ssl_sock = ssl_wrap_socket(
#     921         sock=sock,
#
# /usr/local/lib/python3.11/dist-packages/urllib3/util/ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     459
# --> 460     ssl_sock = _ssl_wrap_socket_impl(sock, context, tls_in_tls, server_hostname)
#     461     return ssl_sock
#
# /usr/local/lib/python3.11/dist-packages/urllib3/util/ssl_.py in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     503
# --> 504     return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#
# /usr/lib/python3.11/ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     516         # ctx._wrap_socket()
# --> 517         return self.sslsocket_class._create(
#     518             sock=sock,
#
# /usr/lib/python3.11/ssl.py in _create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1103                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1104                     self.do_handshake()
#    1105         except:
#
# /usr/lib/python3.11/ssl.py in do_handshake(self, block)
#    1381                 self.settimeout(None)
# -> 1382             self._sslobj.do_handshake()
#    1383         finally:
#
# SSLEOFError: [SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1006)
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786             # Make the request on the HTTPConnection object
# --> 787             response = self._make_request(
#     788                 conn,
#
# /usr/local/lib/python3.11/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     487                 new_e = _wrap_proxy_error(new_e, conn.proxy.scheme)
# --> 488             raise new_e
#     489
#
# SSLError: [SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1006)
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     666         try:
# --> 667             resp = conn.urlopen(
#     668                 method=request.method,
#
# /usr/local/lib/python3.11/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     840
# --> 841             retries = retries.increment(
#     842                 method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# /usr/local/lib/python3.11/dist-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     518             reason = error or ResponseError(cause)
# --> 519             raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     520
#
# MaxRetryError: HTTPSConnectionPool(host='opendart.fss.or.kr', port=443): Max retries exceeded with url: /api/fnlttSinglAcntAll.json?crtfc_key=85006d20472a255d5eae25ee265b5ed1b78d1386&corp_code=00443913&bsns_year=2022&reprt_code=11011&fs_div=CFS (Caused by SSLError(SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1006)')))
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# <ipython-input-25-34bb9a5920b0> in <cell line: 0>()
#      92
#      93 # 실행: 모든 외감기업의 2022년 재무제표 수집
# ---> 94 collect_all_financials("2022")
#
# <ipython-input-25-34bb9a5920b0> in collect_all_financials(year)
#      78     for corp_code, corp_name in corp_list:
#      79         print(f"기업 {corp_name}({corp_code}) 재무제표 수집 중...")
# ---> 80         df = get_financial_data(corp_code, year)
#      81         if df is not None:
#      82             df['기업명'] = corp_name
#
# <ipython-input-25-34bb9a5920b0> in get_financial_data(corp_code, year)
#      49     }
#      50
# ---> 51     response = requests.get(FINANCIAL_URL, params=params)
#      52     data = response.json()
#      53
#
# /usr/local/lib/python3.11/dist-packages/requests/api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# /usr/local/lib/python3.11/dist-packages/requests/api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# /usr/local/lib/python3.11/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     587         }
#     588         send_kwargs.update(settings)
# --> 589         resp = self.send(prep, **send_kwargs)
#     590
#     591         return resp
#
# /usr/local/lib/python3.11/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     701
#     702         # Send the request
# --> 703         r = adapter.send(request, **kwargs)
#     704
#     705         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python3.11/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     696             if isinstance(e.reason, _SSLError):
#     697                 # This branch is for urllib3 v1.22 and later.
# --> 698                 raise SSLError(e, request=request)
#     699
#     700             raise ConnectionError(e, request=request)
#
# SSLError: HTTPSConnectionPool(host='opendart.fss.or.kr', port=443): Max retries exceeded with url: /api/fnlttSinglAcntAll.json?crtfc_key=85006d20472a255d5eae25ee265b5ed1b78d1386&corp_code=00443913&bsns_year=2022&reprt_code=11011&fs_div=CFS (Caused by SSLError(SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1006)')))
